# %%
# !nvidia-smi
# Out:
# Thu Oct  8 06:03:32 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 455.23.05    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P8    27W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !ls
# Out:
# download_physionet.sh  sample_data

# %%
ls
# Out:
# download_physionet.sh  sample_data/

# %%
# !chmod 777 download_physionet.sh

# %%
# !./download_physionet.sh
# Out:
# --2020-10-08 06:05:26--  https://www.physionet.org/physiobank/database/sleep-edfx/sleep-cassette/SC4001E0-PSG.edf
# Resolving www.physionet.org (www.physionet.org)... 18.18.42.54
# Connecting to www.physionet.org (www.physionet.org)|18.18.42.54|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 48338048 (46M) [application/octet-stream]
# Saving to: ‘SC4001E0-PSG.edf’
#
# SC4001E0-PSG.edf    100%[===================>]  46.10M  9.55MB/s    in 5.8s
#
# 2020-10-08 06:05:33 (7.95 MB/s) - ‘SC4001E0-PSG.edf’ saved [48338048/48338048]
#
# --2020-10-08 06:05:33--  https://www.physionet.org/physiobank/database/sleep-edfx/sleep-cassette/SC4001E0-PSG.edf.hyp
# Resolving www.physionet.org (www.physionet.org)... 18.18.42.54
# Connecting to www.physionet.org (www.physionet.org)|18.18.42.54|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2020-10-08 06:05:35 ERROR 404: Not Found.
#
# --2020-10-08 06:05:35--  https://www.physionet.org/physiobank/database/sleep-edfx/sleep-cassette/SC4001EC-Hypnogram.edf
# Resolving www.physionet.org (www.physionet.org)... 18.18.42.54
# Connecting to www.physionet.org (www.physionet.org)|18.18.42.54|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4620 (4.5K) [application/octet-stream]
# Saving to: ‘SC4001EC-Hypnogram.edf’
#
# SC4001EC-Hypnogram. 100%[===================>]   4.51K  --.-KB/s    in 0s
#
# 2020-10-08 06:05:36 (493 MB/s) - ‘SC4001EC-Hypnogram.edf’ saved [4620/4620]
#
# --2020-10-08 06:05:36--  https://www.physionet.org/physiobank/database/sleep-edfx/sleep-cassette/SC4002E0-PSG.edf
# Resolving www.physionet.org (www.physionet.org)... 18.18.42.54
# Connecting to www.physionet.org (www.physionet.org)|18.18.42.54|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 51621248 (49M) [application/octet-stream]
# Saving to: ‘SC4002E0-PSG.edf’
#
# SC4002E0-PSG.edf    100%[===================>]  49.23M  1.37MB/s    in 37s
#
# 2020-10-08 06:06:13 (1.35 MB/s) - ‘SC4002E0-PSG.edf’ saved [51621248/51621248]
#
# --2020-10-08 06:06:13--  https://www.physionet.org/physiobank/database/sleep-edfx/sleep-cassette/SC4002E0-PSG.edf.hyp
# Resolving www.physionet.org (www.physionet.org)... 18.18.42.54
# Connecting to www.physionet.org (www.physionet.org)|18.18.42.54|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2020-10-08 06:06:14 ERROR 404: Not Found.
#
# --2020-10-08 06:06:14--  https://www.physionet.org/physiobank/database/sleep-edfx/sleep-cassette/SC4002EC-Hypnogram.edf
# Resolving www.physionet.org (www.physionet.org)... 18.18.42.54
# Connecting to www.physionet.org (www.physionet.org)|18.18.42.54|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4580 (4.5K) [application/octet-stream]
# Saving to: ‘SC4002EC-Hypnogram.edf’
#
# SC4002EC-Hypnogram. 100%[===================>]   4.47K  --.-KB/s    in 0s
#
# 2020-10-08 06:06:15 (502 MB/s) - ‘SC4002EC-Hypnogram.edf’ saved [4580/4580]
#
# --2020-10-08 06:06:15--  https://www.physionet.org/physiobank/database/sleep-edfx/sleep-cassette/SC4011E0-PSG.edf
# Resolving www.physionet.org (www.physionet.org)... 18.18.42.54
# Connecting to www.physionet.org (www.physionet.org)|18.18.42.54|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 51110528 (49M) [application/octet-stream]
# Saving to: ‘SC4011E0-PSG.edf’
#
# SC4011E0-PSG.edf    100%[===================>]  48.74M  1.95MB/s    in 54s
#
# 2020-10-08 06:07:10 (927 KB/s) - ‘SC4011E0-PSG.edf’ saved [51110528/51110528]
#
# --2020-10-08 06:07:10--  https://www.physionet.org/physiobank/database/sleep-edfx/sleep-cassette/SC4011E0-PSG.edf.hyp
# Resolving www.physionet.org (www.physionet.org)... 18.18.42.54
# Connecting to www.physionet.org (www.physionet.org)|18.18.42.54|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2020-10-08 06:07:12 ERROR 404: Not Found.
#
# --2020-10-08 06:07:12--  https://www.physionet.org/physiobank/database/sleep-edfx/sleep-cassette/SC4011EH-Hypnogram.edf
# Resolving www.physionet.org (www.physionet.org)... 18.18.42.54
# Connecting to www.physionet.org (www.physionet.org)|18.18.42.54|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3896 (3.8K) [application/octet-stream]
# Saving to: ‘SC4011EH-Hypnogram.edf’
#
# SC4011EH-Hypnogram. 100%[===================>]   3.80K  --.-KB/s    in 0s
#
# 2020-10-08 06:07:13 (565 MB/s) - ‘SC4011EH-Hypnogram.edf’ saved [3896/3896]
#
# --2020-10-08 06:07:13--  https://www.physionet.org/physiobank/database/sleep-edfx/sleep-cassette/SC4012E0-PSG.edf
# Resolving www.physionet.org (www.physionet.org)... 18.18.42.54
# Connecting to www.physionet.org (www.physionet.org)|18.18.42.54|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 51986048 (50M) [application/octet-stream]
# Saving to: ‘SC4012E0-PSG.edf’
#
# SC4012E0-PSG.edf    100%[===================>]  49.58M   887KB/s    in 63s
#
# 2020-10-08 06:08:17 (810 KB/s) - ‘SC4012E0-PSG.edf’ saved [51986048/51986048]
#
# --2020-10-08 06:08:17--  https://www.physionet.org/physiobank/database/sleep-edfx/sleep-cassette/SC4012E0-PSG.edf.hyp
# Resolving www.physionet.org (www.physionet.org)... 18.18.42.54
# Connecting to www.physionet.org (www.physionet.org)|18.18.42.54|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2020-10-08 06:08:18 ERROR 404: Not Found.
#
# --2020-10-08 06:08:18--  https://www.physionet.org/physiobank/database/sleep-edfx/sleep-cassette/SC4012EC-Hypnogram.edf
# Resolving www.physionet.org (www.physionet.org)... 18.18.42.54
# Connecting to www.physionet.org (www.physionet.org)|18.18.42.54|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5082 (5.0K) [application/octet-stream]
# Saving to: ‘SC4012EC-Hypnogram.edf’
#
# SC4012EC-Hypnogram. 100%[===================>]   4.96K  --.-KB/s    in 0s
#
# 2020-10-08 06:08:19 (253 MB/s) - ‘SC4012EC-Hypnogram.edf’ saved [5082/5082]
#
# --2020-10-08 06:08:19--  https://www.physionet.org/physiobank/database/sleep-edfx/sleep-cassette/SC4021E0-PSG.edf
# Resolving www.physionet.org (www.physionet.org)... 18.18.42.54
# Connecting to www.physionet.org (www.physionet.org)|18.18.42.54|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 51147008 (49M) [application/octet-stream]
# Saving to: ‘SC4021E0-PSG.edf’
#
# SC4021E0-PSG.edf    100%[===================>]  48.78M  1.43MB/s    in 56s
#
# 2020-10-08 06:09:16 (897 KB/s) - ‘SC4021E0-PSG.edf’ saved [51147008/51147008]
#
# --2020-10-08 06:09:16--  https://www.physionet.org/physiobank/database/sleep-edfx/sleep-cassette/SC4021E0-PSG.edf.hyp
# Resolving www.physionet.org (www.physionet.org)... 18.18.42.54
# Connecting to www.physionet.org (www.physionet.org)|18.18.42.54|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2020-10-08 06:09:17 ERROR 404: Not Found.
#
# --2020-10-08 06:09:17--  https://www.physionet.org/physiobank/database/sleep-edfx/sleep-cassette/SC4021EH-Hypnogram.edf
# Resolving www.physionet.org (www.physionet.org)... 18.18.42.54
# Connecting to www.physionet.org (www.physionet.org)|18.18.42.54|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4804 (4.7K) [application/octet-stream]
# Saving to: ‘SC4021EH-Hypnogram.edf’
#
# SC4021EH-Hypnogram. 100%[===================>]   4.69K  --.-KB/s    in 0s
#
# 2020-10-08 06:09:18 (476 MB/s) - ‘SC4021EH-Hypnogram.edf’ saved [4804/4804]
#
# --2020-10-08 06:09:18--  https://www.physionet.org/physiobank/database/sleep-edfx/sleep-cassette/SC4022E0-PSG.edf
# Resolving www.physionet.org (www.physionet.org)... 18.18.42.54
# Connecting to www.physionet.org (www.physionet.org)|18.18.42.54|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 50271488 (48M) [application/octet-stream]
# Saving to: ‘SC4022E0-PSG.edf’
#
# SC4022E0-PSG.edf    100%[===================>]  47.94M   669KB/s    in 45s
#
# 2020-10-08 06:10:04 (1.06 MB/s) - ‘SC4022E0-PSG.edf’ saved [50271488/50271488]
#
# --2020-10-08 06:10:04--  https://www.physionet.org/physiobank/database/sleep-edfx/sleep-cassette/SC4022E0-PSG.edf.hyp
# Resolving www.physionet.org (www.physionet.org)... 18.18.42.54
# Connecting to www.physionet.org (www.physionet.org)|18.18.42.54|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2020-10-08 06:10:05 ERROR 404: Not Found.
#
# --2020-10-08 06:10:05--  https://www.physionet.org/physiobank/database/sleep-edfx/sleep-cassette/SC4022EJ-Hypnogram.edf
# Resolving www.physionet.org (www.physionet.org)... 18.18.42.54
# Connecting to www.physionet.org (www.physionet.org)|18.18.42.54|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5292 (5.2K) [application/octet-stream]
# Saving to: ‘SC4022EJ-Hypnogram.edf’
#
# SC4022EJ-Hypnogram. 100%[===================>]   5.17K  --.-KB/s    in 0s
#
# 2020-10-08 06:10:06 (540 MB/s) - ‘SC4022EJ-Hypnogram.edf’ saved [5292/5292]
#
# --2020-10-08 06:10:06--  https://www.physionet.org/physiobank/database/sleep-edfx/sleep-cassette/SC4031E0-PSG.edf
# Resolving www.physionet.org (www.physionet.org)... 18.18.42.54
# Connecting to www.physionet.org (www.physionet.org)|18.18.42.54|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 51438848 (49M) [application/octet-stream]
# Saving to: ‘SC4031E0-PSG.edf’
#
# SC4031E0-PSG.edf    100%[===================>]  49.06M   429KB/s    in 44s
#
# 2020-10-08 06:10:51 (1.12 MB/s) - ‘SC4031E0-PSG.edf’ saved [51438848/51438848]
#
# --2020-10-08 06:10:51--  https://www.physionet.org/physiobank/database/sleep-edfx/sleep-cassette/SC4031E0-PSG.edf.hyp
# Resolving www.physionet.org (www.physionet.org)... 18.18.42.54
# Connecting to www.physionet.org (www.physionet.org)|18.18.42.54|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2020-10-08 06:10:52 ERROR 404: Not Found.
#
# --2020-10-08 06:10:52--  https://www.physionet.org/physiobank/database/sleep-edfx/sleep-cassette/SC4031EC-Hypnogram.edf
# Resolving www.physionet.org (www.physionet.org)... 18.18.42.54
# Connecting to www.physionet.org (www.physionet.org)|18.18.42.54|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3700 (3.6K) [application/octet-stream]
# Saving to: ‘SC4031EC-Hypnogram.edf’
#
# SC4031EC-Hypnogram. 100%[===================>]   3.61K  --.-KB/s    in 0s
#
# 2020-10-08 06:10:53 (539 MB/s) - ‘SC4031EC-Hypnogram.edf’ saved [3700/3700]
#
# --2020-10-08 06:10:53--  https://www.physionet.org/physiobank/database/sleep-edfx/sleep-cassette/SC4032E0-PSG.edf
# Resolving www.physionet.org (www.physionet.org)... 18.18.42.54
# Connecting to www.physionet.org (www.physionet.org)|18.18.42.54|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 49833728 (48M) [application/octet-stream]
# Saving to: ‘SC4032E0-PSG.edf’
#
# SC4032E0-PSG.edf    100%[===================>]  47.52M  1.32MB/s    in 68s
#
# 2020-10-08 06:12:02 (712 KB/s) - ‘SC4032E0-PSG.edf’ saved [49833728/49833728]
#
# --2020-10-08 06:12:02--  https://www.physionet.org/physiobank/database/sleep-edfx/sleep-cassette/SC4032E0-PSG.edf.hyp
# Resolving www.physionet.org (www.physionet.org)... 18.18.42.54
# Connecting to www.physionet.org (www.physionet.org)|18.18.42.54|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2020-10-08 06:12:03 ERROR 404: Not Found.
#
# --2020-10-08 06:12:03--  https://www.physionet.org/physiobank/database/sleep-edfx/sleep-cassette/SC4032EP-Hypnogram.edf
# Resolving www.physionet.org (www.physionet.org)... 18.18.42.54
# Connecting to www.physionet.org (www.physionet.org)|18.18.42.54|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3800 (3.7K) [application/octet-stream]
# Saving to: ‘SC4032EP-Hypnogram.edf’
#
# SC4032EP-Hypnogram. 100%[===================>]   3.71K  --.-KB/s    in 0s
#
# 2020-10-08 06:12:04 (520 MB/s) - ‘SC4032EP-Hypnogram.edf’ saved [3800/3800]
#
# --2020-10-08 06:12:04--  https://www.physionet.org/physiobank/database/sleep-edfx/sleep-cassette/SC4041E0-PSG.edf
# Resolving www.physionet.org (www.physionet.org)... 18.18.42.54
# Connecting to www.physionet.org (www.physionet.org)|18.18.42.54|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 46878848 (45M) [application/octet-stream]
# Saving to: ‘SC4041E0-PSG.edf’
#
# SC4041E0-PSG.edf    100%[===================>]  44.71M  2.65MB/s    in 64s
#
# 2020-10-08 06:13:09 (720 KB/s) - ‘SC4041E0-PSG.edf’ saved [46878848/46878848]
#
# --2020-10-08 06:13:09--  https://www.physionet.org/physiobank/database/sleep-edfx/sleep-cassette/SC4041E0-PSG.edf.hyp
# Resolving www.physionet.org (www.physionet.org)... 18.18.42.54
# Connecting to www.physionet.org (www.physionet.org)|18.18.42.54|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2020-10-08 06:13:10 ERROR 404: Not Found.
#
# --2020-10-08 06:13:10--  https://www.physionet.org/physiobank/database/sleep-edfx/sleep-cassette/SC4041EC-Hypnogram.edf
# Resolving www.physionet.org (www.physionet.org)... 18.18.42.54
# Connecting to www.physionet.org (www.physionet.org)|18.18.42.54|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4830 (4.7K) [application/octet-stream]
# Saving to: ‘SC4041EC-Hypnogram.edf’
#
# SC4041EC-Hypnogram. 100%[===================>]   4.72K  --.-KB/s    in 0s
#
# 2020-10-08 06:13:11 (423 MB/s) - ‘SC4041EC-Hypnogram.edf’ saved [4830/4830]
#
# --2020-10-08 06:13:11--  https://www.physionet.org/physiobank/database/sleep-edfx/sleep-cassette/SC4042E0-PSG.edf
# Resolving www.physionet.org (www.physionet.org)... 18.18.42.54
# Connecting to www.physionet.org (www.physionet.org)|18.18.42.54|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 50928128 (49M) [application/octet-stream]
# Saving to: ‘SC4042E0-PSG.edf’
#
# SC4042E0-PSG.edf    100%[===================>]  48.57M  1.17MB/s    in 54s
#
# 2020-10-08 06:14:06 (927 KB/s) - ‘SC4042E0-PSG.edf’ saved [50928128/50928128]
#
# --2020-10-08 06:14:06--  https://www.physionet.org/physiobank/database/sleep-edfx/sleep-cassette/SC4042E0-PSG.edf.hyp
# Resolving www.physionet.org (www.physionet.org)... 18.18.42.54
# Connecting to www.physionet.org (www.physionet.org)|18.18.42.54|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2020-10-08 06:14:07 ERROR 404: Not Found.
#
# --2020-10-08 06:14:07--  https://www.physionet.org/physiobank/database/sleep-edfx/sleep-cassette/SC4042EC-Hypnogram.edf
# Resolving www.physionet.org (www.physionet.org)... 18.18.42.54
# Connecting to www.physionet.org (www.physionet.org)|18.18.42.54|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5276 (5.2K) [application/octet-stream]
# Saving to: ‘SC4042EC-Hypnogram.edf’
#
# SC4042EC-Hypnogram. 100%[===================>]   5.15K  --.-KB/s    in 0s
#
# 2020-10-08 06:14:08 (576 MB/s) - ‘SC4042EC-Hypnogram.edf’ saved [5276/5276]
#
# --2020-10-08 06:14:08--  https://www.physionet.org/physiobank/database/sleep-edfx/sleep-cassette/SC4051E0-PSG.edf
# Resolving www.physionet.org (www.physionet.org)... 18.18.42.54
# Connecting to www.physionet.org (www.physionet.org)|18.18.42.54|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 49651328 (47M) [application/octet-stream]
# Saving to: ‘SC4051E0-PSG.edf’
#
# SC4051E0-PSG.edf    100%[===================>]  47.35M  1.28MB/s    in 42s
#
# 2020-10-08 06:14:50 (1.14 MB/s) - ‘SC4051E0-PSG.edf’ saved [49651328/49651328]
#
# --2020-10-08 06:14:50--  https://www.physionet.org/physiobank/database/sleep-edfx/sleep-cassette/SC4051E0-PSG.edf.hyp
# Resolving www.physionet.org (www.physionet.org)... 18.18.42.54
# Connecting to www.physionet.org (www.physionet.org)|18.18.42.54|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2020-10-08 06:14:52 ERROR 404: Not Found.
#
# --2020-10-08 06:14:52--  https://www.physionet.org/physiobank/database/sleep-edfx/sleep-cassette/SC4051EC-Hypnogram.edf
# Resolving www.physionet.org (www.physionet.org)... 18.18.42.54
# Connecting to www.physionet.org (www.physionet.org)|18.18.42.54|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3976 (3.9K) [application/octet-stream]
# Saving to: ‘SC4051EC-Hypnogram.edf’
#
# SC4051EC-Hypnogram. 100%[===================>]   3.88K  --.-KB/s    in 0s
#
# 2020-10-08 06:14:53 (252 MB/s) - ‘SC4051EC-Hypnogram.edf’ saved [3976/3976]
#
# --2020-10-08 06:14:53--  https://www.physionet.org/physiobank/database/sleep-edfx/sleep-cassette/SC4052E0-PSG.edf
# Resolving www.physionet.org (www.physionet.org)... 18.18.42.54
# Connecting to www.physionet.org (www.physionet.org)|18.18.42.54|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 51183488 (49M) [application/octet-stream]
# Saving to: ‘SC4052E0-PSG.edf’
#
# SC4052E0-PSG.edf    100%[===================>]  48.81M  2.29MB/s    in 42s
#
# 2020-10-08 06:15:36 (1.16 MB/s) - ‘SC4052E0-PSG.edf’ saved [51183488/51183488]
#
# --2020-10-08 06:15:36--  https://www.physionet.org/physiobank/database/sleep-edfx/sleep-cassette/SC4052E0-PSG.edf.hyp
# Resolving www.physionet.org (www.physionet.org)... 18.18.42.54
# Connecting to www.physionet.org (www.physionet.org)|18.18.42.54|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2020-10-08 06:15:37 ERROR 404: Not Found.
#
# --2020-10-08 06:15:37--  https://www.physionet.org/physiobank/database/sleep-edfx/sleep-cassette/SC4052EC-Hypnogram.edf
# Resolving www.physionet.org (www.physionet.org)... 18.18.42.54
# Connecting to www.physionet.org (www.physionet.org)|18.18.42.54|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4232 (4.1K) [application/octet-stream]
# Saving to: ‘SC4052EC-Hypnogram.edf’
#
# SC4052EC-Hypnogram. 100%[===================>]   4.13K  --.-KB/s    in 0s
#
# 2020-10-08 06:15:37 (417 MB/s) - ‘SC4052EC-Hypnogram.edf’ saved [4232/4232]
#
# --2020-10-08 06:15:37--  https://www.physionet.org/physiobank/database/sleep-edfx/sleep-cassette/SC4061E0-PSG.edf
# Resolving www.physionet.org (www.physionet.org)... 18.18.42.54
# Connecting to www.physionet.org (www.physionet.org)|18.18.42.54|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 50526848 (48M) [application/octet-stream]
# Saving to: ‘SC4061E0-PSG.edf’
#
# SC4061E0-PSG.edf    100%[===================>]  48.19M  1.06MB/s    in 69s
#
# 2020-10-08 06:16:47 (719 KB/s) - ‘SC4061E0-PSG.edf’ saved [50526848/50526848]
#
# --2020-10-08 06:16:47--  https://www.physionet.org/physiobank/database/sleep-edfx/sleep-cassette/SC4061E0-PSG.edf.hyp
# Resolving www.physionet.org (www.physionet.org)... 18.18.42.54
# Connecting to www.physionet.org (www.physionet.org)|18.18.42.54|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2020-10-08 06:16:48 ERROR 404: Not Found.
#
# --2020-10-08 06:16:48--  https://www.physionet.org/physiobank/database/sleep-edfx/sleep-cassette/SC4061EC-Hypnogram.edf
# Resolving www.physionet.org (www.physionet.org)... 18.18.42.54
# Connecting to www.physionet.org (www.physionet.org)|18.18.42.54|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2620 (2.6K) [application/octet-stream]
# Saving to: ‘SC4061EC-Hypnogram.edf’
#
# SC4061EC-Hypnogram. 100%[===================>]   2.56K  --.-KB/s    in 0s
#
# 2020-10-08 06:16:48 (359 MB/s) - ‘SC4061EC-Hypnogram.edf’ saved [2620/2620]
#
# --2020-10-08 06:16:48--  https://www.physionet.org/physiobank/database/sleep-edfx/sleep-cassette/SC4062E0-PSG.edf
# Resolving www.physionet.org (www.physionet.org)... 18.18.42.54
# Connecting to www.physionet.org (www.physionet.org)|18.18.42.54|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 51621248 (49M) [application/octet-stream]
# Saving to: ‘SC4062E0-PSG.edf’
#
# SC4062E0-PSG.edf    100%[===================>]  49.23M   584KB/s    in 49s
#
# 2020-10-08 06:17:39 (1020 KB/s) - ‘SC4062E0-PSG.edf’ saved [51621248/51621248]
#
# --2020-10-08 06:17:39--  https://www.physionet.org/physiobank/database/sleep-edfx/sleep-cassette/SC4062E0-PSG.edf.hyp
# Resolving www.physionet.org (www.physionet.org)... 18.18.42.54
# Connecting to www.physionet.org (www.physionet.org)|18.18.42.54|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2020-10-08 06:17:40 ERROR 404: Not Found.
#
# --2020-10-08 06:17:40--  https://www.physionet.org/physiobank/database/sleep-edfx/sleep-cassette/SC4062EC-Hypnogram.edf
# Resolving www.physionet.org (www.physionet.org)... 18.18.42.54
# Connecting to www.physionet.org (www.physionet.org)|18.18.42.54|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3146 (3.1K) [application/octet-stream]
# Saving to: ‘SC4062EC-Hypnogram.edf’
#
# SC4062EC-Hypnogram. 100%[===================>]   3.07K  --.-KB/s    in 0s
#
# 2020-10-08 06:17:41 (514 MB/s) - ‘SC4062EC-Hypnogram.edf’ saved [3146/3146]
#
# --2020-10-08 06:17:41--  https://www.physionet.org/physiobank/database/sleep-edfx/sleep-cassette/SC4071E0-PSG.edf
# Resolving www.physionet.org (www.physionet.org)... 18.18.42.54
# Connecting to www.physionet.org (www.physionet.org)|18.18.42.54|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 51256448 (49M) [application/octet-stream]
# Saving to: ‘SC4071E0-PSG.edf’
#
# SC4071E0-PSG.edf    100%[===================>]  48.88M  1.22MB/s    in 48s
#
# 2020-10-08 06:18:30 (1.01 MB/s) - ‘SC4071E0-PSG.edf’ saved [51256448/51256448]
#
# --2020-10-08 06:18:30--  https://www.physionet.org/physiobank/database/sleep-edfx/sleep-cassette/SC4071E0-PSG.edf.hyp
# Resolving www.physionet.org (www.physionet.org)... 18.18.42.54
# Connecting to www.physionet.org (www.physionet.org)|18.18.42.54|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2020-10-08 06:18:31 ERROR 404: Not Found.
#
# --2020-10-08 06:18:31--  https://www.physionet.org/physiobank/database/sleep-edfx/sleep-cassette/SC4071EC-Hypnogram.edf
# Resolving www.physionet.org (www.physionet.org)... 18.18.42.54
# Connecting to www.physionet.org (www.physionet.org)|18.18.42.54|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3628 (3.5K) [application/octet-stream]
# Saving to: ‘SC4071EC-Hypnogram.edf’
#
# SC4071EC-Hypnogram. 100%[===================>]   3.54K  --.-KB/s    in 0s
#
# 2020-10-08 06:18:32 (604 MB/s) - ‘SC4071EC-Hypnogram.edf’ saved [3628/3628]
#
# --2020-10-08 06:18:32--  https://www.physionet.org/physiobank/database/sleep-edfx/sleep-cassette/SC4072E0-PSG.edf
# Resolving www.physionet.org (www.physionet.org)... 18.18.42.54
# Connecting to www.physionet.org (www.physionet.org)|18.18.42.54|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 50526848 (48M) [application/octet-stream]
# Saving to: ‘SC4072E0-PSG.edf’
#
# SC4072E0-PSG.edf    100%[===================>]  48.19M  1.82MB/s    in 31s
#
# 2020-10-08 06:19:04 (1.55 MB/s) - ‘SC4072E0-PSG.edf’ saved [50526848/50526848]
#
# --2020-10-08 06:19:04--  https://www.physionet.org/physiobank/database/sleep-edfx/sleep-cassette/SC4072E0-PSG.edf.hyp
# Resolving www.physionet.org (www.physionet.org)... 18.18.42.54
# Connecting to www.physionet.org (www.physionet.org)|18.18.42.54|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2020-10-08 06:19:05 ERROR 404: Not Found.
#
# --2020-10-08 06:19:05--  https://www.physionet.org/physiobank/database/sleep-edfx/sleep-cassette/SC4072EH-Hypnogram.edf
# Resolving www.physionet.org (www.physionet.org)... 18.18.42.54
# Connecting to www.physionet.org (www.physionet.org)|18.18.42.54|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5284 (5.2K) [application/octet-stream]
# Saving to: ‘SC4072EH-Hypnogram.edf’
#
# SC4072EH-Hypnogram. 100%[===================>]   5.16K  --.-KB/s    in 0s
#
# 2020-10-08 06:19:06 (503 MB/s) - ‘SC4072EH-Hypnogram.edf’ saved [5284/5284]
#
# --2020-10-08 06:19:06--  https://www.physionet.org/physiobank/database/sleep-edfx/sleep-cassette/SC4081E0-PSG.edf
# Resolving www.physionet.org (www.physionet.org)... 18.18.42.54
# Connecting to www.physionet.org (www.physionet.org)|18.18.42.54|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 51001088 (49M) [application/octet-stream]
# Saving to: ‘SC4081E0-PSG.edf’
#
# SC4081E0-PSG.edf    100%[===================>]  48.64M   423KB/s    in 75s
#
# 2020-10-08 06:20:22 (662 KB/s) - ‘SC4081E0-PSG.edf’ saved [51001088/51001088]
#
# --2020-10-08 06:20:22--  https://www.physionet.org/physiobank/database/sleep-edfx/sleep-cassette/SC4081E0-PSG.edf.hyp
# Resolving www.physionet.org (www.physionet.org)... 18.18.42.54
# Connecting to www.physionet.org (www.physionet.org)|18.18.42.54|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2020-10-08 06:20:23 ERROR 404: Not Found.
#
# --2020-10-08 06:20:23--  https://www.physionet.org/physiobank/database/sleep-edfx/sleep-cassette/SC4081EC-Hypnogram.edf
# Resolving www.physionet.org (www.physionet.org)... 18.18.42.54
# Connecting to www.physionet.org (www.physionet.org)|18.18.42.54|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4306 (4.2K) [application/octet-stream]
# Saving to: ‘SC4081EC-Hypnogram.edf’
#
# SC4081EC-Hypnogram. 100%[===================>]   4.21K  --.-KB/s    in 0s
#
# 2020-10-08 06:20:23 (475 MB/s) - ‘SC4081EC-Hypnogram.edf’ saved [4306/4306]
#
# --2020-10-08 06:20:23--  https://www.physionet.org/physiobank/database/sleep-edfx/sleep-cassette/SC4082E0-PSG.edf
# Resolving www.physionet.org (www.physionet.org)... 18.18.42.54
# Connecting to www.physionet.org (www.physionet.org)|18.18.42.54|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 48046208 (46M) [application/octet-stream]
# Saving to: ‘SC4082E0-PSG.edf’
#
# SC4082E0-PSG.edf    100%[===================>]  45.82M  1.05MB/s    in 39s
#
# 2020-10-08 06:21:04 (1.17 MB/s) - ‘SC4082E0-PSG.edf’ saved [48046208/48046208]
#
# --2020-10-08 06:21:04--  https://www.physionet.org/physiobank/database/sleep-edfx/sleep-cassette/SC4082E0-PSG.edf.hyp
# Resolving www.physionet.org (www.physionet.org)... 18.18.42.54
# Connecting to www.physionet.org (www.physionet.org)|18.18.42.54|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2020-10-08 06:21:05 ERROR 404: Not Found.
#
# --2020-10-08 06:21:05--  https://www.physionet.org/physiobank/database/sleep-edfx/sleep-cassette/SC4082EP-Hypnogram.edf
# Resolving www.physionet.org (www.physionet.org)... 18.18.42.54
# Connecting to www.physionet.org (www.physionet.org)|18.18.42.54|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4668 (4.6K) [application/octet-stream]
# Saving to: ‘SC4082EP-Hypnogram.edf’
#
# SC4082EP-Hypnogram. 100%[===================>]   4.56K  --.-KB/s    in 0s
#
# 2020-10-08 06:21:06 (460 MB/s) - ‘SC4082EP-Hypnogram.edf’ saved [4668/4668]
#
# --2020-10-08 06:21:06--  https://www.physionet.org/physiobank/database/sleep-edfx/sleep-cassette/SC4091E0-PSG.edf
# Resolving www.physionet.org (www.physionet.org)... 18.18.42.54
# Connecting to www.physionet.org (www.physionet.org)|18.18.42.54|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 49833728 (48M) [application/octet-stream]
# Saving to: ‘SC4091E0-PSG.edf’
#
# SC4091E0-PSG.edf    100%[===================>]  47.52M  1.98MB/s    in 24s
#
# 2020-10-08 06:21:31 (1.97 MB/s) - ‘SC4091E0-PSG.edf’ saved [49833728/49833728]
#
# --2020-10-08 06:21:31--  https://www.physionet.org/physiobank/database/sleep-edfx/sleep-cassette/SC4091E0-PSG.edf.hyp
# Resolving www.physionet.org (www.physionet.org)... 18.18.42.54
# Connecting to www.physionet.org (www.physionet.org)|18.18.42.54|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2020-10-08 06:21:32 ERROR 404: Not Found.
#
# --2020-10-08 06:21:32--  https://www.physionet.org/physiobank/database/sleep-edfx/sleep-cassette/SC4091EC-Hypnogram.edf
# Resolving www.physionet.org (www.physionet.org)... 18.18.42.54
# Connecting to www.physionet.org (www.physionet.org)|18.18.42.54|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4474 (4.4K) [application/octet-stream]
# Saving to: ‘SC4091EC-Hypnogram.edf’
#
# SC4091EC-Hypnogram. 100%[===================>]   4.37K  --.-KB/s    in 0s
#
# 2020-10-08 06:21:32 (204 MB/s) - ‘SC4091EC-Hypnogram.edf’ saved [4474/4474]
#
# --2020-10-08 06:21:32--  https://www.physionet.org/physiobank/database/sleep-edfx/sleep-cassette/SC4092E0-PSG.edf
# Resolving www.physionet.org (www.physionet.org)... 18.18.42.54
# Connecting to www.physionet.org (www.physionet.org)|18.18.42.54|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 52131968 (50M) [application/octet-stream]
# Saving to: ‘SC4092E0-PSG.edf’
#
# SC4092E0-PSG.edf     45%[========>           ]  22.51M  1.53MB/s    eta 18s    ^C

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
ls -al
# Out:
# total 958016
# drwxr-xr-x 1 root root     4096 Oct  8 06:21 ./
# drwxr-xr-x 1 root root     4096 Oct  8 06:02 ../
# drwxr-xr-x 1 root root     4096 Oct  5 16:31 .config/
# -rwxrwxrwx 1 root root    11388 Oct  8 06:04 download_physionet.sh*
# drwxr-xr-x 1 root root     4096 Oct  5 16:31 sample_data/
# -rw-r--r-- 1 root root 48338048 Apr  5  2018 SC4001E0-PSG.edf
# -rw-r--r-- 1 root root     4620 Apr  5  2018 SC4001EC-Hypnogram.edf
# -rw-r--r-- 1 root root 51621248 Apr  5  2018 SC4002E0-PSG.edf
# -rw-r--r-- 1 root root     4580 Apr  5  2018 SC4002EC-Hypnogram.edf
# -rw-r--r-- 1 root root 51110528 Apr  5  2018 SC4011E0-PSG.edf
# -rw-r--r-- 1 root root     3896 Apr  5  2018 SC4011EH-Hypnogram.edf
# -rw-r--r-- 1 root root 51986048 Apr  5  2018 SC4012E0-PSG.edf
# -rw-r--r-- 1 root root     5082 Apr  5  2018 SC4012EC-Hypnogram.edf
# -rw-r--r-- 1 root root 51147008 Apr  5  2018 SC4021E0-PSG.edf
# -rw-r--r-- 1 root root     4804 Apr  5  2018 SC4021EH-Hypnogram.edf
# -rw-r--r-- 1 root root 50271488 Apr  5  2018 SC4022E0-PSG.edf
# -rw-r--r-- 1 root root     5292 Apr  5  2018 SC4022EJ-Hypnogram.edf
# -rw-r--r-- 1 root root 51438848 Apr  5  2018 SC4031E0-PSG.edf
# -rw-r--r-- 1 root root     3700 Apr  5  2018 SC4031EC-Hypnogram.edf
# -rw-r--r-- 1 root root 49833728 Apr  5  2018 SC4032E0-PSG.edf
# -rw-r--r-- 1 root root     3800 Apr  5  2018 SC4032EP-Hypnogram.edf
# -rw-r--r-- 1 root root 46878848 Apr  5  2018 SC4041E0-PSG.edf
# -rw-r--r-- 1 root root     4830 Apr  5  2018 SC4041EC-Hypnogram.edf
# -rw-r--r-- 1 root root 50928128 Apr  5  2018 SC4042E0-PSG.edf
# -rw-r--r-- 1 root root     5276 Apr  5  2018 SC4042EC-Hypnogram.edf
# -rw-r--r-- 1 root root 49651328 Apr  5  2018 SC4051E0-PSG.edf
# -rw-r--r-- 1 root root     3976 Apr  5  2018 SC4051EC-Hypnogram.edf
# -rw-r--r-- 1 root root 51183488 Apr  5  2018 SC4052E0-PSG.edf
# -rw-r--r-- 1 root root     4232 Apr  5  2018 SC4052EC-Hypnogram.edf
# -rw-r--r-- 1 root root 50526848 Apr  5  2018 SC4061E0-PSG.edf
# -rw-r--r-- 1 root root     2620 Apr  5  2018 SC4061EC-Hypnogram.edf
# -rw-r--r-- 1 root root 51621248 Apr  5  2018 SC4062E0-PSG.edf
# -rw-r--r-- 1 root root     3146 Apr  5  2018 SC4062EC-Hypnogram.edf
# -rw-r--r-- 1 root root 51256448 Apr  5  2018 SC4071E0-PSG.edf
# -rw-r--r-- 1 root root     3628 Apr  5  2018 SC4071EC-Hypnogram.edf
# -rw-r--r-- 1 root root 50526848 Apr  5  2018 SC4072E0-PSG.edf
# -rw-r--r-- 1 root root     5284 Apr  5  2018 SC4072EH-Hypnogram.edf
# -rw-r--r-- 1 root root 51001088 Apr  5  2018 SC4081E0-PSG.edf
# -rw-r--r-- 1 root root     4306 Apr  5  2018 SC4081EC-Hypnogram.edf
# -rw-r--r-- 1 root root 48046208 Apr  5  2018 SC4082E0-PSG.edf
# -rw-r--r-- 1 root root     4668 Apr  5  2018 SC4082EP-Hypnogram.edf
# -rw-r--r-- 1 root root 49833728 Apr  5  2018 SC4091E0-PSG.edf
# -rw-r--r-- 1 root root     4474 Apr  5  2018 SC4091EC-Hypnogram.edf
# -rw-r--r-- 1 root root 23609010 Oct  8 06:21 SC4092E0-PSG.edf

# %%
ls
# Out:
# download_physionet.sh*  SC4031E0-PSG.edf        SC4062E0-PSG.edf
# sample_data/            SC4031EC-Hypnogram.edf  SC4062EC-Hypnogram.edf
# SC4001E0-PSG.edf        SC4032E0-PSG.edf        SC4071E0-PSG.edf
# SC4001EC-Hypnogram.edf  SC4032EP-Hypnogram.edf  SC4071EC-Hypnogram.edf
# SC4002E0-PSG.edf        SC4041E0-PSG.edf        SC4072E0-PSG.edf
# SC4002EC-Hypnogram.edf  SC4041EC-Hypnogram.edf  SC4072EH-Hypnogram.edf
# SC4011E0-PSG.edf        SC4042E0-PSG.edf        SC4081E0-PSG.edf
# SC4011EH-Hypnogram.edf  SC4042EC-Hypnogram.edf  SC4081EC-Hypnogram.edf
# SC4012E0-PSG.edf        SC4051E0-PSG.edf        SC4082E0-PSG.edf
# SC4012EC-Hypnogram.edf  SC4051EC-Hypnogram.edf  SC4082EP-Hypnogram.edf
# SC4021E0-PSG.edf        SC4052E0-PSG.edf        SC4091E0-PSG.edf
# SC4021EH-Hypnogram.edf  SC4052EC-Hypnogram.edf  SC4091EC-Hypnogram.edf
# SC4022E0-PSG.edf        SC4061E0-PSG.edf        SC4092E0-PSG.edf
# SC4022EJ-Hypnogram.edf  SC4061EC-Hypnogram.edf

# %%
mkdir signals

# %%
mkdir annotations

# %%
mv *Hypnogram.edf ./annotations

# %%
mv *PSG.edf ./signals

# %%
ls signals/
# Out:
# SC4001E0-PSG.edf  SC4022E0-PSG.edf  SC4051E0-PSG.edf  SC4072E0-PSG.edf
# SC4002E0-PSG.edf  SC4031E0-PSG.edf  SC4052E0-PSG.edf  SC4081E0-PSG.edf
# SC4011E0-PSG.edf  SC4032E0-PSG.edf  SC4061E0-PSG.edf  SC4082E0-PSG.edf
# SC4012E0-PSG.edf  SC4041E0-PSG.edf  SC4062E0-PSG.edf  SC4091E0-PSG.edf
# SC4021E0-PSG.edf  SC4042E0-PSG.edf  SC4071E0-PSG.edf  SC4092E0-PSG.edf

# %%
ls annotations
# Out:
# SC4001EC-Hypnogram.edf  SC4032EP-Hypnogram.edf  SC4071EC-Hypnogram.edf
# SC4002EC-Hypnogram.edf  SC4041EC-Hypnogram.edf  SC4072EH-Hypnogram.edf
# SC4011EH-Hypnogram.edf  SC4042EC-Hypnogram.edf  SC4081EC-Hypnogram.edf
# SC4012EC-Hypnogram.edf  SC4051EC-Hypnogram.edf  SC4082EP-Hypnogram.edf
# SC4021EH-Hypnogram.edf  SC4052EC-Hypnogram.edf  SC4091EC-Hypnogram.edf
# SC4022EJ-Hypnogram.edf  SC4061EC-Hypnogram.edf
# SC4031EC-Hypnogram.edf  SC4062EC-Hypnogram.edf

# %%
# !pip install pyedflib
# Out:
# Collecting pyedflib
#   Downloading https://files.pythonhosted.org/packages/ed/00/2ab3e04b03651a82df063beb16f5cf077751d7045432067b04b265ab8760/pyEDFlib-0.1.18.tar.gz (1.1MB)
#      |████████████████████████████████| 1.1MB 2.8MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from pyedflib) (1.18.5)
# Building wheels for collected packages: pyedflib
#   Building wheel for pyedflib (PEP 517) ... done
#   Created wheel for pyedflib: filename=pyEDFlib-0.1.18-cp36-cp36m-linux_x86_64.whl size=920481 sha256=b9d97d23863ff86ae51a0604e23787c3d1e1f08de9bc83bbc19d9e6c94cba32b
#   Stored in directory: /root/.cache/pip/wheels/4c/16/32/829749d6ab56f64e81e44aed0b4b9a892c975512c15cc3edbb
# Successfully built pyedflib
# Installing collected packages: pyedflib
# Successfully installed pyedflib-0.1.18

# %%
import numpy as np
from pyedflib import highlevel
import matplotlib.pyplot as plt
import os
import pandas as pd
import random
import shutil

# %%
def search_annotations_edf(dirname):
    filenames = os.listdir(dirname)
    filenames = [file for file in filenames if file.endswith("Hypnogram.edf")]
    return filenames

def search_signals_edf(dirname):
    filenames = os.listdir(dirname)
    filenames = [file for file in filenames if file.endswith("PSG.edf")]
    return filenames

def search_correct_annotations(dirname,filename):
    search_filename = filename.split('-')[0][:-2]
    file_list = os.listdir(dirname)
    filename = [file for file in file_list if search_filename in file if file.endswith("Hypnogram.edf")]
    
    return filename

def search_signals_npy(dirname):
    filenames = os.listdir(dirname)
    filenames = [file for file in filenames if file.endswith(".npy")]
    return filenames

def search_correct_annotations_npy(dirname,filename):
    search_filename = filename.split('-')[0][:-2]
    file_list = os.listdir(dirname)
    filename = [file for file in file_list if search_filename in file if file.endswith("npy")]
    
    return filename

def search_correct_signals_npy(dirname,filename):
    search_filename = filename.split('-')[0][:-2]
    file_list = os.listdir(dirname)
    filename = [file for file in file_list if search_filename in file if file.endswith("npy")]
    
    return filename

# %%
signals_path = 'signals/'
annotations_path = 'annotations/'
annotations_edf_list = search_annotations_edf(annotations_path)
signals_edf_list = search_signals_edf(signals_path)

print('signals edf file list')
print(signals_edf_list)

print('annotations edf file list')
print(annotations_edf_list)
# Out:
# signals edf file list
# ['SC4012E0-PSG.edf', 'SC4052E0-PSG.edf', 'SC4071E0-PSG.edf', 'SC4051E0-PSG.edf', 'SC4062E0-PSG.edf', 'SC4041E0-PSG.edf', 'SC4001E0-PSG.edf', 'SC4021E0-PSG.edf', 'SC4042E0-PSG.edf', 'SC4002E0-PSG.edf', 'SC4081E0-PSG.edf', 'SC4061E0-PSG.edf', 'SC4011E0-PSG.edf', 'SC4072E0-PSG.edf', 'SC4091E0-PSG.edf', 'SC4092E0-PSG.edf', 'SC4031E0-PSG.edf', 'SC4022E0-PSG.edf', 'SC4032E0-PSG.edf', 'SC4082E0-PSG.edf']
# annotations edf file list
# ['SC4082EP-Hypnogram.edf', 'SC4041EC-Hypnogram.edf', 'SC4072EH-Hypnogram.edf', 'SC4081EC-Hypnogram.edf', 'SC4001EC-Hypnogram.edf', 'SC4052EC-Hypnogram.edf', 'SC4091EC-Hypnogram.edf', 'SC4051EC-Hypnogram.edf', 'SC4022EJ-Hypnogram.edf', 'SC4062EC-Hypnogram.edf', 'SC4061EC-Hypnogram.edf', 'SC4012EC-Hypnogram.edf', 'SC4011EH-Hypnogram.edf', 'SC4002EC-Hypnogram.edf', 'SC4071EC-Hypnogram.edf', 'SC4032EP-Hypnogram.edf', 'SC4042EC-Hypnogram.edf', 'SC4031EC-Hypnogram.edf', 'SC4021EH-Hypnogram.edf']

# %%
epoch_size = 30
sample_rate = 100
save_signals_path = signals_path + 'npy/'
save_annotations_path = annotations_path+'npy/'

os.makedirs(save_annotations_path,exist_ok=True)
os.makedirs(save_signals_path,exist_ok=True)

for filename in signals_edf_list:
    signals_filename = filename
    annotations_filename = search_correct_annotations(annotations_path,filename)[0]
    
    print(signals_filename,annotations_filename)


    signals_filename = signals_path + signals_filename
    annotations_filename = annotations_path + annotations_filename
    
    _, _, annotations_header = highlevel.read_edf(annotations_filename)
    print(annotations_header)
    label = []
    for ann in annotations_header['annotations']:
        start = ann[0]

        length = ann[1]
        length = int(str(length)[2:-1]) // epoch_size # label은 30초 간격으로 사용할 것이기 때문에 30으로 나눈 값이 해당 sleep stage가 반복된 횟수이다.
        
        if ann[2] == 'Sleep stage W':
            for time in range(length):
                label.append(0)
        elif ann[2] == 'Sleep stage 1':
            for time in range(length):
                label.append(1)
        elif ann[2] == 'Sleep stage 2':
            for time in range(length):
                label.append(2)
        elif ann[2] == 'Sleep stage 3':
            for time in range(length):
                label.append(3)
        elif ann[2] == 'Sleep stage 4':
            for time in range(length):
                label.append(3)
        elif ann[2] == 'Sleep stage R':
            for time in range(length):
                label.append(4)
        else:
            for time in range(length):
                label.append(5)
    label = np.array(label)


    signals, _, signals_header = highlevel.read_edf(signals_filename)
    
    
    signals_len = len(signals[0]) // sample_rate // epoch_size
    annotations_len = len(label)
    if signals_header['startdate'] == annotations_header['startdate']:
        print("%s file's signal & annotations start time is same"%signals_filename.split('/')[-1])
        
        if signals_len > annotations_len :
            signals = signals[:3][:annotations_len]
        elif signals_len < annotations_len :
            signals = signals[:3]
            label = label[:signals_len]
        else:
            signals = signals[:3]
        signals = np.array(signals)
        
        np.save(save_signals_path + signals_filename.split('/')[-1].split('.')[0],signals)
        np.save(save_annotations_path + annotations_filename.split('/')[-1].split('.')[0],label)
        
        if (len(signals[0])//sample_rate//epoch_size != len(label)):
            print('signals len : %d / annotations len : %d'%(len(signals[0])//sample_rate//epoch_size,len(label)))
        
    else:
        print("%s file''s signal & annotations start time is different"%signals_filename.split('/')[-1])
# Out:
# Reading Channels: 0it [00:00, ?it/s]
# SC4012E0-PSG.edf SC4012EC-Hypnogram.edf
# {'technician': '', 'recording_additional': '', 'patientname': 'Female 33yr', 'patient_additional': '', 'patientcode': '', 'equipment': '', 'admincode': '', 'gender': 'Female', 'startdate': datetime.datetime(1989, 3, 30, 17, 0), 'birthdate': '', 'annotations': [[0.0, b'19290', 'Sleep stage W'], [19290.0, b'150', 'Sleep stage 1'], [19440.0, b'900', 'Sleep stage 2'], [20340.0, b'30', 'Sleep stage 1'], [20370.0, b'510', 'Sleep stage 2'], [20880.0, b'60', 'Sleep stage 3'], [20940.0, b'30', 'Sleep stage 2'], [20970.0, b'120', 'Sleep stage 4'], [21090.0, b'30', 'Sleep stage 3'], [21120.0, b'30', 'Sleep stage 4'], [21150.0, b'30', 'Sleep stage 3'], [21180.0, b'30', 'Sleep stage 4'], [21210.0, b'90', 'Sleep stage 3'], [21300.0, b'30', 'Sleep stage 4'], [21330.0, b'120', 'Sleep stage 3'], [21450.0, b'90', 'Sleep stage 4'], [21540.0, b'60', 'Sleep stage 3'], [21600.0, b'90', 'Sleep stage 2'], [21690.0, b'30', 'Sleep stage 1'], [21720.0, b'390', 'Sleep stage 2'], [22110.0, b'60', 'Sleep stage 3'], [22170.0, b'60', 'Sleep stage 2'], [22230.0, b'60', 'Sleep stage 3'], [22290.0, b'30', 'Sleep stage 2'], [22320.0, b'30', 'Sleep stage 3'], [22350.0, b'60', 'Sleep stage 2'], [22410.0, b'60', 'Sleep stage 3'], [22470.0, b'60', 'Sleep stage 2'], [22530.0, b'90', 'Sleep stage 3'], [22620.0, b'30', 'Sleep stage 4'], [22650.0, b'120', 'Sleep stage 3'], [22770.0, b'330', 'Sleep stage 2'], [23100.0, b'90', 'Sleep stage 3'], [23190.0, b'30', 'Sleep stage 2'], [23220.0, b'60', 'Sleep stage 3'], [23280.0, b'30', 'Sleep stage 2'], [23310.0, b'30', 'Sleep stage 4'], [23340.0, b'1020', 'Sleep stage 2'], [24360.0, b'30', 'Sleep stage W'], [24390.0, b'30', 'Sleep stage 1'], [24420.0, b'780', 'Sleep stage 2'], [25200.0, b'360', 'Sleep stage R'], [25560.0, b'150', 'Sleep stage 1'], [25710.0, b'180', 'Sleep stage 2'], [25890.0, b'30', 'Sleep stage R'], [25920.0, b'30', 'Sleep stage 2'], [25950.0, b'480', 'Sleep stage R'], [26430.0, b'30', 'Sleep stage 2'], [26460.0, b'30', 'Sleep stage R'], [26490.0, b'30', 'Sleep stage 2'], [26520.0, b'60', 'Sleep stage 1'], [26580.0, b'60', 'Sleep stage R'], [26640.0, b'180', 'Sleep stage 1'], [26820.0, b'420', 'Sleep stage 2'], [27240.0, b'30', 'Sleep stage 3'], [27270.0, b'390', 'Sleep stage 2'], [27660.0, b'30', 'Sleep stage 3'], [27690.0, b'60', 'Sleep stage 2'], [27750.0, b'30', 'Sleep stage 3'], [27780.0, b'60', 'Sleep stage 2'], [27840.0, b'30', 'Sleep stage 3'], [27870.0, b'30', 'Sleep stage 2'], [27900.0, b'180', 'Sleep stage 3'], [28080.0, b'30', 'Sleep stage 2'], [28110.0, b'90', 'Sleep stage 3'], [28200.0, b'30', 'Sleep stage 2'], [28230.0, b'60', 'Sleep stage 3'], [28290.0, b'180', 'Sleep stage 2'], [28470.0, b'30', 'Sleep stage 3'], [28500.0, b'30', 'Sleep stage 2'], [28530.0, b'330', 'Sleep stage 3'], [28860.0, b'30', 'Sleep stage 4'], [28890.0, b'240', 'Sleep stage 3'], [29130.0, b'90', 'Sleep stage 4'], [29220.0, b'30', 'Sleep stage 3'], [29250.0, b'90', 'Sleep stage W'], [29340.0, b'30', 'Sleep stage 1'], [29370.0, b'1020', 'Sleep stage 2'], [30390.0, b'30', 'Sleep stage 1'], [30420.0, b'870', 'Sleep stage 2'], [31290.0, b'30', 'Sleep stage 1'], [31320.0, b'720', 'Sleep stage 2'], [32040.0, b'90', 'Sleep stage R'], [32130.0, b'60', 'Sleep stage 1'], [32190.0, b'270', 'Sleep stage R'], [32460.0, b'60', 'Sleep stage 1'], [32520.0, b'30', 'Sleep stage W'], [32550.0, b'30', 'Sleep stage 1'], [32580.0, b'150', 'Sleep stage 2'], [32730.0, b'420', 'Sleep stage R'], [33150.0, b'150', 'Sleep stage 1'], [33300.0, b'150', 'Sleep stage 2'], [33450.0, b'420', 'Sleep stage R'], [33870.0, b'60', 'Sleep stage 1'], [33930.0, b'690', 'Sleep stage R'], [34620.0, b'30', 'Sleep stage 1'], [34650.0, b'120', 'Sleep stage R'], [34770.0, b'60', 'Sleep stage 1'], [34830.0, b'120', 'Sleep stage 2'], [34950.0, b'540', 'Sleep stage W'], [35490.0, b'150', 'Sleep stage 1'], [35640.0, b'540', 'Sleep stage 2'], [36180.0, b'30', 'Sleep stage 1'], [36210.0, b'960', 'Sleep stage 2'], [37170.0, b'30', 'Sleep stage 3'], [37200.0, b'60', 'Sleep st ...
# signals/npy/SC4012E0-PSG.edf
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-46-dd6e153d37a9> in <module>()
#      50
#      51     print(signals_filename)
# ---> 52     signals, info, signals_header = highlevel.read_edf(signals_filename)
#      53     print(info)
#      54     break
#
# /usr/local/lib/python3.6/dist-packages/pyedflib/highlevel.py in read_edf(edf_file, ch_nrs, ch_names, digital, verbose)
#     323         not isinstance(ch_names, list): ch_names = [ch_names]
#     324
# --> 325     with pyedflib.EdfReader(edf_file) as f:
#     326         # see which channels we want to load
#     327         available_chs = [ch.upper() for ch in f.getSignalLabels()]
#
# pyedflib/_extensions/_pyedflib.pyx in pyedflib._extensions._pyedflib.CyEdfReader.__init__()
#
# pyedflib/_extensions/_pyedflib.pyx in pyedflib._extensions._pyedflib.CyEdfReader.open()
#
# pyedflib/_extensions/_pyedflib.pyx in pyedflib._extensions._pyedflib.CyEdfReader.check_open_ok()
#
# OSError: can not open file, no such file or directory

# %%
# !ls annotations/npy/
# Out:
# SC4001EC-Hypnogram.npy	SC4041EC-Hypnogram.npy	SC4062EC-Hypnogram.npy
# SC4002EC-Hypnogram.npy	SC4042EC-Hypnogram.npy	SC4071EC-Hypnogram.npy
# SC4011EH-Hypnogram.npy	SC4051EC-Hypnogram.npy	SC4072EH-Hypnogram.npy
# SC4012EC-Hypnogram.npy	SC4052EC-Hypnogram.npy	SC4081EC-Hypnogram.npy
# SC4021EH-Hypnogram.npy	SC4061EC-Hypnogram.npy	SC4091EC-Hypnogram.npy

# %%
ls signals/npy/
# Out:
# SC4001E0-PSG.npy  SC4021E0-PSG.npy  SC4052E0-PSG.npy  SC4072E0-PSG.npy
# SC4002E0-PSG.npy  SC4041E0-PSG.npy  SC4061E0-PSG.npy  SC4081E0-PSG.npy
# SC4011E0-PSG.npy  SC4042E0-PSG.npy  SC4062E0-PSG.npy  SC4091E0-PSG.npy
# SC4012E0-PSG.npy  SC4051E0-PSG.npy  SC4071E0-PSG.npy

# %%
signals_path =  'signals/npy/'
signals_npy_list = search_signals_npy(signals_path)
print(signals_npy_list)
for filename in signals_npy_list:
  signals = signals_path + filename
  signals = np.load(signals)
  print(signals.shape)
  break
# Out:
# ['SC4062E0-PSG.npy', 'SC4011E0-PSG.npy', 'SC4052E0-PSG.npy', 'SC4041E0-PSG.npy', 'SC4081E0-PSG.npy', 'SC4002E0-PSG.npy', 'SC4051E0-PSG.npy', 'SC4021E0-PSG.npy', 'SC4071E0-PSG.npy', 'SC4061E0-PSG.npy', 'SC4072E0-PSG.npy', 'SC4091E0-PSG.npy', 'SC4012E0-PSG.npy', 'SC4001E0-PSG.npy', 'SC4042E0-PSG.npy']
# (3, 8490000)

# %%
signals_path =  'signals/npy/'

signals_npy_list = search_signals_npy(signals_path)

print(signals_npy_list)

channel_name_list = ['Fpz-Cz/','Pz-Oz/','EOG/']
for channel_index,channel_name in enumerate(channel_name_list):
    save_path = signals_path + channel_name
    os.makedirs(save_path,exist_ok=True)

    for filename in signals_npy_list:
        signals_filename = filename

        signals_filename = signals_path + signals_filename
        
        signals = np.load(signals_filename)
        
        signals = signals[channel_index].reshape(1,-1)
        print(signals.shape)
        
        np.save(save_path + filename,signals)
# Out:
# ['SC4062E0-PSG.npy', 'SC4011E0-PSG.npy', 'SC4052E0-PSG.npy', 'SC4041E0-PSG.npy', 'SC4081E0-PSG.npy', 'SC4002E0-PSG.npy', 'SC4051E0-PSG.npy', 'SC4021E0-PSG.npy', 'SC4071E0-PSG.npy', 'SC4061E0-PSG.npy', 'SC4072E0-PSG.npy', 'SC4091E0-PSG.npy', 'SC4012E0-PSG.npy', 'SC4001E0-PSG.npy', 'SC4042E0-PSG.npy']
# (1, 8490000)
# (1, 8406000)
# (1, 8418000)
# (1, 7710000)
# (1, 8388000)
# (1, 8490000)
# (1, 8166000)
# (1, 8412000)
# (1, 8430000)
# (1, 8310000)
# (1, 8310000)
# (1, 8196000)
# (1, 8550000)
# (1, 7950000)
# (1, 8376000)
# (1, 8490000)
# (1, 8406000)
# (1, 8418000)
# (1, 7710000)
# (1, 8388000)
# (1, 8490000)
# (1, 8166000)
# (1, 8412000)
# (1, 8430000)
# (1, 8310000)
# (1, 8310000)
# (1, 8196000)
# (1, 8550000)
# (1, 7950000)
# (1, 8376000)
# (1, 8490000)
# (1, 8406000)
# (1, 8418000)
# (1, 7710000)
# (1, 8388000)
# (1, 8490000)
# (1, 8166000)
# (1, 8412000)
# (1, 8430000)
# (1, 8310000)
# (1, 8310000)
# (1, 8196000)
# (1, 8550000)
# (1, 7950000)
# (1, 8376000)

# %%
epoch_size = 30
sample_rate = 100

path =  'signals/npy/Fpz-Cz/'
annotations_path = 'annotations/npy/'
signals_npy_list = search_signals_npy(path)

print(signals_npy_list)


for filename in signals_npy_list:
    signals_filename = path + filename
    annotations_filename = annotations_path+search_correct_annotations_npy(annotations_path,filename)[0]
    signals = np.load(signals_filename)
    label = np.load(annotations_filename)
    if len(signals[0])//sample_rate//epoch_size != len(label):
        print('%s is fault'%filename)
# Out:
# ['SC4062E0-PSG.npy', 'SC4011E0-PSG.npy', 'SC4052E0-PSG.npy', 'SC4041E0-PSG.npy', 'SC4081E0-PSG.npy', 'SC4002E0-PSG.npy', 'SC4051E0-PSG.npy', 'SC4021E0-PSG.npy', 'SC4071E0-PSG.npy', 'SC4061E0-PSG.npy', 'SC4072E0-PSG.npy', 'SC4091E0-PSG.npy', 'SC4012E0-PSG.npy', 'SC4001E0-PSG.npy', 'SC4042E0-PSG.npy']

# %%
fs = 100                                # Sampling rate (512 Hz)
epoch_size = 30
#data = np.random.uniform(0, 100, 1024)  # 2 sec of data b/w 0.0-100.0

path =  'annotations/npy/'
signals_path = 'signals/npy/Fpz-Cz/'

save_annotations_path = path + 'remove_wake/'
save_signals_path = signals_path + 'remove_wake/'

os.makedirs(save_annotations_path,exist_ok=True)
os.makedirs(save_signals_path,exist_ok=True)
annotations_npy_list = search_signals_npy(path)

check_index_size = 10

total_label = np.zeros([6],dtype=int)

for filename in annotations_npy_list:
    label = np.load(path + filename)
    signals_filename = search_correct_signals_npy(signals_path,filename)[0]
    
    signals = np.load(signals_path+signals_filename)
    
    for remove_start_index in range(0,len(label),1):
        #print(np.bincount(label[remove_start_index:(remove_start_index+check_index_size)],minlength=6)[0])
        if(np.bincount(label[remove_start_index:(remove_start_index+check_index_size)],minlength=6)[0] != check_index_size):
            break
            
    for remove_end_index in range(len(label),-1,-1,):
        #print(np.bincount(label[remove_end_index-check_index_size:(remove_end_index)],minlength=6)[0])
        if(np.bincount(label[remove_end_index-check_index_size:(remove_end_index)],minlength=6)[0] != check_index_size and np.bincount(label[remove_end_index-check_index_size:(remove_end_index)],minlength=6)[5] == 0 ):
            break
    
    #print('remove start index : %d / remove end index : %d'%(remove_start_index,remove_end_index))
    label = label[remove_start_index:remove_end_index+1]
    signals = signals[0,remove_start_index*fs*epoch_size:(remove_end_index+1)*fs*epoch_size].reshape(1,-1)
    #print(np.bincount(label,minlength=6))
    if len(label) ==len(signals[0])//30//fs:
        np.save(save_annotations_path+filename.split('.')[0],label)
        np.save(save_signals_path+signals_filename.split('.')[0],signals)
    for i in range(6):
        total_label[i] += np.bincount(label,minlength=6)[i]
    
    
print(total_label)
# Out:
# [1457 1279 6799 2378 2581   19]

# %%
fs = 100                                # Sampling rate (512 Hz)
epoch_size = 30
#data = np.random.uniform(0, 100, 1024)  # 2 sec of data b/w 0.0-100.0

path =  'annotations/npy/remove_wake/'
signals_path = 'signals/npy/Fpz-Cz/remove_wake/'

annotations_npy_list = search_signals_npy(path)

total_label = np.zeros([6],dtype=int)

for filename in annotations_npy_list:
    label = np.load(path + filename)
    signals_filename = search_correct_signals_npy(signals_path,filename)[0]
    
    signals = np.load(signals_path+signals_filename)
    
    
    #print('remove start index : %d / remove end index : %d'%(remove_start_index,remove_end_index))
    #print(np.bincount(label,minlength=6))
    if len(label) !=len(signals[0])//30//fs:
        print('file is fault!!!')
    for i in range(6):
        total_label[i] += np.bincount(label,minlength=6)[i]
        
print(total_label)

x = np.arange(len(total_label))

plt.bar(x,total_label,width=0.7)
# Out:
# [1457 1279 6799 2378 2581   19]
# <BarContainer object of 6 artists>

# %%
fs = 100                                # Sampling rate (512 Hz)
epoch_size = 30
#data = np.random.uniform(0, 100, 1024)  # 2 sec of data b/w 0.0-100.0

path =  'annotations/npy/remove_wake/'
signals_path = 'signals/npy/Fpz-Cz/remove_wake/'

annotations_npy_list = search_signals_npy(path)

print(annotations_npy_list)

random.shuffle(annotations_npy_list)

print(annotations_npy_list)

trainDataset_count = 12
testDataset_count = len(annotations_npy_list)-trainDataset_count

train_label = np.zeros([6],dtype=int)
test_label = np.zeros([6],dtype=int)

for filename in annotations_npy_list[:trainDataset_count]:
    label = np.load(path + filename)
    
    for i in range(6):
        train_label[i] += np.bincount(label,minlength=6)[i]

        
for filename in annotations_npy_list[trainDataset_count:]:
    label = np.load(path + filename)
    
    for i in range(6):
        test_label[i] += np.bincount(label,minlength=6)[i]
        
train_label = train_label / np.sum(train_label) * 100
test_label = test_label / np.sum(test_label) * 100
print(train_label)
print(test_label)
# Out:
# ['SC4072EH-Hypnogram.npy', 'SC4012EC-Hypnogram.npy', 'SC4071EC-Hypnogram.npy', 'SC4062EC-Hypnogram.npy', 'SC4042EC-Hypnogram.npy', 'SC4051EC-Hypnogram.npy', 'SC4091EC-Hypnogram.npy', 'SC4041EC-Hypnogram.npy', 'SC4021EH-Hypnogram.npy', 'SC4002EC-Hypnogram.npy', 'SC4061EC-Hypnogram.npy', 'SC4011EH-Hypnogram.npy', 'SC4052EC-Hypnogram.npy', 'SC4081EC-Hypnogram.npy', 'SC4001EC-Hypnogram.npy']
# ['SC4011EH-Hypnogram.npy', 'SC4002EC-Hypnogram.npy', 'SC4021EH-Hypnogram.npy', 'SC4091EC-Hypnogram.npy', 'SC4071EC-Hypnogram.npy', 'SC4001EC-Hypnogram.npy', 'SC4041EC-Hypnogram.npy', 'SC4072EH-Hypnogram.npy', 'SC4042EC-Hypnogram.npy', 'SC4051EC-Hypnogram.npy', 'SC4062EC-Hypnogram.npy', 'SC4061EC-Hypnogram.npy', 'SC4052EC-Hypnogram.npy', 'SC4081EC-Hypnogram.npy', 'SC4012EC-Hypnogram.npy']
# [ 9.3616643   8.93492176 46.7727596  16.1628734  18.61664296  0.15113798]
# [12.37366003  8.39203675 47.10566616 17.15160796 14.91577335  0.06125574]

# %%
signals_path = 'signals/npy/Fpz-Cz/remove_wake/'

save_train_path = 'signals/npy//Fpz-Cz/remove_wake/train/'
save_test_path = 'signals/npy/Fpz-Cz/remove_wake/test/'

os.makedirs(save_train_path,exist_ok=True)
os.makedirs(save_test_path,exist_ok=True)

for filename in annotations_npy_list[:trainDataset_count]:
    signals_filename = search_correct_signals_npy(signals_path,filename)[0]
    shutil.copy(signals_path+signals_filename,save_train_path+filename)
    

        
for filename in annotations_npy_list[trainDataset_count:]:
    signals_filename = search_correct_signals_npy(signals_path,filename)[0]
    shutil.copy(signals_path+signals_filename,save_test_path+filename)

# %%
train_path =  'signals/npy/Fpz-Cz/remove_wake/train/'
test_path = 'signals/npy/Fpz-Cz/remove_wake/test/'
annotations_path = 'annotations/npy/remove_wake/'

train_list = search_signals_npy(train_path)
test_list = search_signals_npy(test_path)

print(train_list)
print(test_list)

train_label = np.zeros([6],dtype=int)
test_label = np.zeros([6],dtype=int)

for filename in train_list:
    filename = search_correct_annotations_npy(annotations_path,filename)[0]
    label = np.load(annotations_path + filename)
    
    for i in range(6):
        train_label[i] += np.bincount(label,minlength=6)[i]

        
for filename in test_list:
    filename = search_correct_annotations_npy(annotations_path,filename)[0]
    label = np.load(annotations_path + filename)
    
    for i in range(6):
        test_label[i] += np.bincount(label,minlength=6)[i]
        
train_label = train_label / np.sum(train_label) * 100
test_label = test_label / np.sum(test_label) * 100
print(train_label)
print(test_label)
# Out:
# ['SC4072EH-Hypnogram.npy', 'SC4071EC-Hypnogram.npy', 'SC4062EC-Hypnogram.npy', 'SC4042EC-Hypnogram.npy', 'SC4051EC-Hypnogram.npy', 'SC4091EC-Hypnogram.npy', 'SC4041EC-Hypnogram.npy', 'SC4021EH-Hypnogram.npy', 'SC4002EC-Hypnogram.npy', 'SC4061EC-Hypnogram.npy', 'SC4011EH-Hypnogram.npy', 'SC4001EC-Hypnogram.npy']
# ['SC4012EC-Hypnogram.npy', 'SC4052EC-Hypnogram.npy', 'SC4081EC-Hypnogram.npy']
# [ 9.3616643   8.93492176 46.7727596  16.1628734  18.61664296  0.15113798]
# [12.37366003  8.39203675 47.10566616 17.15160796 14.91577335  0.06125574]

# %%
import numpy as np
import os
import time
import matplotlib.pylab as plt
from  torch.utils.data import Dataset
from torchvision import datasets, transforms
import sys
import random
import math
import warnings
import pandas as pd

from torch.utils.data import DataLoader
import torchvision.transforms as transforms
import torch
from torchsummary import summary
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
def data_preprocessing_torch(signals): # 하나의 데이터셋에 대한 data_preprocessing (using torch)
    signals = (signals - signals.mean(dim=1).unsqueeze(1))/signals.std(dim=1).unsqueeze(1)

    return signals

def data_preprocessing_oneToOne_torch(signals,min,max,max_value):
    signals_std = (signals + max_value) / (2*max_value)
    signals_scaled = signals_std * (max - min) + min
    return signals_scaled

def data_preprocessing_minmax_torch(signals,min,max):
    signals_std = (signals - signals.min(dim=1).unsqueeze(1)) / (
            signals.max(dim=1).unsqueeze(1) - signals.min(dim=1).unsqueeze(1))
    signals_scaled = signals_std * (max - min) + min
    return signals_scaled

def get_dataset_one_channel_norm_withoutCut(dirname,annotations_dir,data_path,use_noise=True,epsilon=0.5,noise_scale=2e-6,preprocessing=True,norm_methods='Standard'):
    # npy read!
    path = dirname + data_path
    signals = np.load(path)

    signals = torch.from_numpy(signals).float().to(device)

    if use_noise:
        if np.random.rand() < epsilon:
            # noise = np.random.normal(loc=0,scale=noise_scale,size=signals.shape)
            # signals = signals + noise
            noise = torch.normal(mean=0., std=noise_scale, size=signals.shape).to(device)
            signals = signals + noise

    if preprocessing:
        if norm_methods == 'Standard':
            signals = data_preprocessing_torch(signals)
        elif norm_methods == 'minmax':
            signals = data_preprocessing_minmax_torch(signals,0,1)
        elif norm_methods == 'oneToOne':
            signals = data_preprocessing_oneToOne_torch(signals,-1,1,1e-4)
    label = get_annotations(annotations_dir, data_path)
    return signals, label

# model conv layer weight init function
def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:         # Conv weight init
        torch.nn.init.xavier_uniform_(m.weight.data)
        
def suffle_dataset_list(dataset_list): # 데이터 셔플
    random.shuffle(dataset_list)
    return dataset_list


# npy파일을 통해 label을 가져오는 함수
def get_annotations(label_dir,file_name):
    label_path = label_dir + file_name
    label = np.load(label_path)
    return label

def signals_expand_torch_one_channel(signals): # 2차원 데이터를 3차원으로 변환 (8,N) -> (batch,8,6000) 형태로
    signals = signals.expand(1,1,-1)
    #print(signals.shape)
    signals = signals.transpose(2, 1) # 차원 변경
    signals = signals.reshape(-1, 3000, 1) # 형태 변환
    signals = signals.transpose(2, 1) # 차원 변경
    return signals

# %%
class DeepSleepNet_Classification(nn.Module):  # input channel = 8channel / output = 5
    def __init__(self,in_channel=1,out_channel=6,layer=[64,128,128,128],sample_rate = 100):
        super(DeepSleepNet_Classification, self).__init__()

        
        self.fc1 = nn.Linear(3000,512)
        self.fc2 = nn.Linear(512,512)
        self.fc3 = nn.Linear(512,512)
        self.fc4 = nn.Linear(512,out_channel)
        

    def forward(self, input):
        # print("feature_extract_2d.shape : ", feature_extract_2d.shape)
        # 여기서 문제 발생 weight의 경우에는 [64 , 32 , 100] 이지만 input 이 2차원 [32, 750]이라 문제 발생!
        out = torch.flatten(input, 1)
        out = self.fc1(out)
        out = self.fc2(out)
        out = self.fc3(out)
        out = self.fc4(out)

        return out

# %%
model = DeepSleepNet_Classification(in_channel=1,out_channel=6)
summary(model.cuda(),(1,3000))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                  [-1, 512]       1,536,512
#             Linear-2                  [-1, 512]         262,656
#             Linear-3                  [-1, 512]         262,656
#             Linear-4                    [-1, 6]           3,078
# ================================================================
# Total params: 2,064,902
# Trainable params: 2,064,902
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 0.01
# Params size (MB): 7.88
# Estimated Total Size (MB): 7.90
# ----------------------------------------------------------------

# %%
def search_npy_list(dirname):  # 매개변수 dir에서 모든 npy파일을 찾고 fold에 따른 dataset 나누기
    filenames = os.listdir(dirname)
    filenames = [file for _, file in enumerate(filenames) if file.endswith(".npy")]
    return filenames

# %%
def train_model_withNoise_norm(save_filename,logging_filename,train_signal_dir, test_signal_dir,annotations_dir
                               ,epochs=2000,learning_rate=0.001,step_size=100,gamma=0.5,channel=0,
                               layer_filters=[64,128,256,512],first_conv=[200,40,100],optim='Adam',lf='CE',
                               epsilon=0.7,noise_scale=2e-6,min_value=-1e-4,max_value=1e-4,preprocessing=True,
                               norm_methods='Standard',use_noise=True,loss_type='softmax'):
    # Adam optimizer param
    b1 = 0.5
    b2 = 0.999

    beta = 0.001

    check_file = open(logging_filename, 'w')  # logging file

    print('Preproceesing  : ',preprocessing)
    print('min/max value : %f/%f'%(min_value,max_value))
    print('noise scale : ',noise_scale)
    print('loss function : ',lf)
    print('epsilon : ',epsilon)
    print('norm methods : ',norm_methods)

    print('logging file name : ', logging_filename)
    print('save file name : ', save_filename)
    print('layer filters : ',layer_filters)
    print('fisrt_conv info : ',first_conv)
    print('loss type : ',loss_type)
    print('training data oversampling noise : ',use_noise)
    best_accuracy = 0.
    best_epoch = 0

    train_dataset_list = search_npy_list(train_signal_dir)
    test_dataset_list = search_npy_list(test_signal_dir)

    train_dataset_len = len(train_dataset_list)
    test_dataset_len = len(test_dataset_list)

    print('train_dataset length : ', len(train_dataset_list))
    print(train_dataset_list)

    print('test_dataset length : ',test_dataset_len)
    print(test_dataset_list)


    model = DeepSleepNet_Classification()

    #model = resnet18_200hz(in_channel=1,layer_filters=layer_filters,first_conv=first_conv,use_batchnorm=True,num_classes=5)

    model.apply(weights_init) # weight init

    cuda = torch.cuda.is_available()

    if cuda:
        print('can use CUDA!!!')
        model = model.cuda()
    #summary(model,[1,6000])
    print('torch.cuda.device_count() : ', torch.cuda.device_count())
    if torch.cuda.device_count() > 1:
        print('Multi GPU Activation !!!')
        #model = nn.DataParallel(model)

    # loss funcition
    if lf == 'CE':
        loss_fn = nn.CrossEntropyLoss().to(device)
    elif lf == 'CEW':
        samples_per_cls = [27,15,41,5,11]
        no_of_classes = 5
        effective_num = 1.0 - np.power(beta,samples_per_cls)
        #print(effective_num)
        weights = (1.0 - beta) / np.array(effective_num)
        #print(weights)
        weights = weights / np.sum(weights) * no_of_classes
        weights = torch.tensor(weights).float()
        weights = weights.to(device)
        loss_fn = nn.CrossEntropyLoss(weight=weights).to(device)
    elif lf == 'FL':
        loss_fn = FocalLoss(gamma=2).to(device)
    elif lf == 'CBL':
        loss_fn = CB_loss(samples_per_cls=[27,15,41,5,11],no_of_classes=5,loss_type=loss_type,beta=0.9999,gamma=2.0)
    #loss_fn = FocalLoss(gamma=2).to(device)

    # optimizer ADAM (SGD의 경우에는 정상적으로 학습이 진행되지 않았음)
    if optim == 'Adam':
        print('Optimizer : Adam')
        optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, betas=(b1, b2))
    elif optim == 'RMS':
        print('Optimizer : RMSprop')
        optimizer = torch.optim.RMSprop(model.parameters(), lr=learning_rate)
    elif optim == 'SGD':
        print('Optimizer : SGD')
        optimizer = torch.optim.SGD(model.parameters(),lr=learning_rate,momentum=0.9)

    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer=optimizer, mode='min', factor=gamma, patience=10,
                                                           min_lr=1e-6)
    #stride = 40 일 때, batch_size = 20이면 16GB정도의 메모리 사용
    batch_size = 5
    norm_square = 2

    train_batch_size = math.ceil(train_dataset_len / batch_size)
    print('train_batch_size : ',train_batch_size)

    test_batch_size = test_dataset_len

    best_accuracy = 0.
    stop_count = 0
    for epoch in range(epochs):
        train_dataset = suffle_dataset_list(train_dataset_list) # 매 epoch마다 train_dataset shuffle !
        count = 0  # check batch
        train_total_loss = 0.0
        train_total_count = 0
        train_total_data = 0

        val_total_loss = 0.0
        val_total_count = 0
        val_total_data = 0

        test_total_loss = 0.0
        test_total_count = 0
        test_total_data = 0

        start_time = time.time()
        model.train()

        output_str = 'current_lr : %f\n'%(optimizer.state_dict()['param_groups'][0]['lr'])
        sys.stdout.write(output_str)
        check_file.write(output_str)
        for index, file_name in enumerate(train_dataset):
            #print('index : ',index)
            if index % batch_size == 0:
                batch_signal, batch_label = get_dataset_one_channel_norm_withoutCut(train_signal_dir,annotations_dir,file_name,
                                                                         use_noise=use_noise,epsilon=epsilon,noise_scale=noise_scale,
                                                                         preprocessing=preprocessing,norm_methods=norm_methods)
            else:
                new_signal, new_label = get_dataset_one_channel_norm_withoutCut(train_signal_dir,annotations_dir,file_name,
                                                                         use_noise=use_noise,epsilon=epsilon,noise_scale=noise_scale,
                                                                         preprocessing=preprocessing,norm_methods=norm_methods)

                batch_signal = torch.cat((batch_signal, new_signal),dim=1)
                batch_label = np.concatenate((batch_label, new_label))
            count += 1
            if count == batch_size or index == len(train_dataset) - 1:  # batch 학습 시작!
                batch_signal = signals_expand_torch_one_channel(batch_signal)
                #batch_signal = signals_expand_torch_one_channel(batch_signal)
                # batch_signal = torch.from_numpy(batch_signal).float().to(device)
                batch_label = torch.from_numpy(batch_label).long().to(device)
                optimizer.zero_grad()
                # print(batch_signal.shape)
                # print(batch_signal)
                pred = model(batch_signal)
                norm = 0

                for parameter in model.parameters():
                    norm += torch.norm(parameter, p=norm_square)

                loss = loss_fn(pred, batch_label) + beta * norm
                #print('loss : ',loss.item())
                # loss = loss_fn(pred, batch_label)
                # acc
                _, predict = torch.max(pred, 1)
                check_count = (predict == batch_label).sum().item()

                train_total_loss += loss.item()

                train_total_count += check_count
                train_total_data += len(batch_signal)
                loss.backward()
                optimizer.step()

                del (batch_signal)
                del (batch_label)
                del (loss)
                del (pred)
                torch.cuda.empty_cache()
                count = 0

        train_total_loss /= train_batch_size
        train_accuracy = train_total_count / train_total_data * 100

        output_str = 'train dataset : %d/%d epochs spend time : %.4f sec / total_loss : %.4f correct : %d/%d -> %.4f%%\n' \
                     % (epoch + 1, epochs, time.time() - start_time, train_total_loss,
                        train_total_count, train_total_data, train_accuracy)
        sys.stdout.write(output_str)
        check_file.write(output_str)

    

        #check test dataset
        start_time = time.time()
        for file_name in test_dataset_list:
            batch_signal, batch_label = get_dataset_one_channel_norm_withoutCut(test_signal_dir,annotations_dir,file_name,
                                                                         use_noise=False,epsilon=epsilon,noise_scale=noise_scale,
                                                                         preprocessing=preprocessing,norm_methods=norm_methods)

            batch_signal = signals_expand_torch_one_channel(batch_signal)

            batch_label = torch.from_numpy(batch_label).long().to(device)

            with torch.no_grad():
                pred = model(batch_signal)

                loss = loss_fn(pred, batch_label)

                # acc
                _, predict = torch.max(pred, 1)
                check_count = (predict == batch_label).sum().item()

                test_total_loss += loss.item()
                test_total_count += check_count
                test_total_data += len(batch_signal)

                # 사용하지 않는 변수 제거
                del (batch_signal)
                del (batch_label)
                del (loss)
                del (pred)
                torch.cuda.empty_cache()
        test_total_loss /= test_batch_size
        test_accuracy = test_total_count / test_total_data * 100



        output_str = 'test dataset : %d/%d epochs spend time : %.4f sec  / total_loss : %.4f correct : %d/%d -> %.4f%%\n' \
                     % (epoch + 1, epochs, time.time() - start_time, test_total_loss,
                        test_total_count, test_total_data, test_accuracy)
        sys.stdout.write(output_str)
        check_file.write(output_str)

        scheduler.step(float(test_total_loss))
        #scheduler.step()

        if epoch == 0:
            best_accuracy = test_accuracy
            best_epoch = epoch
            save_file = save_filename
            #save_file = save_path + 'best_SleepEEGNet_CNN_channel%d.pth'%channel
            torch.save(model.state_dict(),save_file)
            stop_count = 0
        else:
            if best_accuracy < test_accuracy:
                best_accuracy = test_accuracy
                best_epoch = epoch
                save_file = save_filename
                torch.save(model.state_dict(), save_file)
                stop_count = 0
            else:
                stop_count += 1
        if stop_count > 30:
            print('Early Stopping')
            break

        output_str = 'best epoch : %d/%d / val accuracy : %f%%\n' \
                     % (best_epoch+1, epochs, best_accuracy)
        sys.stdout.write(output_str)
        print('=' * 30)


    output_str = 'best epoch : %d/%d / accuracy : %f%%\n' \
                 % (best_epoch+1, epochs, best_accuracy)
    sys.stdout.write(output_str)
    check_file.write(output_str)
    print('=' * 30)

    check_file.close()

# %%
save_filename = './train.pth'
logging_filename = './logging.txt'
train_signal_dir = 'signals/npy/Fpz-Cz/remove_wake/train/'
test_signal_dir = 'signals/npy/Fpz-Cz/remove_wake/test/'
annotations_dir = 'annotations/npy/remove_wake/'
train_model_withNoise_norm(save_filename,logging_filename,train_signal_dir, 
                           test_signal_dir,annotations_dir,
                           epochs=2000,learning_rate=0.001,step_size=100,gamma=0.5,channel=0,
                           layer_filters=[64,128,256,512],first_conv=[200,40,100],
                           optim='Adam',lf='CE',epsilon=0,noise_scale=0,
                           min_value=-0,max_value=0,preprocessing=True,
                           norm_methods='Standard',use_noise=False,loss_type='softmax')
# Out:
# Preproceesing  :  True
# min/max value : 0.000000/0.000000
# noise scale :  0
# loss function :  CE
# epsilon :  0
# norm methods :  Standard
# logging file name :  ./logging.txt
# save file name :  ./train.pth
# layer filters :  [64, 128, 256, 512]
# fisrt_conv info :  [200, 40, 100]
# loss type :  softmax
# training data oversampling noise :  False
# train_dataset length :  12
# ['SC4072EH-Hypnogram.npy', 'SC4071EC-Hypnogram.npy', 'SC4062EC-Hypnogram.npy', 'SC4042EC-Hypnogram.npy', 'SC4051EC-Hypnogram.npy', 'SC4091EC-Hypnogram.npy', 'SC4041EC-Hypnogram.npy', 'SC4021EH-Hypnogram.npy', 'SC4002EC-Hypnogram.npy', 'SC4061EC-Hypnogram.npy', 'SC4011EH-Hypnogram.npy', 'SC4001EC-Hypnogram.npy']
# test_dataset length :  3
# ['SC4012EC-Hypnogram.npy', 'SC4052EC-Hypnogram.npy', 'SC4081EC-Hypnogram.npy']
# can use CUDA!!!
# torch.cuda.device_count() :  1
# Optimizer : Adam
# train_batch_size :  3
# current_lr : 0.001000
# train dataset : 1/2000 epochs spend time : 0.6095 sec / total_loss : 1.7761 correct : 2821/11248 -> 25.0800%
# test dataset : 1/2000 epochs spend time : 0.0755 sec  / total_loss : 1.9306 correct : 1385/3265 -> 42.4196%
# best epoch : 1/2000 / val accuracy : 42.419602%
# ==============================
# current_lr : 0.001000
# train dataset : 2/2000 epochs spend time : 0.3197 sec / total_loss : 1.7173 correct : 4519/11248 -> 40.1760%
# test dataset : 2/2000 epochs spend time : 0.0772 sec  / total_loss : 1.5982 correct : 1362/3265 -> 41.7152%
# best epoch : 1/2000 / val accuracy : 42.419602%
# ==============================
# current_lr : 0.001000
# train dataset : 3/2000 epochs spend time : 0.3083 sec / total_loss : 1.5920 correct : 4863/11248 -> 43.2344%
# test dataset : 3/2000 epochs spend time : 0.0737 sec  / total_loss : 1.6136 correct : 1213/3265 -> 37.1516%
# best epoch : 1/2000 / val accuracy : 42.419602%
# ==============================
# current_lr : 0.001000
# train dataset : 4/2000 epochs spend time : 0.3118 sec / total_loss : 1.5440 correct : 4947/11248 -> 43.9812%
# test dataset : 4/2000 epochs spend time : 0.0724 sec  / total_loss : 1.5839 correct : 1388/3265 -> 42.5115%
# best epoch : 4/2000 / val accuracy : 42.511485%
# ==============================
# current_lr : 0.001000
# train dataset : 5/2000 epochs spend time : 0.3113 sec / total_loss : 1.5221 correct : 5115/11248 -> 45.4748%
# test dataset : 5/2000 epochs spend time : 0.0717 sec  / total_loss : 1.5612 correct : 1328/3265 -> 40.6738%
# best epoch : 4/2000 / val accuracy : 42.511485%
# ==============================
# current_lr : 0.001000
# train dataset : 6/2000 epochs spend time : 0.3064 sec / total_loss : 1.5065 correct : 5151/11248 -> 45.7948%
# test dataset : 6/2000 epochs spend time : 0.0761 sec  / total_loss : 1.5483 correct : 1382/3265 -> 42.3277%
# best epoch : 4/2000 / val accuracy : 42.511485%
# ==============================
# current_lr : 0.001000
# train dataset : 7/2000 epochs spend time : 0.3002 sec / total_loss : 1.4790 correct : 5298/11248 -> 47.1017%
# test dataset : 7/2000 epochs spend time : 0.0724 sec  / total_loss : 1.5730 correct : 1268/3265 -> 38.8361%
# best epoch : 4/2000 / val accuracy : 42.511485%
# ==============================
# current_lr : 0.001000
# train dataset : 8/2000 epochs spend time : 0.3075 sec / total_loss : 1.4761 correct : 5254/11248 -> 46.7105%
# test dataset : 8/2000 epochs spend time : 0.0708 sec  / total_loss : 1.6259 correct : 1089/3265 -> 33.3538%
# best epoch : 4/2000 / val accuracy : 42.511485%
# ==============================
# current_lr : 0.001000
# train dataset : 9/2000 epochs spend time : 0.3141 sec / total_loss : 1.5685 correct : 4864/11248 -> 43.2432%
# test dataset : 9/2000 epochs spend time : 0.0746 sec  / total_loss : 1.6955 correct : 1359/3265 -> 41.6233%
# best epoch : 4/2000 / val accuracy : 42.511485%
# ==============================
# current_lr : 0.001000
# train dataset : 10/2000 epochs spend time : 0.2962 sec / total_loss : 2.5165 correct : 3909/11248 -> 34.7528%
# test dataset : 10/2000 epochs spend time : 0.0739 sec  / total_loss : 2.9484 correct : 538/3265 -> 16.4778%
# best epoch : 4/2000 / val accuracy : 42.511485%
# ==============================
# current_lr : 0.001000
# train dataset : 11/2000 epochs spend time : 0.2961 sec / total_loss : 2.2957 correct : 3158/11248 -> 28.0761%
# test dataset : 11/2000 epochs spend time : 0.0684 sec  / total_loss : 1.8781 correct : 1090/3265 -> 33.3844%
# best epoch : 4/2000 / val accuracy : 42.511485%
# ==============================
# current_lr : 0.001000
# train dataset : 12/2000 epochs spend time : 0.2913 sec / total_loss : 1.7060 correct : 4770/11248 -> 42.4075%
# test dataset : 12/2000 epochs spend time : 0.0633 sec  / total_loss : 1.6296 correct : 1058/3265 -> 32.4043%
# best epoch : 4/2000 / val accuracy : 42.511485%
# ==============================
# current_lr : 0.001000
# train dataset : 13/2000 epochs spend time : 0.2830 sec / total_loss : 1.4650 correct : 5043/11248 -> 44.8346%
# test dataset : 13/2000 epochs spend time : 0.0663 sec  / total_loss : 1.5894 correct : 1319/3265 -> 40.3982%
# best epoch : 4/2000 / val accuracy : 42.511485%
# ==============================
# current_lr : 0.001000
# train dataset : 14/2000 epochs spend time : 0.2888 sec / total_loss : 1.4653 correct : 5241/11248 -> 46.5950%
# test dataset : 14/2000 epochs spend time : 0.0732 sec  / total_loss : 1.6147 correct : 1149/3265 -> 35.1914%
# best epoch : 4/2000 / val accuracy : 42.511485%
# ==============================
# current_lr : 0.001000
# train dataset : 15/2000 epochs spend time : 0.2985 sec / total_loss : 1.4116 correct : 5237/11248 -> 46.5594%
# test dataset : 15/2000 epochs spend time : 0.0665 sec  / total_loss : 1.5877 correct : 1347/3265 -> 41.2557%
# best epoch : 4/2000 / val accuracy : 42.511485%
# ==============================
# current_lr : 0.001000
# train dataset : 16/2000 epochs spend time : 0.2790 sec / total_loss : 1.4130 correct : 5388/11248 -> 47.9018%
# test dataset : 16/2000 epochs spend time : 0.0681 sec  / total_loss : 1.5990 correct : 1298/3265 -> 39.7550%
# best epoch : 4/2000 / val accuracy : 42.511485%
# ==============================
# current_lr : 0.001000
# train dataset : 17/2000 epochs spend time : 0.2890 sec / total_loss : 1.3965 correct : 5485/11248 -> 48.7642%
# test dataset : 17/2000 epochs spend time : 0.0696 sec  / total_loss : 1.6145 correct : 1139/3265 -> 34.8851%
# best epoch : 4/2000 / val accuracy : 42.511485%
# ==============================
# current_lr : 0.000500
# train dataset : 18/2000 epochs spend time : 0.2862 sec / total_loss : 1.3589 correct : 5523/11248 -> 49.1021%
# test dataset : 18/2000 epochs spend time : 0.0737 sec  / total_loss : 1.5960 correct : 1336/3265 -> 40.9188%
# best epoch : 4/2000 / val accuracy : 42.511485%
# ==============================
# current_lr : 0.000500
# train dataset : 19/2000 epochs spend time : 0.2954 sec / total_loss : 1.3655 correct : 5532/11248 -> 49.1821%
# test dataset : 19/2000 epochs spend time : 0.0666 sec  / total_loss : 1.5984 correct : 1255/3265 -> 38.4380%
# best epoch : 4/2000 / val accuracy : 42.511485%
# ==============================
# current_lr : 0.000500
# train dataset : 20/2000 epochs spend time : 0.2936 sec / total_loss : 1.3487 correct : 5650/11248 -> 50.2312%
# test dataset : 20/2000 epochs spend time : 0.0723 sec  / total_loss : 1.6096 correct : 1252/3265 -> 38.3461%
# best epoch : 4/2000 / val accuracy : 42.511485%
# ==============================
# current_lr : 0.000500
# train dataset : 21/2000 epochs spend time : 0.2863 sec / total_loss : 1.3138 correct : 5653/11248 -> 50.2578%
# test dataset : 21/2000 epochs spend time : 0.0686 sec  / total_loss : 1.6207 correct : 1338/3265 -> 40.9801%
# best epoch : 4/2000 / val accuracy : 42.511485%
# ==============================
# current_lr : 0.000500
# train dataset : 22/2000 epochs spend time : 0.2872 sec / total_loss : 1.3292 correct : 5620/11248 -> 49.9644%
# test dataset : 22/2000 epochs spend time : 0.0689 sec  / total_loss : 1.6215 correct : 1323/3265 -> 40.5207%
# best epoch : 4/2000 / val accuracy : 42.511485%
# ==============================
# current_lr : 0.000500
# train dataset : 23/2000 epochs spend time : 0.2831 sec / total_loss : 1.3303 correct : 5657/11248 -> 50.2934%
# test dataset : 23/2000 epochs spend time : 0.0719 sec  / total_loss : 1.6285 correct : 1187/3265 -> 36.3553%
# best epoch : 4/2000 / val accuracy : 42.511485%
# ==============================
# current_lr : 0.000500
# train dataset : 24/2000 epochs spend time : 0.2861 sec / total_loss : 1.3044 correct : 5748/11248 -> 51.1024%
# test dataset : 24/2000 epochs spend time : 0.0667 sec  / total_loss : 1.6425 correct : 1327/3265 -> 40.6432%
# best epoch : 4/2000 / val accuracy : 42.511485%
# ==============================
# current_lr : 0.000500
# train dataset : 25/2000 epochs spend time : 0.2859 sec / total_loss : 1.3244 correct : 5694/11248 -> 50.6223%
# test dataset : 25/2000 epochs spend time : 0.0687 sec  / total_loss : 1.6338 correct : 1272/3265 -> 38.9587%
# best epoch : 4/2000 / val accuracy : 42.511485%
# ==============================
# current_lr : 0.000500
# train dataset : 26/2000 epochs spend time : 0.2844 sec / total_loss : 1.3362 correct : 5732/11248 -> 50.9602%
# test dataset : 26/2000 epochs spend time : 0.0666 sec  / total_loss : 1.6974 correct : 1073/3265 -> 32.8637%
# best epoch : 4/2000 / val accuracy : 42.511485%
# ==============================
# current_lr : 0.000500
# train dataset : 27/2000 epochs spend time : 0.2925 sec / total_loss : 1.2986 correct : 5523/11248 -> 49.1021%
# test dataset : 27/2000 epochs spend time : 0.0636 sec  / total_loss : 1.6454 correct : 1356/3265 -> 41.5314%
# best epoch : 4/2000 / val accuracy : 42.511485%
# ==============================
# current_lr : 0.000500
# train dataset : 28/2000 epochs spend time : 0.2687 sec / total_loss : 1.2853 correct : 5775/11248 -> 51.3425%
# test dataset : 28/2000 epochs spend time : 0.0675 sec  / total_loss : 1.6320 correct : 1291/3265 -> 39.5406%
# best epoch : 4/2000 / val accuracy : 42.511485%
# ==============================
# current_lr : 0.000250
# train dataset : 29/2000 epochs spend time : 0.2888 sec / total_loss : 1.2594 correct : 5833/11248 -> 51.8581%
# test dataset : 29/2000 epochs spend time : 0.0734 sec  / total_loss : 1.6236 correct : 1311/3265 -> 40.1531%
# best epoch : 4/2000 / val accuracy : 42.511485%
# ==============================
# current_lr : 0.000250
# train dataset : 30/2000 epochs spend time : 0.2861 sec / total_loss : 1.2629 correct : 5922/11248 -> 52.6494%
# test dataset : 30/2000 epochs spend time : 0.0684 sec  / total_loss : 1.6253 correct : 1278/3265 -> 39.1424%
# best epoch : 4/2000 / val accuracy : 42.511485%
# ==============================
# current_lr : 0.000250
# train dataset : 31/2000 epochs spend time : 0.2858 sec / total_loss : 1.2412 correct : 5969/11248 -> 53.0672%
# test dataset : 31/2000 epochs spend time : 0.0664 sec  / total_loss : 1.6294 correct : 1274/3265 -> 39.0199%
# best epoch : 4/2000 / val accuracy : 42.511485%
# ==============================
# current_lr : 0.000250
# train dataset : 32/2000 epochs spend time : 0.2879 sec / total_loss : 1.2430 correct : 5955/11248 -> 52.9427%
# test dataset : 32/2000 epochs spend time : 0.0690 sec  / total_loss : 1.6451 correct : 1262/3265 -> 38.6524%
# best epoch : 4/2000 / val accuracy : 42.511485%
# ==============================
# current_lr : 0.000250
# train dataset : 33/2000 epochs spend time : 0.2905 sec / total_loss : 1.2626 correct : 5944/11248 -> 52.8450%
# test dataset : 33/2000 epochs spend time : 0.0687 sec  / total_loss : 1.6517 correct : 1254/3265 -> 38.4074%
# best epoch : 4/2000 / val accuracy : 42.511485%
# ==============================
# current_lr : 0.000250
# train dataset : 34/2000 epochs spend time : 0.2817 sec / total_loss : 1.2346 correct : 5948/11248 -> 52.8805%
# test dataset : 34/2000 epochs spend time : 0.0587 sec  / total_loss : 1.6560 correct : 1224/3265 -> 37.4885%
# best epoch : 4/2000 / val accuracy : 42.511485%
# ==============================
# current_lr : 0.000250
# train dataset : 35/2000 epochs spend time : 0.2820 sec / total_loss : 1.2359 correct : 5990/11248 -> 53.2539%
# test dataset : 35/2000 epochs spend time : 0.0672 sec  / total_loss : 1.6514 correct : 1274/3265 -> 39.0199%
# Early Stopping
# best epoch : 4/2000 / accuracy : 42.511485%
# ==============================
