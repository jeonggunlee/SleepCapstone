# %% [markdown]
# <a href="https://colab.research.google.com/github/jeonggunlee/SleepCapstone/blob/master/Codes/SleepNet_with_Convolution_3stage_Conv_multibranch_73.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 한림대학교 소프트웨어 융합대학
# 빅데이터 캡스톤 프로젝트
#
# 딥러닝에 기반한 수면 분류 모델 개발

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd drive/My\ Drive
# Out:
# /content/drive/My Drive

# %%
# GPU 가용성 체크
# !nvidia-smi
# Out:
# Wed Nov 25 08:02:53 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 455.38       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   49C    P8    10W /  70W |      0MiB / 15079MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import pandas as pd
import random
import shutil

def search_signals_npy(dirname):
    filenames = os.listdir(dirname)
    filenames = [file for file in filenames if file.endswith(".npy")]
    return filenames

def search_correct_signals_npy(dirname,filename):
    search_filename = filename.split('-')[0][:-2]
    file_list = os.listdir(dirname)
    filename = [file for file in file_list if search_filename in file if file.endswith("npy")]
    
    return filename

# %%
fs = 100                                # Sampling rate (512 Hz)
epoch_size = 30
#data = np.random.uniform(0, 100, 1024)  # 2 sec of data b/w 0.0-100.0

path =  'annotations/npy/remove_wake/'
signals_path = 'signals/npy/Fpz-Cz/remove_wake/'

annotations_npy_list = search_signals_npy(path)

total_label = np.zeros([6],dtype=int)

for filename in annotations_npy_list:
    label = np.load(path + filename)
    signals_filename = search_correct_signals_npy(signals_path,filename)[0]
    
    signals = np.load(signals_path+signals_filename)
    
    #print('remove start index : %d / remove end index : %d'%(remove_start_index,remove_end_index))
    #print(np.bincount(label,minlength=6))
    if len(label) !=len(signals[0])//30//fs:
        print('file is fault!!!')
    for i in range(6):
        total_label[i] += np.bincount(label,minlength=6)[i]
        
print(total_label)

x = np.arange(len(total_label))

plt.bar(x,total_label,width=0.7)
# Out:
# [ 4336  2804 17799  5703  7717    61]
# <BarContainer object of 6 artists>

# %%
fs = 100                                # Sampling rate (512 Hz)
epoch_size = 30
#data = np.random.uniform(0, 100, 1024)  # 2 sec of data b/w 0.0-100.0

path =  'annotations/npy/remove_wake/'
signals_path = 'signals/npy/Fpz-Cz/remove_wake/'

annotations_npy_list = search_signals_npy(path)

print(annotations_npy_list)

random.shuffle(annotations_npy_list)

print(annotations_npy_list)

trainDataset_count = 30
testDataset_count = len(annotations_npy_list)-trainDataset_count

train_label = np.zeros([6],dtype=int)
test_label = np.zeros([6],dtype=int)

for filename in annotations_npy_list[:trainDataset_count]:
    label = np.load(path + filename)
    
    for i in range(6):
        train_label[i] += np.bincount(label,minlength=6)[i]

        
for filename in annotations_npy_list[trainDataset_count:]:
    label = np.load(path + filename)
    
    for i in range(6):
        test_label[i] += np.bincount(label,minlength=6)[i]
        
train_label = train_label / np.sum(train_label) * 100
test_label = test_label / np.sum(test_label) * 100
print(train_label)
print(test_label)
# Out:
# ['SC4001EC-Hypnogram.npy', 'SC4002EC-Hypnogram.npy', 'SC4011EH-Hypnogram.npy', 'SC4012EC-Hypnogram.npy', 'SC4021EH-Hypnogram.npy', 'SC4022EJ-Hypnogram.npy', 'SC4031EC-Hypnogram.npy', 'SC4032EP-Hypnogram.npy', 'SC4041EC-Hypnogram.npy', 'SC4042EC-Hypnogram.npy', 'SC4051EC-Hypnogram.npy', 'SC4052EC-Hypnogram.npy', 'SC4061EC-Hypnogram.npy', 'SC4062EC-Hypnogram.npy', 'SC4071EC-Hypnogram.npy', 'SC4072EH-Hypnogram.npy', 'SC4081EC-Hypnogram.npy', 'SC4082EP-Hypnogram.npy', 'SC4091EC-Hypnogram.npy', 'SC4092EC-Hypnogram.npy', 'SC4101EC-Hypnogram.npy', 'SC4102EC-Hypnogram.npy', 'SC4111EC-Hypnogram.npy', 'SC4112EC-Hypnogram.npy', 'SC4121EC-Hypnogram.npy', 'SC4122EV-Hypnogram.npy', 'SC4131EC-Hypnogram.npy', 'SC4141EU-Hypnogram.npy', 'SC4142EU-Hypnogram.npy', 'SC4151EC-Hypnogram.npy', 'SC4152EC-Hypnogram.npy', 'SC4161EC-Hypnogram.npy', 'SC4162EC-Hypnogram.npy', 'SC4171EU-Hypnogram.npy', 'SC4172EC-Hypnogram.npy', 'SC4181EC-Hypnogram.npy', 'SC4182EC-Hypnogram.npy', 'SC4191EP-Hypnogram.npy', 'SC4192EV-Hypnogram.npy']
# ['SC4112EC-Hypnogram.npy', 'SC4192EV-Hypnogram.npy', 'SC4042EC-Hypnogram.npy', 'SC4162EC-Hypnogram.npy', 'SC4031EC-Hypnogram.npy', 'SC4051EC-Hypnogram.npy', 'SC4072EH-Hypnogram.npy', 'SC4122EV-Hypnogram.npy', 'SC4002EC-Hypnogram.npy', 'SC4022EJ-Hypnogram.npy', 'SC4032EP-Hypnogram.npy', 'SC4071EC-Hypnogram.npy', 'SC4001EC-Hypnogram.npy', 'SC4082EP-Hypnogram.npy', 'SC4101EC-Hypnogram.npy', 'SC4141EU-Hypnogram.npy', 'SC4021EH-Hypnogram.npy', 'SC4012EC-Hypnogram.npy', 'SC4041EC-Hypnogram.npy', 'SC4062EC-Hypnogram.npy', 'SC4121EC-Hypnogram.npy', 'SC4152EC-Hypnogram.npy', 'SC4092EC-Hypnogram.npy', 'SC4181EC-Hypnogram.npy', 'SC4052EC-Hypnogram.npy', 'SC4142EU-Hypnogram.npy', 'SC4161EC-Hypnogram.npy', 'SC4172EC-Hypnogram.npy', 'SC4151EC-Hypnogram.npy', 'SC4102EC-Hypnogram.npy', 'SC4182EC-Hypnogram.npy', 'SC4061EC-Hypnogram.npy', 'SC4111EC-Hypnogram.npy', 'SC4191EP-Hypnogram.npy', 'SC4011EH-Hypnogram.npy', 'SC4081EC-Hypnogram.npy', 'SC4171EU-Hypnogram.npy', 'SC4091EC-Hypnogram.npy', 'SC4131EC-Hypnogram.npy']
# [12.39769627  7.38270856 45.6603011  13.89309892 20.50452999  0.16166515]
# [ 7.50372322  7.01111238 48.59663192 18.07767213 18.66193149  0.14892886]

# %%
#
# 실행하지마...
#
#
#signals_path = 'signals/npy/Fpz-Cz/remove_wake/'
#
#save_train_path = 'signals/npy//Fpz-Cz/remove_wake/train/'
#save_test_path = 'signals/npy/Fpz-Cz/remove_wake/test/'
#
#os.makedirs(save_train_path,exist_ok=True)
#os.makedirs(save_test_path,exist_ok=True)
#
#for filename in annotations_npy_list[:trainDataset_count]:
#    signals_filename = search_correct_signals_npy(signals_path,filename)[0]
#    shutil.copy(signals_path+signals_filename,save_train_path+filename)
#    
#
#        
#for filename in annotations_npy_list[trainDataset_count:]:
#    signals_filename = search_correct_signals_npy(signals_path,filename)[0]
#    shutil.copy(signals_path+signals_filename,save_test_path+filename)

# %%
def search_correct_annotations_npy(dirname,filename):
    search_filename = filename.split('-')[0][:-2]
    file_list = os.listdir(dirname)
    filename = [file for file in file_list if search_filename in file if file.endswith("npy")]
    
    return filename

train_path =  'signals/npy/Fpz-Cz/remove_wake/train/'
test_path = 'signals/npy/Fpz-Cz/remove_wake/test/'
annotations_path = 'annotations/npy/remove_wake/'

train_list = search_signals_npy(train_path)
test_list = search_signals_npy(test_path)

print(train_list)
print(test_list)

train_label = np.zeros([6],dtype=int)
test_label = np.zeros([6],dtype=int)

for filename in train_list:
    filename = search_correct_annotations_npy(annotations_path,filename)[0]
    label = np.load(annotations_path + filename)
    
    for i in range(6):
        train_label[i] += np.bincount(label,minlength=6)[i]

        
for filename in test_list:
    filename = search_correct_annotations_npy(annotations_path,filename)[0]
    label = np.load(annotations_path + filename)
    
    for i in range(6):
        test_label[i] += np.bincount(label,minlength=6)[i]
        
train_label = train_label / np.sum(train_label) * 100
test_label = test_label / np.sum(test_label) * 100
print(train_label)
print(test_label)
# Out:
# ['SC4182EC-Hypnogram.npy', 'SC4141EU-Hypnogram.npy', 'SC4062EC-Hypnogram.npy', 'SC4112EC-Hypnogram.npy', 'SC4151EC-Hypnogram.npy', 'SC4002EC-Hypnogram.npy', 'SC4122EV-Hypnogram.npy', 'SC4081EC-Hypnogram.npy', 'SC4042EC-Hypnogram.npy', 'SC4012EC-Hypnogram.npy', 'SC4181EC-Hypnogram.npy', 'SC4172EC-Hypnogram.npy', 'SC4162EC-Hypnogram.npy', 'SC4061EC-Hypnogram.npy', 'SC4031EC-Hypnogram.npy', 'SC4101EC-Hypnogram.npy', 'SC4111EC-Hypnogram.npy', 'SC4022EJ-Hypnogram.npy', 'SC4171EU-Hypnogram.npy', 'SC4052EC-Hypnogram.npy', 'SC4001EC-Hypnogram.npy', 'SC4071EC-Hypnogram.npy', 'SC4121EC-Hypnogram.npy', 'SC4041EC-Hypnogram.npy', 'SC4032EP-Hypnogram.npy', 'SC4051EC-Hypnogram.npy', 'SC4092EC-Hypnogram.npy', 'SC4161EC-Hypnogram.npy', 'SC4102EC-Hypnogram.npy', 'SC4191EP-Hypnogram.npy']
# ['SC4192EV-Hypnogram.npy', 'SC4092EC-Hypnogram.npy', 'SC4072EH-Hypnogram.npy', 'SC4142EU-Hypnogram.npy', 'SC4091EC-Hypnogram.npy', 'SC4082EP-Hypnogram.npy', 'SC4131EC-Hypnogram.npy', 'SC4011EH-Hypnogram.npy', 'SC4021EH-Hypnogram.npy']
# [ 9.54537537  7.85925797 47.57010974 14.97648493 19.90942345  0.13934855]
# [10.1490889   6.42738818 46.5819989  14.72114854 21.81115406  0.30922142]

# %%
print(len(train_list))
print(len(test_list))
# Out:
# 30
# 9

# %%
import numpy as np
import os
import time
import matplotlib.pylab as plt
from  torch.utils.data import Dataset
from torchvision import datasets, transforms
import sys
import random
import math
import warnings
import pandas as pd

from torch.utils.data import DataLoader
import torchvision.transforms as transforms
import torch
from torchsummary import summary
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
def data_preprocessing_torch(signals): # 하나의 데이터셋에 대한 data_preprocessing (using torch)
    signals = (signals - signals.mean(dim=1).unsqueeze(1))/signals.std(dim=1).unsqueeze(1)

    return signals

def data_preprocessing_oneToOne_torch(signals,min,max,max_value):
    signals_std = (signals + max_value) / (2*max_value)
    signals_scaled = signals_std * (max - min) + min
    return signals_scaled

def data_preprocessing_minmax_torch(signals,min,max):
    signals_std = (signals - signals.min(dim=1).unsqueeze(1)) / (
            signals.max(dim=1).unsqueeze(1) - signals.min(dim=1).unsqueeze(1))
    signals_scaled = signals_std * (max - min) + min
    return signals_scaled

def get_dataset_one_channel_norm_withoutCut(dirname,annotations_dir,data_path,use_noise=True,epsilon=0.5,noise_scale=2e-6,preprocessing=True,norm_methods='Standard'):
    # npy read!
    path = dirname + data_path
    signals = np.load(path)

    signals = torch.from_numpy(signals).float().to(device)

    if use_noise:
        if np.random.rand() < epsilon:
            # noise = np.random.normal(loc=0,scale=noise_scale,size=signals.shape)
            # signals = signals + noise
            noise = torch.normal(mean=0., std=noise_scale, size=signals.shape).to(device)
            signals = signals + noise

    if preprocessing:
        if norm_methods == 'Standard':
            signals = data_preprocessing_torch(signals)
        elif norm_methods == 'minmax':
            signals = data_preprocessing_minmax_torch(signals,0,1)
        elif norm_methods == 'oneToOne':
            signals = data_preprocessing_oneToOne_torch(signals,-1,1,1e-4)
    label = get_annotations(annotations_dir, data_path)
    return signals, label

# model conv layer weight init function
def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:         # Conv weight init
        torch.nn.init.xavier_uniform_(m.weight.data)
        
def suffle_dataset_list(dataset_list): # 데이터 셔플
    random.shuffle(dataset_list)
    return dataset_list


# npy파일을 통해 label을 가져오는 함수
def get_annotations(label_dir,file_name):
    label_path = label_dir + file_name
    label = np.load(label_path)
    return label

def signals_expand_torch_one_channel(signals): # 2차원 데이터를 3차원으로 변환 (8,N) -> (batch,8,6000) 형태로
    signals = signals.expand(1,1,-1)
    #print(signals.shape)
    signals = signals.transpose(2, 1) # 차원 변경
    signals = signals.reshape(-1, 3000, 1) # 형태 변환
    signals = signals.transpose(2, 1) # 차원 변경
    return signals

# %%
class DeepSleepNet_Classification(nn.Module):  # input channel = 8channel / output = 5
    def __init__(self,in_channel=1,out_channel=6,layer=[64,128,128,128],sample_rate = 100):
        super(DeepSleepNet_Classification, self).__init__()

        self.conv1d_1a = nn.Conv1d(1,16, kernel_size=200, stride=20, padding=180)
        self.conv1d_2a = nn.Conv1d(16, 32, kernel_size=20, stride=2, padding=10)
        self.conv1d_3a = nn.Conv1d(32, 32, kernel_size=20, stride=2, padding=10)
        self.conv1d_4a = nn.Conv1d(32, 48, kernel_size=10, stride=2, padding=8)

        self.conv1d_1b = nn.Conv1d(1,16, kernel_size=100, stride=20, padding=90)
        self.conv1d_2b = nn.Conv1d(16, 32, kernel_size=20, stride=2, padding=10)
        self.conv1d_3b = nn.Conv1d(32, 32, kernel_size=20, stride=2, padding=10)
        self.conv1d_4b = nn.Conv1d(32, 48, kernel_size=10, stride=2, padding=8)

        self.conv1d_1c = nn.Conv1d(96, 96, kernel_size=10, stride=1)

        self.fc1 = nn.Linear(96*15,600)
        self.fc2 = nn.Linear(600,300)
        self.fc3 = nn.Linear(300,100)        
        self.fc4 = nn.Linear(100,out_channel) 

        self.ReLU = nn.ReLU()
        self.LeakyReLU = nn.LeakyReLU()
        self.dropout = nn.Dropout(p=0.3)

    def forward(self, input):
        outa = self.conv1d_1a(input)
        outa = self.LeakyReLU(outa)
        outa = self.conv1d_2a(outa)
        outa = self.LeakyReLU(outa)
        outa = self.dropout(outa)
        outa = self.conv1d_3a(outa)
        outa = self.LeakyReLU(outa)
        outa = self.dropout(outa)
        outa = self.conv1d_4a(outa)
        outa = self.LeakyReLU(outa)     
        outa = self.dropout(outa)

        outb = self.conv1d_1b(input)
        outb = self.LeakyReLU(outb)
        outb = self.conv1d_2b(outb)
        outb = self.LeakyReLU(outb)
        outb = self.dropout(outb)
        outb = self.conv1d_3b(outb)
        outb = self.LeakyReLU(outb)
        outb = self.dropout(outb)
        outb = self.conv1d_4b(outb)
        outb = self.LeakyReLU(outb)     
        outb = self.dropout(outb)

        out = torch.cat([outa, outb], dim=1)

        out = self.conv1d_1c(out)
        out = self.LeakyReLU(out)     
        out = self.dropout(out)

        out = torch.flatten(out, 1)
        out = self.fc1(out)
        out = self.LeakyReLU(out)
        out = self.fc2(out)
        out = self.LeakyReLU(out)
        out = self.dropout(out)
        out = self.fc3(out)
        out = self.LeakyReLU(out)
        out = self.dropout(out)        
        out = self.fc4(out)

        return out

# %%
model = DeepSleepNet_Classification(in_channel=1,out_channel=6)
summary(model.cuda(),(1,3000))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv1d-1              [-1, 16, 159]           3,216
#          LeakyReLU-2              [-1, 16, 159]               0
#             Conv1d-3               [-1, 32, 80]          10,272
#          LeakyReLU-4               [-1, 32, 80]               0
#            Dropout-5               [-1, 32, 80]               0
#             Conv1d-6               [-1, 32, 41]          20,512
#          LeakyReLU-7               [-1, 32, 41]               0
#            Dropout-8               [-1, 32, 41]               0
#             Conv1d-9               [-1, 48, 24]          15,408
#         LeakyReLU-10               [-1, 48, 24]               0
#           Dropout-11               [-1, 48, 24]               0
#            Conv1d-12              [-1, 16, 155]           1,616
#         LeakyReLU-13              [-1, 16, 155]               0
#            Conv1d-14               [-1, 32, 78]          10,272
#         LeakyReLU-15               [-1, 32, 78]               0
#           Dropout-16               [-1, 32, 78]               0
#            Conv1d-17               [-1, 32, 40]          20,512
#         LeakyReLU-18               [-1, 32, 40]               0
#           Dropout-19               [-1, 32, 40]               0
#            Conv1d-20               [-1, 48, 24]          15,408
#         LeakyReLU-21               [-1, 48, 24]               0
#           Dropout-22               [-1, 48, 24]               0
#            Conv1d-23               [-1, 96, 15]          92,256
#         LeakyReLU-24               [-1, 96, 15]               0
#           Dropout-25               [-1, 96, 15]               0
#            Linear-26                  [-1, 600]         864,600
#         LeakyReLU-27                  [-1, 600]               0
#            Linear-28                  [-1, 300]         180,300
#         LeakyReLU-29                  [-1, 300]               0
#           Dropout-30                  [-1, 300]               0
#            Linear-31                  [-1, 100]          30,100
#         LeakyReLU-32                  [-1, 100]               0
#           Dropout-33                  [-1, 100]               0
#            Linear-34                    [-1, 6]             606
# ================================================================
# Total params: 1,265,078
# Trainable params: 1,265,078
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 0.36
# Params size (MB): 4.83
# Estimated Total Size (MB): 5.19
# ----------------------------------------------------------------

# %%
def search_npy_list(dirname):  # 매개변수 dir에서 모든 npy파일을 찾고 fold에 따른 dataset 나누기
    filenames = os.listdir(dirname)
    filenames = [file for _, file in enumerate(filenames) if file.endswith(".npy")]
    return filenames

# %%
def train_model_withNoise_norm(save_filename,logging_filename,train_signal_dir, test_signal_dir,annotations_dir
                               ,epochs=2000,learning_rate=0.001,step_size=100,gamma=0.5,channel=0,
                               layer_filters=[64,128,256,512],first_conv=[200,40,100],optim='Adam',lf='CE',
                               epsilon=0.7,noise_scale=2e-6,min_value=-1e-4,max_value=1e-4,preprocessing=True,
                               norm_methods='Standard',use_noise=True,loss_type='softmax'):
    # Adam optimizer param
    b1 = 0.5
    b2 = 0.999

    beta = 0.001

    check_file = open(logging_filename, 'w')  # logging file

    print('Preproceesing  : ',preprocessing)
    print('min/max value : %f/%f'%(min_value,max_value))
    print('noise scale : ',noise_scale)
    print('loss function : ',lf)
    print('epsilon : ',epsilon)
    print('norm methods : ',norm_methods)

    print('logging file name : ', logging_filename)
    print('save file name : ', save_filename)
    print('layer filters : ',layer_filters)
    print('fisrt_conv info : ',first_conv)
    print('loss type : ',loss_type)
    print('training data oversampling noise : ',use_noise)
    best_accuracy = 0.
    best_epoch = 0

    train_dataset_list = search_npy_list(train_signal_dir)
    test_dataset_list = search_npy_list(test_signal_dir)

    train_dataset_len = len(train_dataset_list)
    test_dataset_len = len(test_dataset_list)

    print('train_dataset length : ', len(train_dataset_list))
    print(train_dataset_list)

    print('test_dataset length : ',test_dataset_len)
    print(test_dataset_list)


    model = DeepSleepNet_Classification()

    #model = resnet18_200hz(in_channel=1,layer_filters=layer_filters,first_conv=first_conv,use_batchnorm=True,num_classes=5)

    model.apply(weights_init) # weight init

    cuda = torch.cuda.is_available()

    if cuda:
        print('can use CUDA!!!')
        model = model.cuda()
    #summary(model,[1,6000])
    print('torch.cuda.device_count() : ', torch.cuda.device_count())
    if torch.cuda.device_count() > 1:
        print('Multi GPU Activation !!!')
        #model = nn.DataParallel(model)

    # loss funcition
    if lf == 'CE':
        loss_fn = nn.CrossEntropyLoss().to(device)
    elif lf == 'CEW':
        samples_per_cls = [27,15,41,5,11]
        no_of_classes = 5
        effective_num = 1.0 - np.power(beta,samples_per_cls)
        #print(effective_num)
        weights = (1.0 - beta) / np.array(effective_num)
        #print(weights)
        weights = weights / np.sum(weights) * no_of_classes
        weights = torch.tensor(weights).float()
        weights = weights.to(device)
        loss_fn = nn.CrossEntropyLoss(weight=weights).to(device)
    elif lf == 'FL':
        loss_fn = FocalLoss(gamma=2).to(device)
    elif lf == 'CBL':
        loss_fn = CB_loss(samples_per_cls=[27,15,41,5,11],no_of_classes=5,loss_type=loss_type,beta=0.9999,gamma=2.0)
    #loss_fn = FocalLoss(gamma=2).to(device)

    # optimizer ADAM (SGD의 경우에는 정상적으로 학습이 진행되지 않았음)
    if optim == 'Adam':
        print('Optimizer : Adam')
        optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, betas=(b1, b2))
    elif optim == 'RMS':
        print('Optimizer : RMSprop')
        optimizer = torch.optim.RMSprop(model.parameters(), lr=learning_rate)
    elif optim == 'SGD':
        print('Optimizer : SGD')
        optimizer = torch.optim.SGD(model.parameters(),lr=learning_rate,momentum=0.9)

    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer=optimizer, mode='min', factor=gamma, patience=10,
                                                           min_lr=1e-6)
    #stride = 40 일 때, batch_size = 20이면 16GB정도의 메모리 사용
    batch_size = 10
    norm_square = 2

    train_batch_size = math.ceil(train_dataset_len / batch_size)
    print('train_batch_size : ',train_batch_size)

    test_batch_size = test_dataset_len

    best_accuracy = 0.
    stop_count = 0
    for epoch in range(epochs):
        train_dataset = suffle_dataset_list(train_dataset_list) # 매 epoch마다 train_dataset shuffle !
        count = 0  # check batch
        train_total_loss = 0.0
        train_total_count = 0
        train_total_data = 0

        val_total_loss = 0.0
        val_total_count = 0
        val_total_data = 0

        test_total_loss = 0.0
        test_total_count = 0
        test_total_data = 0

        start_time = time.time()
        model.train()

        output_str = 'current_lr : %f\n'%(optimizer.state_dict()['param_groups'][0]['lr'])
        sys.stdout.write(output_str)
        check_file.write(output_str)
        for index, file_name in enumerate(train_dataset):
            #print('index : ',index)
            if index % batch_size == 0:
                batch_signal, batch_label = get_dataset_one_channel_norm_withoutCut(train_signal_dir,annotations_dir,file_name,
                                                                         use_noise=use_noise,epsilon=epsilon,noise_scale=noise_scale,
                                                                         preprocessing=preprocessing,norm_methods=norm_methods)
            else:
                new_signal, new_label = get_dataset_one_channel_norm_withoutCut(train_signal_dir,annotations_dir,file_name,
                                                                         use_noise=use_noise,epsilon=epsilon,noise_scale=noise_scale,
                                                                         preprocessing=preprocessing,norm_methods=norm_methods)

                batch_signal = torch.cat((batch_signal, new_signal),dim=1)
                batch_label = np.concatenate((batch_label, new_label))
            count += 1
            if count == batch_size or index == len(train_dataset) - 1:  # batch 학습 시작!
                batch_signal = signals_expand_torch_one_channel(batch_signal)
                #batch_signal = signals_expand_torch_one_channel(batch_signal)
                # batch_signal = torch.from_numpy(batch_signal).float().to(device)
                batch_label = torch.from_numpy(batch_label).long().to(device)
                optimizer.zero_grad()
                # print(batch_signal.shape)
                # print(batch_signal)
                pred = model(batch_signal)
                norm = 0

                for parameter in model.parameters():
                    norm += torch.norm(parameter, p=norm_square)

                loss = loss_fn(pred, batch_label) + beta * norm
                #print('loss : ',loss.item())
                # loss = loss_fn(pred, batch_label)
                # acc
                _, predict = torch.max(pred, 1)
                check_count = (predict == batch_label).sum().item()

                train_total_loss += loss.item()

                train_total_count += check_count
                train_total_data += len(batch_signal)
                loss.backward()
                optimizer.step()

                del (batch_signal)
                del (batch_label)
                del (loss)
                del (pred)
                torch.cuda.empty_cache()
                count = 0

        train_total_loss /= train_batch_size
        train_accuracy = train_total_count / train_total_data * 100

        output_str = 'train dataset : %d/%d epochs spend time : %.4f sec / total_loss : %.4f correct : %d/%d -> %.4f%%\n' \
                     % (epoch + 1, epochs, time.time() - start_time, train_total_loss,
                        train_total_count, train_total_data, train_accuracy)
        sys.stdout.write(output_str)
        check_file.write(output_str)

    

        #check test dataset
        start_time = time.time()
        for file_name in test_dataset_list:
            batch_signal, batch_label = get_dataset_one_channel_norm_withoutCut(test_signal_dir,annotations_dir,file_name,
                                                                         use_noise=False,epsilon=epsilon,noise_scale=noise_scale,
                                                                         preprocessing=preprocessing,norm_methods=norm_methods)

            batch_signal = signals_expand_torch_one_channel(batch_signal)

            batch_label = torch.from_numpy(batch_label).long().to(device)

            with torch.no_grad():
                model.eval()
                pred = model(batch_signal)

                loss = loss_fn(pred, batch_label)

                # acc
                _, predict = torch.max(pred, 1)
                check_count = (predict == batch_label).sum().item()

                test_total_loss += loss.item()
                test_total_count += check_count
                test_total_data += len(batch_signal)

                # 사용하지 않는 변수 제거
                del (batch_signal)
                del (batch_label)
                del (loss)
                del (pred)
                torch.cuda.empty_cache()
        test_total_loss /= test_batch_size
        test_accuracy = test_total_count / test_total_data * 100



        output_str = 'test dataset : %d/%d epochs spend time : %.4f sec  / total_loss : %.4f correct : %d/%d -> %.4f%%\n' \
                     % (epoch + 1, epochs, time.time() - start_time, test_total_loss,
                        test_total_count, test_total_data, test_accuracy)
        sys.stdout.write(output_str)
        check_file.write(output_str)

        scheduler.step(float(test_total_loss))
        #scheduler.step()

        if epoch == 0:
            best_accuracy = test_accuracy
            best_epoch = epoch
            save_file = save_filename
            #save_file = save_path + 'best_SleepEEGNet_CNN_channel%d.pth'%channel
            torch.save(model.state_dict(),save_file)
            stop_count = 0
        else:
            if best_accuracy < test_accuracy:
                best_accuracy = test_accuracy
                best_epoch = epoch
                save_file = save_filename
                torch.save(model.state_dict(), save_file)
                stop_count = 0
            else:
                stop_count += 1
        if stop_count > 30:
            print('Early Stopping')
            break

        output_str = 'best epoch : %d/%d / val accuracy : %f%%\n' \
                     % (best_epoch+1, epochs, best_accuracy)
        sys.stdout.write(output_str)
        print('=' * 30)


    output_str = 'best epoch : %d/%d / accuracy : %f%%\n' \
                 % (best_epoch+1, epochs, best_accuracy)
    sys.stdout.write(output_str)
    check_file.write(output_str)
    print('=' * 30)

    check_file.close()

# %%
save_filename = './train.pth'
logging_filename = './logging.txt'
train_signal_dir = 'signals/npy/Fpz-Cz/remove_wake/train/'
test_signal_dir = 'signals/npy/Fpz-Cz/remove_wake/test/'
annotations_dir = 'annotations/npy/remove_wake/'
train_model_withNoise_norm(save_filename,logging_filename,train_signal_dir, 
                           test_signal_dir,annotations_dir,
                           epochs=2000,learning_rate=0.0001,step_size=100,gamma=0.5,channel=0,
                           layer_filters=[64,128,256,512],first_conv=[200,40,100],
                           optim='Adam',lf='CE',epsilon=0,noise_scale=0,  # RMS, Adam, SGD
                           min_value=-0,max_value=0,preprocessing=True,
                           norm_methods='Standard',use_noise=False,loss_type='softmax')
# Out:
# Preproceesing  :  True
# min/max value : 0.000000/0.000000
# noise scale :  0
# loss function :  CE
# epsilon :  0
# norm methods :  Standard
# logging file name :  ./logging.txt
# save file name :  ./train.pth
# layer filters :  [64, 128, 256, 512]
# fisrt_conv info :  [200, 40, 100]
# loss type :  softmax
# training data oversampling noise :  False
# train_dataset length :  30
# ['SC4182EC-Hypnogram.npy', 'SC4141EU-Hypnogram.npy', 'SC4062EC-Hypnogram.npy', 'SC4112EC-Hypnogram.npy', 'SC4151EC-Hypnogram.npy', 'SC4002EC-Hypnogram.npy', 'SC4122EV-Hypnogram.npy', 'SC4081EC-Hypnogram.npy', 'SC4042EC-Hypnogram.npy', 'SC4012EC-Hypnogram.npy', 'SC4181EC-Hypnogram.npy', 'SC4172EC-Hypnogram.npy', 'SC4162EC-Hypnogram.npy', 'SC4061EC-Hypnogram.npy', 'SC4031EC-Hypnogram.npy', 'SC4101EC-Hypnogram.npy', 'SC4111EC-Hypnogram.npy', 'SC4022EJ-Hypnogram.npy', 'SC4171EU-Hypnogram.npy', 'SC4052EC-Hypnogram.npy', 'SC4001EC-Hypnogram.npy', 'SC4071EC-Hypnogram.npy', 'SC4121EC-Hypnogram.npy', 'SC4041EC-Hypnogram.npy', 'SC4032EP-Hypnogram.npy', 'SC4051EC-Hypnogram.npy', 'SC4092EC-Hypnogram.npy', 'SC4161EC-Hypnogram.npy', 'SC4102EC-Hypnogram.npy', 'SC4191EP-Hypnogram.npy']
# test_dataset length :  9
# ['SC4192EV-Hypnogram.npy', 'SC4092EC-Hypnogram.npy', 'SC4072EH-Hypnogram.npy', 'SC4142EU-Hypnogram.npy', 'SC4091EC-Hypnogram.npy', 'SC4082EP-Hypnogram.npy', 'SC4131EC-Hypnogram.npy', 'SC4011EH-Hypnogram.npy', 'SC4021EH-Hypnogram.npy']
# can use CUDA!!!
# torch.cuda.device_count() :  1
# Optimizer : Adam
# train_batch_size :  3
# current_lr : 0.000100
# train dataset : 1/2000 epochs spend time : 19.9855 sec / total_loss : 1.8615 correct : 4948/28705 -> 17.2374%
# test dataset : 1/2000 epochs spend time : 4.3905 sec  / total_loss : 1.7805 correct : 4129/9055 -> 45.5991%
# best epoch : 1/2000 / val accuracy : 45.599117%
# ==============================
# current_lr : 0.000100
# train dataset : 2/2000 epochs spend time : 3.5571 sec / total_loss : 1.8475 correct : 12187/28705 -> 42.4560%
# test dataset : 2/2000 epochs spend time : 0.3915 sec  / total_loss : 1.7625 correct : 4218/9055 -> 46.5820%
# best epoch : 2/2000 / val accuracy : 46.581999%
# ==============================
# current_lr : 0.000100
# train dataset : 3/2000 epochs spend time : 3.4727 sec / total_loss : 1.8161 correct : 13619/28705 -> 47.4447%
# test dataset : 3/2000 epochs spend time : 0.3627 sec  / total_loss : 1.7144 correct : 4218/9055 -> 46.5820%
# best epoch : 2/2000 / val accuracy : 46.581999%
# ==============================
# current_lr : 0.000100
# train dataset : 4/2000 epochs spend time : 3.4736 sec / total_loss : 1.7336 correct : 13544/28705 -> 47.1834%
# test dataset : 4/2000 epochs spend time : 0.3845 sec  / total_loss : 1.5876 correct : 4218/9055 -> 46.5820%
# best epoch : 2/2000 / val accuracy : 46.581999%
# ==============================
# current_lr : 0.000100
# train dataset : 5/2000 epochs spend time : 3.4675 sec / total_loss : 1.6066 correct : 13503/28705 -> 47.0406%
# test dataset : 5/2000 epochs spend time : 0.3604 sec  / total_loss : 1.4938 correct : 4218/9055 -> 46.5820%
# best epoch : 2/2000 / val accuracy : 46.581999%
# ==============================
# current_lr : 0.000100
# train dataset : 6/2000 epochs spend time : 3.4532 sec / total_loss : 1.5677 correct : 13258/28705 -> 46.1871%
# test dataset : 6/2000 epochs spend time : 0.3618 sec  / total_loss : 1.4843 correct : 4218/9055 -> 46.5820%
# best epoch : 2/2000 / val accuracy : 46.581999%
# ==============================
# current_lr : 0.000100
# train dataset : 7/2000 epochs spend time : 3.4441 sec / total_loss : 1.5585 correct : 13245/28705 -> 46.1418%
# test dataset : 7/2000 epochs spend time : 0.3563 sec  / total_loss : 1.4651 correct : 4218/9055 -> 46.5820%
# best epoch : 2/2000 / val accuracy : 46.581999%
# ==============================
# current_lr : 0.000100
# train dataset : 8/2000 epochs spend time : 3.4465 sec / total_loss : 1.5485 correct : 13121/28705 -> 45.7098%
# test dataset : 8/2000 epochs spend time : 0.3877 sec  / total_loss : 1.4578 correct : 4218/9055 -> 46.5820%
# best epoch : 2/2000 / val accuracy : 46.581999%
# ==============================
# current_lr : 0.000100
# train dataset : 9/2000 epochs spend time : 3.4747 sec / total_loss : 1.5378 correct : 13137/28705 -> 45.7655%
# test dataset : 9/2000 epochs spend time : 0.3600 sec  / total_loss : 1.4569 correct : 4218/9055 -> 46.5820%
# best epoch : 2/2000 / val accuracy : 46.581999%
# ==============================
# current_lr : 0.000100
# train dataset : 10/2000 epochs spend time : 3.4645 sec / total_loss : 1.5355 correct : 13227/28705 -> 46.0791%
# test dataset : 10/2000 epochs spend time : 0.3653 sec  / total_loss : 1.4476 correct : 4218/9055 -> 46.5820%
# best epoch : 2/2000 / val accuracy : 46.581999%
# ==============================
# current_lr : 0.000100
# train dataset : 11/2000 epochs spend time : 3.4710 sec / total_loss : 1.5367 correct : 13147/28705 -> 45.8004%
# test dataset : 11/2000 epochs spend time : 0.3692 sec  / total_loss : 1.4520 correct : 4218/9055 -> 46.5820%
# best epoch : 2/2000 / val accuracy : 46.581999%
# ==============================
# current_lr : 0.000100
# train dataset : 12/2000 epochs spend time : 3.4785 sec / total_loss : 1.5291 correct : 13007/28705 -> 45.3127%
# test dataset : 12/2000 epochs spend time : 0.3695 sec  / total_loss : 1.4336 correct : 4218/9055 -> 46.5820%
# best epoch : 2/2000 / val accuracy : 46.581999%
# ==============================
# current_lr : 0.000100
# train dataset : 13/2000 epochs spend time : 3.4707 sec / total_loss : 1.5303 correct : 13300/28705 -> 46.3334%
# test dataset : 13/2000 epochs spend time : 0.3625 sec  / total_loss : 1.4497 correct : 4218/9055 -> 46.5820%
# best epoch : 2/2000 / val accuracy : 46.581999%
# ==============================
# current_lr : 0.000100
# train dataset : 14/2000 epochs spend time : 3.4981 sec / total_loss : 1.5240 correct : 13331/28705 -> 46.4414%
# test dataset : 14/2000 epochs spend time : 0.3574 sec  / total_loss : 1.4309 correct : 4218/9055 -> 46.5820%
# best epoch : 2/2000 / val accuracy : 46.581999%
# ==============================
# current_lr : 0.000100
# train dataset : 15/2000 epochs spend time : 3.4798 sec / total_loss : 1.5170 correct : 13260/28705 -> 46.1940%
# test dataset : 15/2000 epochs spend time : 0.3641 sec  / total_loss : 1.4272 correct : 4218/9055 -> 46.5820%
# best epoch : 2/2000 / val accuracy : 46.581999%
# ==============================
# current_lr : 0.000100
# train dataset : 16/2000 epochs spend time : 3.4658 sec / total_loss : 1.5122 correct : 13288/28705 -> 46.2916%
# test dataset : 16/2000 epochs spend time : 0.3771 sec  / total_loss : 1.4194 correct : 4218/9055 -> 46.5820%
# best epoch : 2/2000 / val accuracy : 46.581999%
# ==============================
# current_lr : 0.000100
# train dataset : 17/2000 epochs spend time : 3.4641 sec / total_loss : 1.5063 correct : 13401/28705 -> 46.6852%
# test dataset : 17/2000 epochs spend time : 0.3590 sec  / total_loss : 1.4110 correct : 4218/9055 -> 46.5820%
# best epoch : 2/2000 / val accuracy : 46.581999%
# ==============================
# current_lr : 0.000100
# train dataset : 18/2000 epochs spend time : 3.4686 sec / total_loss : 1.5047 correct : 13464/28705 -> 46.9047%
# test dataset : 18/2000 epochs spend time : 0.3618 sec  / total_loss : 1.4127 correct : 4218/9055 -> 46.5820%
# best epoch : 2/2000 / val accuracy : 46.581999%
# ==============================
# current_lr : 0.000100
# train dataset : 19/2000 epochs spend time : 3.4982 sec / total_loss : 1.5015 correct : 13197/28705 -> 45.9746%
# test dataset : 19/2000 epochs spend time : 0.3586 sec  / total_loss : 1.3914 correct : 4218/9055 -> 46.5820%
# best epoch : 2/2000 / val accuracy : 46.581999%
# ==============================
# current_lr : 0.000100
# train dataset : 20/2000 epochs spend time : 3.5111 sec / total_loss : 1.4874 correct : 13546/28705 -> 47.1904%
# test dataset : 20/2000 epochs spend time : 0.3631 sec  / total_loss : 1.3698 correct : 4218/9055 -> 46.5820%
# best epoch : 2/2000 / val accuracy : 46.581999%
# ==============================
# current_lr : 0.000100
# train dataset : 21/2000 epochs spend time : 3.5189 sec / total_loss : 1.4728 correct : 13404/28705 -> 46.6957%
# test dataset : 21/2000 epochs spend time : 0.3628 sec  / total_loss : 1.3518 correct : 4218/9055 -> 46.5820%
# best epoch : 2/2000 / val accuracy : 46.581999%
# ==============================
# current_lr : 0.000100
# train dataset : 22/2000 epochs spend time : 3.5058 sec / total_loss : 1.4384 correct : 13889/28705 -> 48.3853%
# test dataset : 22/2000 epochs spend time : 0.3592 sec  / total_loss : 1.2714 correct : 4935/9055 -> 54.5003%
# best epoch : 22/2000 / val accuracy : 54.500276%
# ==============================
# current_lr : 0.000100
# train dataset : 23/2000 epochs spend time : 3.5271 sec / total_loss : 1.4268 correct : 13304/28705 -> 46.3473%
# test dataset : 23/2000 epochs spend time : 0.3682 sec  / total_loss : 1.2878 correct : 4297/9055 -> 47.4544%
# best epoch : 22/2000 / val accuracy : 54.500276%
# ==============================
# current_lr : 0.000100
# train dataset : 24/2000 epochs spend time : 3.5485 sec / total_loss : 1.3750 correct : 14419/28705 -> 50.2317%
# test dataset : 24/2000 epochs spend time : 0.3737 sec  / total_loss : 1.1899 correct : 5006/9055 -> 55.2844%
# best epoch : 24/2000 / val accuracy : 55.284373%
# ==============================
# current_lr : 0.000100
# train dataset : 25/2000 epochs spend time : 3.5608 sec / total_loss : 1.3250 correct : 14885/28705 -> 51.8551%
# test dataset : 25/2000 epochs spend time : 0.3679 sec  / total_loss : 1.1912 correct : 4591/9055 -> 50.7013%
# best epoch : 24/2000 / val accuracy : 55.284373%
# ==============================
# current_lr : 0.000100
# train dataset : 26/2000 epochs spend time : 3.5381 sec / total_loss : 1.3055 correct : 14962/28705 -> 52.1233%
# test dataset : 26/2000 epochs spend time : 0.3669 sec  / total_loss : 1.0929 correct : 5098/9055 -> 56.3004%
# best epoch : 26/2000 / val accuracy : 56.300387%
# ==============================
# current_lr : 0.000100
# train dataset : 27/2000 epochs spend time : 3.5377 sec / total_loss : 1.2320 correct : 15960/28705 -> 55.6001%
# test dataset : 27/2000 epochs spend time : 0.3597 sec  / total_loss : 1.0493 correct : 5444/9055 -> 60.1215%
# best epoch : 27/2000 / val accuracy : 60.121480%
# ==============================
# current_lr : 0.000100
# train dataset : 28/2000 epochs spend time : 3.5282 sec / total_loss : 1.2461 correct : 15379/28705 -> 53.5760%
# test dataset : 28/2000 epochs spend time : 0.3736 sec  / total_loss : 1.0351 correct : 5957/9055 -> 65.7869%
# best epoch : 28/2000 / val accuracy : 65.786858%
# ==============================
# current_lr : 0.000100
# train dataset : 29/2000 epochs spend time : 3.5360 sec / total_loss : 1.1930 correct : 16603/28705 -> 57.8401%
# test dataset : 29/2000 epochs spend time : 0.3661 sec  / total_loss : 1.0099 correct : 5984/9055 -> 66.0850%
# best epoch : 29/2000 / val accuracy : 66.085036%
# ==============================
# current_lr : 0.000100
# train dataset : 30/2000 epochs spend time : 3.5416 sec / total_loss : 1.1942 correct : 16340/28705 -> 56.9239%
# test dataset : 30/2000 epochs spend time : 0.3674 sec  / total_loss : 1.0053 correct : 5901/9055 -> 65.1684%
# best epoch : 29/2000 / val accuracy : 66.085036%
# ==============================
# current_lr : 0.000100
# train dataset : 31/2000 epochs spend time : 3.5672 sec / total_loss : 1.1767 correct : 16501/28705 -> 57.4848%
# test dataset : 31/2000 epochs spend time : 0.3680 sec  / total_loss : 1.0144 correct : 5777/9055 -> 63.7990%
# best epoch : 29/2000 / val accuracy : 66.085036%
# ==============================
# current_lr : 0.000100
# train dataset : 32/2000 epochs spend time : 3.5850 sec / total_loss : 1.1801 correct : 16470/28705 -> 57.3768%
# test dataset : 32/2000 epochs spend time : 0.3536 sec  / total_loss : 1.0297 correct : 5605/9055 -> 61.8995%
# best epoch : 29/2000 / val accuracy : 66.085036%
# ==============================
# current_lr : 0.000100
# train dataset : 33/2000 epochs spend time : 3.5338 sec / total_loss : 1.1395 correct : 17126/28705 -> 59.6621%
# test dataset : 33/2000 epochs spend time : 0.3614 sec  / total_loss : 0.9812 correct : 5863/9055 -> 64.7488%
# best epoch : 29/2000 / val accuracy : 66.085036%
# ==============================
# current_lr : 0.000100
# train dataset : 34/2000 epochs spend time : 3.6088 sec / total_loss : 1.1358 correct : 17148/28705 -> 59.7387%
# test dataset : 34/2000 epochs spend time : 0.3638 sec  / total_loss : 0.9521 correct : 6015/9055 -> 66.4274%
# best epoch : 34/2000 / val accuracy : 66.427388%
# ==============================
# current_lr : 0.000100
# train dataset : 35/2000 epochs spend time : 3.5753 sec / total_loss : 1.1303 correct : 17378/28705 -> 60.5400%
# test dataset : 35/2000 epochs spend time : 0.3628 sec  / total_loss : 1.0290 correct : 5705/9055 -> 63.0039%
# best epoch : 34/2000 / val accuracy : 66.427388%
# ==============================
# current_lr : 0.000100
# train dataset : 36/2000 epochs spend time : 3.5389 sec / total_loss : 1.1317 correct : 17388/28705 -> 60.5748%
# test dataset : 36/2000 epochs spend time : 0.3647 sec  / total_loss : 0.9709 correct : 5866/9055 -> 64.7819%
# best epoch : 34/2000 / val accuracy : 66.427388%
# ==============================
# current_lr : 0.000100
# train dataset : 37/2000 epochs spend time : 3.5281 sec / total_loss : 1.1308 correct : 17426/28705 -> 60.7072%
# test dataset : 37/2000 epochs spend time : 0.3745 sec  / total_loss : 0.9804 correct : 5721/9055 -> 63.1806%
# best epoch : 34/2000 / val accuracy : 66.427388%
# ==============================
# current_lr : 0.000100
# train dataset : 38/2000 epochs spend time : 3.5263 sec / total_loss : 1.1172 correct : 17643/28705 -> 61.4632%
# test dataset : 38/2000 epochs spend time : 0.3637 sec  / total_loss : 0.9550 correct : 5806/9055 -> 64.1193%
# best epoch : 34/2000 / val accuracy : 66.427388%
# ==============================
# current_lr : 0.000100
# train dataset : 39/2000 epochs spend time : 3.5383 sec / total_loss : 1.1248 correct : 17588/28705 -> 61.2716%
# test dataset : 39/2000 epochs spend time : 0.3602 sec  / total_loss : 0.9757 correct : 5636/9055 -> 62.2419%
# best epoch : 34/2000 / val accuracy : 66.427388%
# ==============================
# current_lr : 0.000100
# train dataset : 40/2000 epochs spend time : 3.5246 sec / total_loss : 1.1190 correct : 17508/28705 -> 60.9929%
# test dataset : 40/2000 epochs spend time : 0.3648 sec  / total_loss : 0.9387 correct : 5897/9055 -> 65.1242%
# best epoch : 34/2000 / val accuracy : 66.427388%
# ==============================
# current_lr : 0.000100
# train dataset : 41/2000 epochs spend time : 3.5213 sec / total_loss : 1.1147 correct : 17644/28705 -> 61.4666%
# test dataset : 41/2000 epochs spend time : 0.3671 sec  / total_loss : 0.9442 correct : 5865/9055 -> 64.7708%
# best epoch : 34/2000 / val accuracy : 66.427388%
# ==============================
# current_lr : 0.000100
# train dataset : 42/2000 epochs spend time : 3.5645 sec / total_loss : 1.1217 correct : 17527/28705 -> 61.0590%
# test dataset : 42/2000 epochs spend time : 0.3698 sec  / total_loss : 0.9510 correct : 5837/9055 -> 64.4616%
# best epoch : 34/2000 / val accuracy : 66.427388%
# ==============================
# current_lr : 0.000100
# train dataset : 43/2000 epochs spend time : 3.5364 sec / total_loss : 1.1002 correct : 17913/28705 -> 62.4038%
# test dataset : 43/2000 epochs spend time : 0.3647 sec  / total_loss : 0.9144 correct : 6050/9055 -> 66.8139%
# best epoch : 43/2000 / val accuracy : 66.813915%
# ==============================
# current_lr : 0.000100
# train dataset : 44/2000 epochs spend time : 3.5406 sec / total_loss : 1.0883 correct : 18064/28705 -> 62.9298%
# test dataset : 44/2000 epochs spend time : 0.3694 sec  / total_loss : 0.9305 correct : 5856/9055 -> 64.6715%
# best epoch : 43/2000 / val accuracy : 66.813915%
# ==============================
# current_lr : 0.000100
# train dataset : 45/2000 epochs spend time : 3.5203 sec / total_loss : 1.0943 correct : 17714/28705 -> 61.7105%
# test dataset : 45/2000 epochs spend time : 0.3668 sec  / total_loss : 0.9638 correct : 5780/9055 -> 63.8321%
# best epoch : 43/2000 / val accuracy : 66.813915%
# ==============================
# current_lr : 0.000100
# train dataset : 46/2000 epochs spend time : 3.5417 sec / total_loss : 1.0837 correct : 18091/28705 -> 63.0239%
# test dataset : 46/2000 epochs spend time : 0.3675 sec  / total_loss : 0.9094 correct : 5982/9055 -> 66.0629%
# best epoch : 43/2000 / val accuracy : 66.813915%
# ==============================
# current_lr : 0.000100
# train dataset : 47/2000 epochs spend time : 3.5223 sec / total_loss : 1.0810 correct : 18049/28705 -> 62.8775%
# test dataset : 47/2000 epochs spend time : 0.3621 sec  / total_loss : 0.9091 correct : 5984/9055 -> 66.0850%
# best epoch : 43/2000 / val accuracy : 66.813915%
# ==============================
# current_lr : 0.000100
# train dataset : 48/2000 epochs spend time : 3.5576 sec / total_loss : 1.0776 correct : 18179/28705 -> 63.3304%
# test dataset : 48/2000 epochs spend time : 0.3649 sec  / total_loss : 0.9439 correct : 5736/9055 -> 63.3462%
# best epoch : 43/2000 / val accuracy : 66.813915%
# ==============================
# current_lr : 0.000100
# train dataset : 49/2000 epochs spend time : 3.5333 sec / total_loss : 1.0797 correct : 18080/28705 -> 62.9855%
# test dataset : 49/2000 epochs spend time : 0.3625 sec  / total_loss : 0.9127 correct : 5971/9055 -> 65.9415%
# best epoch : 43/2000 / val accuracy : 66.813915%
# ==============================
# current_lr : 0.000100
# train dataset : 50/2000 epochs spend time : 3.5346 sec / total_loss : 1.0690 correct : 18252/28705 -> 63.5847%
# test dataset : 50/2000 epochs spend time : 0.3766 sec  / total_loss : 0.9268 correct : 5929/9055 -> 65.4776%
# best epoch : 43/2000 / val accuracy : 66.813915%
# ==============================
# current_lr : 0.000100
# train dataset : 51/2000 epochs spend time : 3.5614 sec / total_loss : 1.0803 correct : 18179/28705 -> 63.3304%
# test dataset : 51/2000 epochs spend time : 0.3669 sec  / total_loss : 0.9188 correct : 5832/9055 -> 64.4064%
# best epoch : 43/2000 / val accuracy : 66.813915%
# ==============================
# current_lr : 0.000100
# train dataset : 52/2000 epochs spend time : 3.5474 sec / total_loss : 1.0669 correct : 18242/28705 -> 63.5499%
# test dataset : 52/2000 epochs spend time : 0.3704 sec  / total_loss : 0.9127 correct : 5996/9055 -> 66.2176%
# best epoch : 43/2000 / val accuracy : 66.813915%
# ==============================
# current_lr : 0.000100
# train dataset : 53/2000 epochs spend time : 3.5507 sec / total_loss : 1.0576 correct : 18188/28705 -> 63.3618%
# test dataset : 53/2000 epochs spend time : 0.3630 sec  / total_loss : 0.9956 correct : 5499/9055 -> 60.7289%
# best epoch : 43/2000 / val accuracy : 66.813915%
# ==============================
# current_lr : 0.000100
# train dataset : 54/2000 epochs spend time : 3.5436 sec / total_loss : 1.0990 correct : 17546/28705 -> 61.1252%
# test dataset : 54/2000 epochs spend time : 0.3580 sec  / total_loss : 0.8997 correct : 6031/9055 -> 66.6041%
# best epoch : 43/2000 / val accuracy : 66.813915%
# ==============================
# current_lr : 0.000100
# train dataset : 55/2000 epochs spend time : 3.5648 sec / total_loss : 1.0542 correct : 18459/28705 -> 64.3059%
# test dataset : 55/2000 epochs spend time : 0.3601 sec  / total_loss : 0.8794 correct : 6095/9055 -> 67.3109%
# best epoch : 55/2000 / val accuracy : 67.310878%
# ==============================
# current_lr : 0.000100
# train dataset : 56/2000 epochs spend time : 3.5329 sec / total_loss : 1.0557 correct : 18280/28705 -> 63.6823%
# test dataset : 56/2000 epochs spend time : 0.3665 sec  / total_loss : 0.9303 correct : 5814/9055 -> 64.2076%
# best epoch : 55/2000 / val accuracy : 67.310878%
# ==============================
# current_lr : 0.000100
# train dataset : 57/2000 epochs spend time : 3.5493 sec / total_loss : 1.0687 correct : 18149/28705 -> 63.2259%
# test dataset : 57/2000 epochs spend time : 0.3658 sec  / total_loss : 0.9224 correct : 5888/9055 -> 65.0248%
# best epoch : 55/2000 / val accuracy : 67.310878%
# ==============================
# current_lr : 0.000100
# train dataset : 58/2000 epochs spend time : 3.5438 sec / total_loss : 1.0457 correct : 18545/28705 -> 64.6055%
# test dataset : 58/2000 epochs spend time : 0.3680 sec  / total_loss : 0.8963 correct : 6004/9055 -> 66.3059%
# best epoch : 55/2000 / val accuracy : 67.310878%
# ==============================
# current_lr : 0.000100
# train dataset : 59/2000 epochs spend time : 3.5413 sec / total_loss : 1.0573 correct : 18239/28705 -> 63.5395%
# test dataset : 59/2000 epochs spend time : 0.3780 sec  / total_loss : 0.9283 correct : 5905/9055 -> 65.2126%
# best epoch : 55/2000 / val accuracy : 67.310878%
# ==============================
# current_lr : 0.000100
# train dataset : 60/2000 epochs spend time : 3.5258 sec / total_loss : 1.0820 correct : 17908/28705 -> 62.3863%
# test dataset : 60/2000 epochs spend time : 0.3642 sec  / total_loss : 0.9245 correct : 5898/9055 -> 65.1353%
# best epoch : 55/2000 / val accuracy : 67.310878%
# ==============================
# current_lr : 0.000100
# train dataset : 61/2000 epochs spend time : 3.5189 sec / total_loss : 1.0512 correct : 18292/28705 -> 63.7241%
# test dataset : 61/2000 epochs spend time : 0.3631 sec  / total_loss : 0.9436 correct : 5815/9055 -> 64.2187%
# best epoch : 55/2000 / val accuracy : 67.310878%
# ==============================
# current_lr : 0.000100
# train dataset : 62/2000 epochs spend time : 3.5668 sec / total_loss : 1.0435 correct : 18417/28705 -> 64.1596%
# test dataset : 62/2000 epochs spend time : 0.3611 sec  / total_loss : 0.8790 correct : 6041/9055 -> 66.7145%
# best epoch : 55/2000 / val accuracy : 67.310878%
# ==============================
# current_lr : 0.000100
# train dataset : 63/2000 epochs spend time : 3.5320 sec / total_loss : 1.0288 correct : 18632/28705 -> 64.9086%
# test dataset : 63/2000 epochs spend time : 0.3607 sec  / total_loss : 0.9341 correct : 5868/9055 -> 64.8040%
# best epoch : 55/2000 / val accuracy : 67.310878%
# ==============================
# current_lr : 0.000100
# train dataset : 64/2000 epochs spend time : 3.5483 sec / total_loss : 1.0380 correct : 18524/28705 -> 64.5323%
# test dataset : 64/2000 epochs spend time : 0.3642 sec  / total_loss : 0.8731 correct : 6069/9055 -> 67.0237%
# best epoch : 55/2000 / val accuracy : 67.310878%
# ==============================
# current_lr : 0.000100
# train dataset : 65/2000 epochs spend time : 3.5577 sec / total_loss : 1.0552 correct : 18247/28705 -> 63.5673%
# test dataset : 65/2000 epochs spend time : 0.3758 sec  / total_loss : 0.8648 correct : 6064/9055 -> 66.9685%
# best epoch : 55/2000 / val accuracy : 67.310878%
# ==============================
# current_lr : 0.000100
# train dataset : 66/2000 epochs spend time : 3.5376 sec / total_loss : 1.0334 correct : 18595/28705 -> 64.7797%
# test dataset : 66/2000 epochs spend time : 0.3709 sec  / total_loss : 0.8995 correct : 5968/9055 -> 65.9083%
# best epoch : 55/2000 / val accuracy : 67.310878%
# ==============================
# current_lr : 0.000100
# train dataset : 67/2000 epochs spend time : 3.5300 sec / total_loss : 1.0595 correct : 18321/28705 -> 63.8251%
# test dataset : 67/2000 epochs spend time : 0.3654 sec  / total_loss : 0.9263 correct : 5783/9055 -> 63.8653%
# best epoch : 55/2000 / val accuracy : 67.310878%
# ==============================
# current_lr : 0.000100
# train dataset : 68/2000 epochs spend time : 3.5287 sec / total_loss : 1.0509 correct : 18353/28705 -> 63.9366%
# test dataset : 68/2000 epochs spend time : 0.3656 sec  / total_loss : 0.8782 correct : 6017/9055 -> 66.4495%
# best epoch : 55/2000 / val accuracy : 67.310878%
# ==============================
# current_lr : 0.000100
# train dataset : 69/2000 epochs spend time : 3.5351 sec / total_loss : 1.0421 correct : 18341/28705 -> 63.8948%
# test dataset : 69/2000 epochs spend time : 0.3661 sec  / total_loss : 0.8721 correct : 6073/9055 -> 67.0679%
# best epoch : 55/2000 / val accuracy : 67.310878%
# ==============================
# current_lr : 0.000100
# train dataset : 70/2000 epochs spend time : 3.5535 sec / total_loss : 1.0249 correct : 18550/28705 -> 64.6229%
# test dataset : 70/2000 epochs spend time : 0.3642 sec  / total_loss : 0.8716 correct : 6067/9055 -> 67.0017%
# best epoch : 55/2000 / val accuracy : 67.310878%
# ==============================
# current_lr : 0.000100
# train dataset : 71/2000 epochs spend time : 3.5323 sec / total_loss : 1.0213 correct : 18759/28705 -> 65.3510%
# test dataset : 71/2000 epochs spend time : 0.3649 sec  / total_loss : 0.8709 correct : 6064/9055 -> 66.9685%
# best epoch : 55/2000 / val accuracy : 67.310878%
# ==============================
# current_lr : 0.000100
# train dataset : 72/2000 epochs spend time : 3.5314 sec / total_loss : 1.0260 correct : 18629/28705 -> 64.8981%
# test dataset : 72/2000 epochs spend time : 0.3715 sec  / total_loss : 0.8442 correct : 6155/9055 -> 67.9735%
# best epoch : 72/2000 / val accuracy : 67.973495%
# ==============================
# current_lr : 0.000100
# train dataset : 73/2000 epochs spend time : 3.5282 sec / total_loss : 1.0247 correct : 18695/28705 -> 65.1280%
# test dataset : 73/2000 epochs spend time : 0.3632 sec  / total_loss : 0.9463 correct : 5823/9055 -> 64.3070%
# best epoch : 72/2000 / val accuracy : 67.973495%
# ==============================
# current_lr : 0.000100
# train dataset : 74/2000 epochs spend time : 3.5402 sec / total_loss : 1.0485 correct : 18490/28705 -> 64.4139%
# test dataset : 74/2000 epochs spend time : 0.3557 sec  / total_loss : 0.8904 correct : 5999/9055 -> 66.2507%
# best epoch : 72/2000 / val accuracy : 67.973495%
# ==============================
# current_lr : 0.000100
# train dataset : 75/2000 epochs spend time : 3.5581 sec / total_loss : 1.0172 correct : 18732/28705 -> 65.2569%
# test dataset : 75/2000 epochs spend time : 0.3797 sec  / total_loss : 0.8681 correct : 6073/9055 -> 67.0679%
# best epoch : 72/2000 / val accuracy : 67.973495%
# ==============================
# current_lr : 0.000100
# train dataset : 76/2000 epochs spend time : 3.6232 sec / total_loss : 1.0099 correct : 18839/28705 -> 65.6297%
# test dataset : 76/2000 epochs spend time : 0.3756 sec  / total_loss : 0.8834 correct : 6024/9055 -> 66.5268%
# best epoch : 72/2000 / val accuracy : 67.973495%
# ==============================
# current_lr : 0.000100
# train dataset : 77/2000 epochs spend time : 3.6082 sec / total_loss : 1.0051 correct : 18904/28705 -> 65.8561%
# test dataset : 77/2000 epochs spend time : 0.3821 sec  / total_loss : 0.8619 correct : 6091/9055 -> 67.2667%
# best epoch : 72/2000 / val accuracy : 67.973495%
# ==============================
# current_lr : 0.000100
# train dataset : 78/2000 epochs spend time : 3.5725 sec / total_loss : 1.0089 correct : 18741/28705 -> 65.2883%
# test dataset : 78/2000 epochs spend time : 0.3700 sec  / total_loss : 0.8878 correct : 5958/9055 -> 65.7979%
# best epoch : 72/2000 / val accuracy : 67.973495%
# ==============================
# current_lr : 0.000100
# train dataset : 79/2000 epochs spend time : 3.5723 sec / total_loss : 1.0129 correct : 18814/28705 -> 65.5426%
# test dataset : 79/2000 epochs spend time : 0.3624 sec  / total_loss : 0.8510 correct : 6139/9055 -> 67.7968%
# best epoch : 72/2000 / val accuracy : 67.973495%
# ==============================
# current_lr : 0.000100
# train dataset : 80/2000 epochs spend time : 3.5486 sec / total_loss : 1.0153 correct : 18899/28705 -> 65.8387%
# test dataset : 80/2000 epochs spend time : 0.3658 sec  / total_loss : 0.8975 correct : 5978/9055 -> 66.0188%
# best epoch : 72/2000 / val accuracy : 67.973495%
# ==============================
# current_lr : 0.000100
# train dataset : 81/2000 epochs spend time : 3.5431 sec / total_loss : 1.0410 correct : 18395/28705 -> 64.0829%
# test dataset : 81/2000 epochs spend time : 0.3871 sec  / total_loss : 0.9386 correct : 5835/9055 -> 64.4395%
# best epoch : 72/2000 / val accuracy : 67.973495%
# ==============================
# current_lr : 0.000100
# train dataset : 82/2000 epochs spend time : 3.5482 sec / total_loss : 1.0244 correct : 18706/28705 -> 65.1663%
# test dataset : 82/2000 epochs spend time : 0.3914 sec  / total_loss : 0.8675 correct : 6004/9055 -> 66.3059%
# best epoch : 72/2000 / val accuracy : 67.973495%
# ==============================
# current_lr : 0.000100
# train dataset : 83/2000 epochs spend time : 3.5574 sec / total_loss : 1.0393 correct : 18573/28705 -> 64.7030%
# test dataset : 83/2000 epochs spend time : 0.3667 sec  / total_loss : 0.8387 correct : 6154/9055 -> 67.9625%
# best epoch : 72/2000 / val accuracy : 67.973495%
# ==============================
# current_lr : 0.000100
# train dataset : 84/2000 epochs spend time : 3.5241 sec / total_loss : 1.0047 correct : 18837/28705 -> 65.6227%
# test dataset : 84/2000 epochs spend time : 0.3638 sec  / total_loss : 0.8611 correct : 6086/9055 -> 67.2115%
# best epoch : 72/2000 / val accuracy : 67.973495%
# ==============================
# current_lr : 0.000100
# train dataset : 85/2000 epochs spend time : 3.5424 sec / total_loss : 0.9964 correct : 18982/28705 -> 66.1279%
# test dataset : 85/2000 epochs spend time : 0.3642 sec  / total_loss : 0.8687 correct : 6047/9055 -> 66.7808%
# best epoch : 72/2000 / val accuracy : 67.973495%
# ==============================
# current_lr : 0.000100
# train dataset : 86/2000 epochs spend time : 3.5288 sec / total_loss : 1.0065 correct : 18803/28705 -> 65.5043%
# test dataset : 86/2000 epochs spend time : 0.3666 sec  / total_loss : 0.8478 correct : 6134/9055 -> 67.7416%
# best epoch : 72/2000 / val accuracy : 67.973495%
# ==============================
# current_lr : 0.000100
# train dataset : 87/2000 epochs spend time : 3.5351 sec / total_loss : 1.0053 correct : 18802/28705 -> 65.5008%
# test dataset : 87/2000 epochs spend time : 0.3652 sec  / total_loss : 0.8760 correct : 6039/9055 -> 66.6924%
# best epoch : 72/2000 / val accuracy : 67.973495%
# ==============================
# current_lr : 0.000100
# train dataset : 88/2000 epochs spend time : 3.5489 sec / total_loss : 0.9993 correct : 18954/28705 -> 66.0303%
# test dataset : 88/2000 epochs spend time : 0.3738 sec  / total_loss : 0.8539 correct : 6101/9055 -> 67.3771%
# best epoch : 72/2000 / val accuracy : 67.973495%
# ==============================
# current_lr : 0.000100
# train dataset : 89/2000 epochs spend time : 3.5387 sec / total_loss : 0.9951 correct : 18907/28705 -> 65.8666%
# test dataset : 89/2000 epochs spend time : 0.3664 sec  / total_loss : 0.8816 correct : 6035/9055 -> 66.6483%
# best epoch : 72/2000 / val accuracy : 67.973495%
# ==============================
# current_lr : 0.000100
# train dataset : 90/2000 epochs spend time : 3.5464 sec / total_loss : 0.9966 correct : 18960/28705 -> 66.0512%
# test dataset : 90/2000 epochs spend time : 0.3739 sec  / total_loss : 0.8347 correct : 6175/9055 -> 68.1944%
# best epoch : 90/2000 / val accuracy : 68.194368%
# ==============================
# current_lr : 0.000100
# train dataset : 91/2000 epochs spend time : 3.5347 sec / total_loss : 0.9975 correct : 18970/28705 -> 66.0860%
# test dataset : 91/2000 epochs spend time : 0.3645 sec  / total_loss : 0.8639 correct : 6091/9055 -> 67.2667%
# best epoch : 90/2000 / val accuracy : 68.194368%
# ==============================
# current_lr : 0.000100
# train dataset : 92/2000 epochs spend time : 3.5274 sec / total_loss : 0.9947 correct : 19094/28705 -> 66.5180%
# test dataset : 92/2000 epochs spend time : 0.3872 sec  / total_loss : 0.8270 correct : 6222/9055 -> 68.7134%
# best epoch : 92/2000 / val accuracy : 68.713418%
# ==============================
# current_lr : 0.000100
# train dataset : 93/2000 epochs spend time : 3.5435 sec / total_loss : 1.0151 correct : 18788/28705 -> 65.4520%
# test dataset : 93/2000 epochs spend time : 0.3682 sec  / total_loss : 0.8695 correct : 6108/9055 -> 67.4544%
# best epoch : 92/2000 / val accuracy : 68.713418%
# ==============================
# current_lr : 0.000100
# train dataset : 94/2000 epochs spend time : 3.5173 sec / total_loss : 0.9829 correct : 19052/28705 -> 66.3717%
# test dataset : 94/2000 epochs spend time : 0.3648 sec  / total_loss : 0.8305 correct : 6207/9055 -> 68.5478%
# best epoch : 92/2000 / val accuracy : 68.713418%
# ==============================
# current_lr : 0.000100
# train dataset : 95/2000 epochs spend time : 3.5587 sec / total_loss : 0.9880 correct : 19004/28705 -> 66.2045%
# test dataset : 95/2000 epochs spend time : 0.3866 sec  / total_loss : 0.8613 correct : 6134/9055 -> 67.7416%
# best epoch : 92/2000 / val accuracy : 68.713418%
# ==============================
# current_lr : 0.000100
# train dataset : 96/2000 epochs spend time : 3.5496 sec / total_loss : 0.9835 correct : 19070/28705 -> 66.4344%
# test dataset : 96/2000 epochs spend time : 0.3661 sec  / total_loss : 0.8377 correct : 6199/9055 -> 68.4594%
# best epoch : 92/2000 / val accuracy : 68.713418%
# ==============================
# current_lr : 0.000100
# train dataset : 97/2000 epochs spend time : 3.5589 sec / total_loss : 0.9853 correct : 19172/28705 -> 66.7898%
# test dataset : 97/2000 epochs spend time : 0.3717 sec  / total_loss : 0.8367 correct : 6194/9055 -> 68.4042%
# best epoch : 92/2000 / val accuracy : 68.713418%
# ==============================
# current_lr : 0.000100
# train dataset : 98/2000 epochs spend time : 3.5158 sec / total_loss : 0.9982 correct : 18917/28705 -> 65.9014%
# test dataset : 98/2000 epochs spend time : 0.3642 sec  / total_loss : 0.8355 correct : 6209/9055 -> 68.5699%
# best epoch : 92/2000 / val accuracy : 68.713418%
# ==============================
# current_lr : 0.000100
# train dataset : 99/2000 epochs spend time : 3.5509 sec / total_loss : 0.9907 correct : 18959/28705 -> 66.0477%
# test dataset : 99/2000 epochs spend time : 0.3663 sec  / total_loss : 0.8602 correct : 6164/9055 -> 68.0729%
# best epoch : 92/2000 / val accuracy : 68.713418%
# ==============================
# current_lr : 0.000100
# train dataset : 100/2000 epochs spend time : 3.5700 sec / total_loss : 0.9893 correct : 19043/28705 -> 66.3404%
# test dataset : 100/2000 epochs spend time : 0.3634 sec  / total_loss : 0.8593 correct : 6154/9055 -> 67.9625%
# best epoch : 92/2000 / val accuracy : 68.713418%
# ==============================
# current_lr : 0.000100
# train dataset : 101/2000 epochs spend time : 3.5659 sec / total_loss : 0.9804 correct : 19157/28705 -> 66.7375%
# test dataset : 101/2000 epochs spend time : 0.3653 sec  / total_loss : 0.8651 correct : 6103/9055 -> 67.3992%
# best epoch : 92/2000 / val accuracy : 68.713418%
# ==============================
# current_lr : 0.000100
# train dataset : 102/2000 epochs spend time : 3.5483 sec / total_loss : 0.9767 correct : 19068/28705 -> 66.4275%
# test dataset : 102/2000 epochs spend time : 0.3822 sec  / total_loss : 0.8583 correct : 6179/9055 -> 68.2385%
# best epoch : 92/2000 / val accuracy : 68.713418%
# ==============================
# current_lr : 0.000100
# train dataset : 103/2000 epochs spend time : 3.5321 sec / total_loss : 0.9907 correct : 19006/28705 -> 66.2115%
# test dataset : 103/2000 epochs spend time : 0.3786 sec  / total_loss : 0.8317 correct : 6218/9055 -> 68.6692%
# best epoch : 92/2000 / val accuracy : 68.713418%
# ==============================
# current_lr : 0.000050
# train dataset : 104/2000 epochs spend time : 3.5426 sec / total_loss : 0.9866 correct : 19121/28705 -> 66.6121%
# test dataset : 104/2000 epochs spend time : 0.3744 sec  / total_loss : 0.8430 correct : 6196/9055 -> 68.4263%
# best epoch : 92/2000 / val accuracy : 68.713418%
# ==============================
# current_lr : 0.000050
# train dataset : 105/2000 epochs spend time : 3.5128 sec / total_loss : 0.9673 correct : 19314/28705 -> 67.2844%
# test dataset : 105/2000 epochs spend time : 0.3768 sec  / total_loss : 0.8306 correct : 6231/9055 -> 68.8128%
# best epoch : 105/2000 / val accuracy : 68.812811%
# ==============================
# current_lr : 0.000050
# train dataset : 106/2000 epochs spend time : 3.5559 sec / total_loss : 0.9722 correct : 19183/28705 -> 66.8281%
# test dataset : 106/2000 epochs spend time : 0.3609 sec  / total_loss : 0.8255 correct : 6243/9055 -> 68.9453%
# best epoch : 106/2000 / val accuracy : 68.945334%
# ==============================
# current_lr : 0.000050
# train dataset : 107/2000 epochs spend time : 3.5442 sec / total_loss : 0.9734 correct : 19219/28705 -> 66.9535%
# test dataset : 107/2000 epochs spend time : 0.3720 sec  / total_loss : 0.8426 correct : 6205/9055 -> 68.5257%
# best epoch : 106/2000 / val accuracy : 68.945334%
# ==============================
# current_lr : 0.000050
# train dataset : 108/2000 epochs spend time : 3.5629 sec / total_loss : 0.9674 correct : 19222/28705 -> 66.9639%
# test dataset : 108/2000 epochs spend time : 0.3822 sec  / total_loss : 0.8278 correct : 6261/9055 -> 69.1441%
# best epoch : 108/2000 / val accuracy : 69.144119%
# ==============================
# current_lr : 0.000050
# train dataset : 109/2000 epochs spend time : 3.5594 sec / total_loss : 0.9769 correct : 19119/28705 -> 66.6051%
# test dataset : 109/2000 epochs spend time : 0.3638 sec  / total_loss : 0.8449 correct : 6197/9055 -> 68.4373%
# best epoch : 108/2000 / val accuracy : 69.144119%
# ==============================
# current_lr : 0.000050
# train dataset : 110/2000 epochs spend time : 3.5517 sec / total_loss : 0.9667 correct : 19269/28705 -> 67.1277%
# test dataset : 110/2000 epochs spend time : 0.3628 sec  / total_loss : 0.8229 correct : 6265/9055 -> 69.1883%
# best epoch : 110/2000 / val accuracy : 69.188294%
# ==============================
# current_lr : 0.000050
# train dataset : 111/2000 epochs spend time : 3.5541 sec / total_loss : 0.9730 correct : 19282/28705 -> 67.1730%
# test dataset : 111/2000 epochs spend time : 0.3686 sec  / total_loss : 0.8505 correct : 6190/9055 -> 68.3600%
# best epoch : 110/2000 / val accuracy : 69.188294%
# ==============================
# current_lr : 0.000050
# train dataset : 112/2000 epochs spend time : 3.5503 sec / total_loss : 0.9633 correct : 19288/28705 -> 67.1939%
# test dataset : 112/2000 epochs spend time : 0.4316 sec  / total_loss : 0.8258 correct : 6255/9055 -> 69.0779%
# best epoch : 110/2000 / val accuracy : 69.188294%
# ==============================
# current_lr : 0.000050
# train dataset : 113/2000 epochs spend time : 3.5481 sec / total_loss : 0.9617 correct : 19331/28705 -> 67.3437%
# test dataset : 113/2000 epochs spend time : 0.3795 sec  / total_loss : 0.8217 correct : 6274/9055 -> 69.2877%
# best epoch : 113/2000 / val accuracy : 69.287686%
# ==============================
# current_lr : 0.000050
# train dataset : 114/2000 epochs spend time : 3.5606 sec / total_loss : 0.9641 correct : 19299/28705 -> 67.2322%
# test dataset : 114/2000 epochs spend time : 0.3663 sec  / total_loss : 0.8319 correct : 6233/9055 -> 68.8349%
# best epoch : 113/2000 / val accuracy : 69.287686%
# ==============================
# current_lr : 0.000050
# train dataset : 115/2000 epochs spend time : 3.5530 sec / total_loss : 0.9591 correct : 19292/28705 -> 67.2078%
# test dataset : 115/2000 epochs spend time : 0.3736 sec  / total_loss : 0.8216 correct : 6254/9055 -> 69.0668%
# best epoch : 113/2000 / val accuracy : 69.287686%
# ==============================
# current_lr : 0.000050
# train dataset : 116/2000 epochs spend time : 3.5533 sec / total_loss : 0.9606 correct : 19247/28705 -> 67.0510%
# test dataset : 116/2000 epochs spend time : 0.3656 sec  / total_loss : 0.8261 correct : 6237/9055 -> 68.8791%
# best epoch : 113/2000 / val accuracy : 69.287686%
# ==============================
# current_lr : 0.000050
# train dataset : 117/2000 epochs spend time : 3.5335 sec / total_loss : 0.9538 correct : 19335/28705 -> 67.3576%
# test dataset : 117/2000 epochs spend time : 0.3724 sec  / total_loss : 0.8276 correct : 6245/9055 -> 68.9674%
# best epoch : 113/2000 / val accuracy : 69.287686%
# ==============================
# current_lr : 0.000050
# train dataset : 118/2000 epochs spend time : 3.5610 sec / total_loss : 0.9526 correct : 19385/28705 -> 67.5318%
# test dataset : 118/2000 epochs spend time : 0.3702 sec  / total_loss : 0.8232 correct : 6270/9055 -> 69.2435%
# best epoch : 113/2000 / val accuracy : 69.287686%
# ==============================
# current_lr : 0.000050
# train dataset : 119/2000 epochs spend time : 3.5485 sec / total_loss : 0.9571 correct : 19291/28705 -> 67.2043%
# test dataset : 119/2000 epochs spend time : 0.3745 sec  / total_loss : 0.8347 correct : 6221/9055 -> 68.7024%
# best epoch : 113/2000 / val accuracy : 69.287686%
# ==============================
# current_lr : 0.000050
# train dataset : 120/2000 epochs spend time : 3.5769 sec / total_loss : 0.9583 correct : 19310/28705 -> 67.2705%
# test dataset : 120/2000 epochs spend time : 0.3735 sec  / total_loss : 0.8278 correct : 6243/9055 -> 68.9453%
# best epoch : 113/2000 / val accuracy : 69.287686%
# ==============================
# current_lr : 0.000050
# train dataset : 121/2000 epochs spend time : 3.5736 sec / total_loss : 0.9547 correct : 19392/28705 -> 67.5562%
# test dataset : 121/2000 epochs spend time : 0.3750 sec  / total_loss : 0.8299 correct : 6230/9055 -> 68.8018%
# best epoch : 113/2000 / val accuracy : 69.287686%
# ==============================
# current_lr : 0.000050
# train dataset : 122/2000 epochs spend time : 3.5597 sec / total_loss : 0.9570 correct : 19223/28705 -> 66.9674%
# test dataset : 122/2000 epochs spend time : 0.3718 sec  / total_loss : 0.8271 correct : 6250/9055 -> 69.0226%
# best epoch : 113/2000 / val accuracy : 69.287686%
# ==============================
# current_lr : 0.000050
# train dataset : 123/2000 epochs spend time : 3.5474 sec / total_loss : 0.9556 correct : 19341/28705 -> 67.3785%
# test dataset : 123/2000 epochs spend time : 0.3906 sec  / total_loss : 0.8220 correct : 6250/9055 -> 69.0226%
# best epoch : 113/2000 / val accuracy : 69.287686%
# ==============================
# current_lr : 0.000050
# train dataset : 124/2000 epochs spend time : 3.5399 sec / total_loss : 0.9532 correct : 19368/28705 -> 67.4726%
# test dataset : 124/2000 epochs spend time : 0.3708 sec  / total_loss : 0.8263 correct : 6250/9055 -> 69.0226%
# best epoch : 113/2000 / val accuracy : 69.287686%
# ==============================
# current_lr : 0.000050
# train dataset : 125/2000 epochs spend time : 3.5604 sec / total_loss : 0.9536 correct : 19365/28705 -> 67.4621%
# test dataset : 125/2000 epochs spend time : 0.3706 sec  / total_loss : 0.8170 correct : 6272/9055 -> 69.2656%
# best epoch : 113/2000 / val accuracy : 69.287686%
# ==============================
# current_lr : 0.000050
# train dataset : 126/2000 epochs spend time : 3.5499 sec / total_loss : 0.9558 correct : 19242/28705 -> 67.0336%
# test dataset : 126/2000 epochs spend time : 0.3681 sec  / total_loss : 0.8433 correct : 6205/9055 -> 68.5257%
# best epoch : 113/2000 / val accuracy : 69.287686%
# ==============================
# current_lr : 0.000050
# train dataset : 127/2000 epochs spend time : 3.5542 sec / total_loss : 0.9556 correct : 19327/28705 -> 67.3297%
# test dataset : 127/2000 epochs spend time : 0.3793 sec  / total_loss : 0.8277 correct : 6254/9055 -> 69.0668%
# best epoch : 113/2000 / val accuracy : 69.287686%
# ==============================
# current_lr : 0.000050
# train dataset : 128/2000 epochs spend time : 3.5924 sec / total_loss : 0.9634 correct : 19204/28705 -> 66.9012%
# test dataset : 128/2000 epochs spend time : 0.3691 sec  / total_loss : 0.8280 correct : 6234/9055 -> 68.8459%
# best epoch : 113/2000 / val accuracy : 69.287686%
# ==============================
# current_lr : 0.000050
# train dataset : 129/2000 epochs spend time : 3.5855 sec / total_loss : 0.9513 correct : 19315/28705 -> 67.2879%
# test dataset : 129/2000 epochs spend time : 0.3732 sec  / total_loss : 0.8128 correct : 6298/9055 -> 69.5527%
# best epoch : 129/2000 / val accuracy : 69.552733%
# ==============================
# current_lr : 0.000050
# train dataset : 130/2000 epochs spend time : 3.5787 sec / total_loss : 0.9437 correct : 19447/28705 -> 67.7478%
# test dataset : 130/2000 epochs spend time : 0.3890 sec  / total_loss : 0.8115 correct : 6271/9055 -> 69.2546%
# best epoch : 129/2000 / val accuracy : 69.552733%
# ==============================
# current_lr : 0.000050
# train dataset : 131/2000 epochs spend time : 3.5510 sec / total_loss : 0.9456 correct : 19431/28705 -> 67.6920%
# test dataset : 131/2000 epochs spend time : 0.3770 sec  / total_loss : 0.8173 correct : 6280/9055 -> 69.3539%
# best epoch : 129/2000 / val accuracy : 69.552733%
# ==============================
# current_lr : 0.000050
# train dataset : 132/2000 epochs spend time : 3.5695 sec / total_loss : 0.9453 correct : 19362/28705 -> 67.4517%
# test dataset : 132/2000 epochs spend time : 0.3777 sec  / total_loss : 0.8151 correct : 6272/9055 -> 69.2656%
# best epoch : 129/2000 / val accuracy : 69.552733%
# ==============================
# current_lr : 0.000050
# train dataset : 133/2000 epochs spend time : 3.5382 sec / total_loss : 0.9444 correct : 19349/28705 -> 67.4064%
# test dataset : 133/2000 epochs spend time : 0.3723 sec  / total_loss : 0.8213 correct : 6252/9055 -> 69.0447%
# best epoch : 129/2000 / val accuracy : 69.552733%
# ==============================
# current_lr : 0.000050
# train dataset : 134/2000 epochs spend time : 3.5694 sec / total_loss : 0.9480 correct : 19330/28705 -> 67.3402%
# test dataset : 134/2000 epochs spend time : 0.3768 sec  / total_loss : 0.8182 correct : 6272/9055 -> 69.2656%
# best epoch : 129/2000 / val accuracy : 69.552733%
# ==============================
# current_lr : 0.000050
# train dataset : 135/2000 epochs spend time : 3.5616 sec / total_loss : 0.9420 correct : 19326/28705 -> 67.3262%
# test dataset : 135/2000 epochs spend time : 0.3700 sec  / total_loss : 0.8111 correct : 6278/9055 -> 69.3319%
# best epoch : 129/2000 / val accuracy : 69.552733%
# ==============================
# current_lr : 0.000050
# train dataset : 136/2000 epochs spend time : 3.5734 sec / total_loss : 0.9413 correct : 19390/28705 -> 67.5492%
# test dataset : 136/2000 epochs spend time : 0.3794 sec  / total_loss : 0.8081 correct : 6285/9055 -> 69.4092%
# best epoch : 129/2000 / val accuracy : 69.552733%
# ==============================
# current_lr : 0.000050
# train dataset : 137/2000 epochs spend time : 3.5679 sec / total_loss : 0.9375 correct : 19494/28705 -> 67.9115%
# test dataset : 137/2000 epochs spend time : 0.3788 sec  / total_loss : 0.8181 correct : 6261/9055 -> 69.1441%
# best epoch : 129/2000 / val accuracy : 69.552733%
# ==============================
# current_lr : 0.000050
# train dataset : 138/2000 epochs spend time : 3.5442 sec / total_loss : 0.9612 correct : 19167/28705 -> 66.7723%
# test dataset : 138/2000 epochs spend time : 0.3721 sec  / total_loss : 0.8309 correct : 6211/9055 -> 68.5919%
# best epoch : 129/2000 / val accuracy : 69.552733%
# ==============================
# current_lr : 0.000050
# train dataset : 139/2000 epochs spend time : 3.5448 sec / total_loss : 0.9463 correct : 19297/28705 -> 67.2252%
# test dataset : 139/2000 epochs spend time : 0.3762 sec  / total_loss : 0.8197 correct : 6235/9055 -> 68.8570%
# best epoch : 129/2000 / val accuracy : 69.552733%
# ==============================
# current_lr : 0.000050
# train dataset : 140/2000 epochs spend time : 3.5472 sec / total_loss : 0.9475 correct : 19290/28705 -> 67.2008%
# test dataset : 140/2000 epochs spend time : 0.3799 sec  / total_loss : 0.8103 correct : 6294/9055 -> 69.5086%
# best epoch : 129/2000 / val accuracy : 69.552733%
# ==============================
# current_lr : 0.000050
# train dataset : 141/2000 epochs spend time : 3.5502 sec / total_loss : 0.9456 correct : 19338/28705 -> 67.3681%
# test dataset : 141/2000 epochs spend time : 0.3721 sec  / total_loss : 0.8053 correct : 6304/9055 -> 69.6190%
# best epoch : 141/2000 / val accuracy : 69.618995%
# ==============================
# current_lr : 0.000050
# train dataset : 142/2000 epochs spend time : 3.5504 sec / total_loss : 0.9504 correct : 19278/28705 -> 67.1590%
# test dataset : 142/2000 epochs spend time : 0.3688 sec  / total_loss : 0.8166 correct : 6215/9055 -> 68.6361%
# best epoch : 141/2000 / val accuracy : 69.618995%
# ==============================
# current_lr : 0.000050
# train dataset : 143/2000 epochs spend time : 3.5693 sec / total_loss : 0.9471 correct : 19373/28705 -> 67.4900%
# test dataset : 143/2000 epochs spend time : 0.3656 sec  / total_loss : 0.8084 correct : 6284/9055 -> 69.3981%
# best epoch : 141/2000 / val accuracy : 69.618995%
# ==============================
# current_lr : 0.000050
# train dataset : 144/2000 epochs spend time : 3.5538 sec / total_loss : 0.9368 correct : 19453/28705 -> 67.7687%
# test dataset : 144/2000 epochs spend time : 0.3699 sec  / total_loss : 0.8068 correct : 6293/9055 -> 69.4975%
# best epoch : 141/2000 / val accuracy : 69.618995%
# ==============================
# current_lr : 0.000050
# ...
# ==============================
# current_lr : 0.000006
# train dataset : 311/2000 epochs spend time : 3.5689 sec / total_loss : 0.8138 correct : 20772/28705 -> 72.3637%
# test dataset : 311/2000 epochs spend time : 0.3647 sec  / total_loss : 0.6913 correct : 6638/9055 -> 73.3076%
# best epoch : 294/2000 / val accuracy : 73.318609%
# ==============================
# current_lr : 0.000006
# train dataset : 312/2000 epochs spend time : 3.5728 sec / total_loss : 0.8125 correct : 20771/28705 -> 72.3602%
# test dataset : 312/2000 epochs spend time : 0.3861 sec  / total_loss : 0.6911 correct : 6637/9055 -> 73.2965%
# best epoch : 294/2000 / val accuracy : 73.318609%
# ==============================
# current_lr : 0.000006
# train dataset : 313/2000 epochs spend time : 3.5801 sec / total_loss : 0.8166 correct : 20800/28705 -> 72.4612%
# test dataset : 313/2000 epochs spend time : 0.3792 sec  / total_loss : 0.6907 correct : 6638/9055 -> 73.3076%
# best epoch : 294/2000 / val accuracy : 73.318609%
# ==============================
# current_lr : 0.000006
# train dataset : 314/2000 epochs spend time : 3.5808 sec / total_loss : 0.8180 correct : 20743/28705 -> 72.2627%
# test dataset : 314/2000 epochs spend time : 0.3862 sec  / total_loss : 0.6926 correct : 6629/9055 -> 73.2082%
# best epoch : 294/2000 / val accuracy : 73.318609%
# ==============================
# current_lr : 0.000006
# train dataset : 315/2000 epochs spend time : 3.5667 sec / total_loss : 0.8142 correct : 20778/28705 -> 72.3846%
# test dataset : 315/2000 epochs spend time : 0.3610 sec  / total_loss : 0.6917 correct : 6638/9055 -> 73.3076%
# best epoch : 294/2000 / val accuracy : 73.318609%
# ==============================
# current_lr : 0.000006
# train dataset : 316/2000 epochs spend time : 3.5362 sec / total_loss : 0.8142 correct : 20685/28705 -> 72.0606%
# test dataset : 316/2000 epochs spend time : 0.3675 sec  / total_loss : 0.6912 correct : 6640/9055 -> 73.3297%
# best epoch : 316/2000 / val accuracy : 73.329652%
# ==============================
# current_lr : 0.000006
# train dataset : 317/2000 epochs spend time : 3.5554 sec / total_loss : 0.8174 correct : 20689/28705 -> 72.0746%
# test dataset : 317/2000 epochs spend time : 0.3677 sec  / total_loss : 0.6910 correct : 6641/9055 -> 73.3407%
# best epoch : 317/2000 / val accuracy : 73.340696%
# ==============================
# current_lr : 0.000006
# train dataset : 318/2000 epochs spend time : 3.5546 sec / total_loss : 0.8106 correct : 20805/28705 -> 72.4787%
# test dataset : 318/2000 epochs spend time : 0.3639 sec  / total_loss : 0.6901 correct : 6645/9055 -> 73.3849%
# best epoch : 318/2000 / val accuracy : 73.384870%
# ==============================
# current_lr : 0.000006
# train dataset : 319/2000 epochs spend time : 3.5618 sec / total_loss : 0.8116 correct : 20752/28705 -> 72.2940%
# test dataset : 319/2000 epochs spend time : 0.3625 sec  / total_loss : 0.6905 correct : 6641/9055 -> 73.3407%
# best epoch : 318/2000 / val accuracy : 73.384870%
# ==============================
# current_lr : 0.000006
# train dataset : 320/2000 epochs spend time : 3.5352 sec / total_loss : 0.8103 correct : 20763/28705 -> 72.3323%
# test dataset : 320/2000 epochs spend time : 0.3753 sec  / total_loss : 0.6900 correct : 6641/9055 -> 73.3407%
# best epoch : 318/2000 / val accuracy : 73.384870%
# ==============================
# current_lr : 0.000006
# train dataset : 321/2000 epochs spend time : 3.5402 sec / total_loss : 0.8118 correct : 20762/28705 -> 72.3289%
# test dataset : 321/2000 epochs spend time : 0.3719 sec  / total_loss : 0.6902 correct : 6642/9055 -> 73.3517%
# best epoch : 318/2000 / val accuracy : 73.384870%
# ==============================
# current_lr : 0.000006
# train dataset : 322/2000 epochs spend time : 3.5178 sec / total_loss : 0.8119 correct : 20800/28705 -> 72.4612%
# test dataset : 322/2000 epochs spend time : 0.3749 sec  / total_loss : 0.6894 correct : 6645/9055 -> 73.3849%
# best epoch : 318/2000 / val accuracy : 73.384870%
# ==============================
# current_lr : 0.000006
# train dataset : 323/2000 epochs spend time : 3.5308 sec / total_loss : 0.8154 correct : 20755/28705 -> 72.3045%
# test dataset : 323/2000 epochs spend time : 0.3637 sec  / total_loss : 0.6904 correct : 6638/9055 -> 73.3076%
# best epoch : 318/2000 / val accuracy : 73.384870%
# ==============================
# current_lr : 0.000006
# train dataset : 324/2000 epochs spend time : 3.5361 sec / total_loss : 0.8137 correct : 20838/28705 -> 72.5936%
# test dataset : 324/2000 epochs spend time : 0.3707 sec  / total_loss : 0.6906 correct : 6636/9055 -> 73.2855%
# best epoch : 318/2000 / val accuracy : 73.384870%
# ==============================
# current_lr : 0.000006
# train dataset : 325/2000 epochs spend time : 3.5300 sec / total_loss : 0.8108 correct : 20750/28705 -> 72.2871%
# test dataset : 325/2000 epochs spend time : 0.3625 sec  / total_loss : 0.6904 correct : 6640/9055 -> 73.3297%
# best epoch : 318/2000 / val accuracy : 73.384870%
# ==============================
# current_lr : 0.000006
# train dataset : 326/2000 epochs spend time : 3.5412 sec / total_loss : 0.8139 correct : 20702/28705 -> 72.1198%
# test dataset : 326/2000 epochs spend time : 0.3557 sec  / total_loss : 0.6904 correct : 6642/9055 -> 73.3517%
# best epoch : 318/2000 / val accuracy : 73.384870%
# ==============================
# current_lr : 0.000006
# train dataset : 327/2000 epochs spend time : 3.5477 sec / total_loss : 0.8181 correct : 20673/28705 -> 72.0188%
# test dataset : 327/2000 epochs spend time : 0.3623 sec  / total_loss : 0.6911 correct : 6632/9055 -> 73.2413%
# best epoch : 318/2000 / val accuracy : 73.384870%
# ==============================
# current_lr : 0.000006
# train dataset : 328/2000 epochs spend time : 3.5770 sec / total_loss : 0.8103 correct : 20729/28705 -> 72.2139%
# test dataset : 328/2000 epochs spend time : 0.3704 sec  / total_loss : 0.6894 correct : 6646/9055 -> 73.3959%
# best epoch : 328/2000 / val accuracy : 73.395914%
# ==============================
# current_lr : 0.000006
# train dataset : 329/2000 epochs spend time : 3.5159 sec / total_loss : 0.8078 correct : 20852/28705 -> 72.6424%
# test dataset : 329/2000 epochs spend time : 0.3693 sec  / total_loss : 0.6905 correct : 6636/9055 -> 73.2855%
# best epoch : 328/2000 / val accuracy : 73.395914%
# ==============================
# current_lr : 0.000006
# train dataset : 330/2000 epochs spend time : 3.5450 sec / total_loss : 0.8081 correct : 20940/28705 -> 72.9490%
# test dataset : 330/2000 epochs spend time : 0.3782 sec  / total_loss : 0.6892 correct : 6644/9055 -> 73.3738%
# best epoch : 328/2000 / val accuracy : 73.395914%
# ==============================
# current_lr : 0.000006
# train dataset : 331/2000 epochs spend time : 3.5455 sec / total_loss : 0.8176 correct : 20691/28705 -> 72.0815%
# test dataset : 331/2000 epochs spend time : 0.3655 sec  / total_loss : 0.6895 correct : 6641/9055 -> 73.3407%
# best epoch : 328/2000 / val accuracy : 73.395914%
# ==============================
# current_lr : 0.000006
# train dataset : 332/2000 epochs spend time : 3.5209 sec / total_loss : 0.8098 correct : 20797/28705 -> 72.4508%
# test dataset : 332/2000 epochs spend time : 0.3659 sec  / total_loss : 0.6897 correct : 6644/9055 -> 73.3738%
# best epoch : 328/2000 / val accuracy : 73.395914%
# ==============================
# current_lr : 0.000006
# train dataset : 333/2000 epochs spend time : 3.5634 sec / total_loss : 0.8101 correct : 20750/28705 -> 72.2871%
# test dataset : 333/2000 epochs spend time : 0.3647 sec  / total_loss : 0.6908 correct : 6633/9055 -> 73.2523%
# best epoch : 328/2000 / val accuracy : 73.395914%
# ==============================
# current_lr : 0.000006
# train dataset : 334/2000 epochs spend time : 3.5446 sec / total_loss : 0.8125 correct : 20778/28705 -> 72.3846%
# test dataset : 334/2000 epochs spend time : 0.3643 sec  / total_loss : 0.6922 correct : 6627/9055 -> 73.1861%
# best epoch : 328/2000 / val accuracy : 73.395914%
# ==============================
# current_lr : 0.000006
# train dataset : 335/2000 epochs spend time : 3.5525 sec / total_loss : 0.8149 correct : 20729/28705 -> 72.2139%
# test dataset : 335/2000 epochs spend time : 0.3687 sec  / total_loss : 0.6908 correct : 6640/9055 -> 73.3297%
# best epoch : 328/2000 / val accuracy : 73.395914%
# ==============================
# current_lr : 0.000006
# train dataset : 336/2000 epochs spend time : 3.5622 sec / total_loss : 0.8121 correct : 20793/28705 -> 72.4369%
# test dataset : 336/2000 epochs spend time : 0.3676 sec  / total_loss : 0.6901 correct : 6638/9055 -> 73.3076%
# best epoch : 328/2000 / val accuracy : 73.395914%
# ==============================
# current_lr : 0.000006
# train dataset : 337/2000 epochs spend time : 3.5391 sec / total_loss : 0.8153 correct : 20745/28705 -> 72.2696%
# test dataset : 337/2000 epochs spend time : 0.3695 sec  / total_loss : 0.6899 correct : 6636/9055 -> 73.2855%
# best epoch : 328/2000 / val accuracy : 73.395914%
# ==============================
# current_lr : 0.000006
# train dataset : 338/2000 epochs spend time : 3.5496 sec / total_loss : 0.8151 correct : 20786/28705 -> 72.4125%
# test dataset : 338/2000 epochs spend time : 0.3585 sec  / total_loss : 0.6891 correct : 6643/9055 -> 73.3628%
# best epoch : 328/2000 / val accuracy : 73.395914%
# ==============================
# current_lr : 0.000006
# train dataset : 339/2000 epochs spend time : 3.5408 sec / total_loss : 0.8101 correct : 20729/28705 -> 72.2139%
# test dataset : 339/2000 epochs spend time : 0.3824 sec  / total_loss : 0.6892 correct : 6645/9055 -> 73.3849%
# best epoch : 328/2000 / val accuracy : 73.395914%
# ==============================
# current_lr : 0.000006
# train dataset : 340/2000 epochs spend time : 3.5626 sec / total_loss : 0.8157 correct : 20743/28705 -> 72.2627%
# test dataset : 340/2000 epochs spend time : 0.3691 sec  / total_loss : 0.6878 correct : 6646/9055 -> 73.3959%
# best epoch : 328/2000 / val accuracy : 73.395914%
# ==============================
# current_lr : 0.000006
# train dataset : 341/2000 epochs spend time : 3.5368 sec / total_loss : 0.8148 correct : 20811/28705 -> 72.4996%
# test dataset : 341/2000 epochs spend time : 0.3674 sec  / total_loss : 0.6889 correct : 6640/9055 -> 73.3297%
# best epoch : 328/2000 / val accuracy : 73.395914%
# ==============================
# current_lr : 0.000006
# train dataset : 342/2000 epochs spend time : 3.5247 sec / total_loss : 0.8078 correct : 20785/28705 -> 72.4090%
# test dataset : 342/2000 epochs spend time : 0.3563 sec  / total_loss : 0.6889 correct : 6642/9055 -> 73.3517%
# best epoch : 328/2000 / val accuracy : 73.395914%
# ==============================
# current_lr : 0.000006
# train dataset : 343/2000 epochs spend time : 3.5495 sec / total_loss : 0.8107 correct : 20832/28705 -> 72.5727%
# test dataset : 343/2000 epochs spend time : 0.3723 sec  / total_loss : 0.6906 correct : 6635/9055 -> 73.2744%
# best epoch : 328/2000 / val accuracy : 73.395914%
# ==============================
# current_lr : 0.000006
# train dataset : 344/2000 epochs spend time : 3.5447 sec / total_loss : 0.8114 correct : 20844/28705 -> 72.6145%
# test dataset : 344/2000 epochs spend time : 0.3720 sec  / total_loss : 0.6897 correct : 6635/9055 -> 73.2744%
# best epoch : 328/2000 / val accuracy : 73.395914%
# ==============================
# current_lr : 0.000006
# train dataset : 345/2000 epochs spend time : 3.5201 sec / total_loss : 0.8092 correct : 20757/28705 -> 72.3114%
# test dataset : 345/2000 epochs spend time : 0.3721 sec  / total_loss : 0.6894 correct : 6635/9055 -> 73.2744%
# best epoch : 328/2000 / val accuracy : 73.395914%
# ==============================
# current_lr : 0.000006
# train dataset : 346/2000 epochs spend time : 3.5505 sec / total_loss : 0.8153 correct : 20723/28705 -> 72.1930%
# test dataset : 346/2000 epochs spend time : 0.3645 sec  / total_loss : 0.6887 correct : 6642/9055 -> 73.3517%
# best epoch : 328/2000 / val accuracy : 73.395914%
# ==============================
# current_lr : 0.000006
# train dataset : 347/2000 epochs spend time : 3.5319 sec / total_loss : 0.8109 correct : 20711/28705 -> 72.1512%
# test dataset : 347/2000 epochs spend time : 0.3584 sec  / total_loss : 0.6886 correct : 6643/9055 -> 73.3628%
# best epoch : 328/2000 / val accuracy : 73.395914%
# ==============================
# current_lr : 0.000006
# train dataset : 348/2000 epochs spend time : 3.5428 sec / total_loss : 0.8113 correct : 20758/28705 -> 72.3149%
# test dataset : 348/2000 epochs spend time : 0.3693 sec  / total_loss : 0.6882 correct : 6643/9055 -> 73.3628%
# best epoch : 328/2000 / val accuracy : 73.395914%
# ==============================
# current_lr : 0.000006
# train dataset : 349/2000 epochs spend time : 3.5627 sec / total_loss : 0.8139 correct : 20740/28705 -> 72.2522%
# test dataset : 349/2000 epochs spend time : 0.3682 sec  / total_loss : 0.6881 correct : 6646/9055 -> 73.3959%
# best epoch : 328/2000 / val accuracy : 73.395914%
# ==============================
# current_lr : 0.000006
# train dataset : 350/2000 epochs spend time : 3.5611 sec / total_loss : 0.8162 correct : 20753/28705 -> 72.2975%
# test dataset : 350/2000 epochs spend time : 0.3667 sec  / total_loss : 0.6884 correct : 6639/9055 -> 73.3186%
# best epoch : 328/2000 / val accuracy : 73.395914%
# ==============================
# current_lr : 0.000006
# train dataset : 351/2000 epochs spend time : 3.5496 sec / total_loss : 0.8126 correct : 20802/28705 -> 72.4682%
# test dataset : 351/2000 epochs spend time : 0.3731 sec  / total_loss : 0.6880 correct : 6643/9055 -> 73.3628%
# best epoch : 328/2000 / val accuracy : 73.395914%
# ==============================
# current_lr : 0.000003
# train dataset : 352/2000 epochs spend time : 3.5763 sec / total_loss : 0.8104 correct : 20809/28705 -> 72.4926%
# test dataset : 352/2000 epochs spend time : 0.3862 sec  / total_loss : 0.6894 correct : 6642/9055 -> 73.3517%
# best epoch : 328/2000 / val accuracy : 73.395914%
# ==============================
# current_lr : 0.000003
# train dataset : 353/2000 epochs spend time : 3.5700 sec / total_loss : 0.8100 correct : 20791/28705 -> 72.4299%
# test dataset : 353/2000 epochs spend time : 0.3824 sec  / total_loss : 0.6887 correct : 6640/9055 -> 73.3297%
# best epoch : 328/2000 / val accuracy : 73.395914%
# ==============================
# current_lr : 0.000003
# train dataset : 354/2000 epochs spend time : 3.5329 sec / total_loss : 0.8136 correct : 20801/28705 -> 72.4647%
# test dataset : 354/2000 epochs spend time : 0.3658 sec  / total_loss : 0.6882 correct : 6642/9055 -> 73.3517%
# best epoch : 328/2000 / val accuracy : 73.395914%
# ==============================
# current_lr : 0.000003
# train dataset : 355/2000 epochs spend time : 3.5319 sec / total_loss : 0.8086 correct : 20822/28705 -> 72.5379%
# test dataset : 355/2000 epochs spend time : 0.3664 sec  / total_loss : 0.6880 correct : 6642/9055 -> 73.3517%
# best epoch : 328/2000 / val accuracy : 73.395914%
# ==============================
# current_lr : 0.000003
# train dataset : 356/2000 epochs spend time : 3.5574 sec / total_loss : 0.8080 correct : 20832/28705 -> 72.5727%
# test dataset : 356/2000 epochs spend time : 0.3639 sec  / total_loss : 0.6883 correct : 6643/9055 -> 73.3628%
# best epoch : 328/2000 / val accuracy : 73.395914%
# ==============================
# current_lr : 0.000003
# train dataset : 357/2000 epochs spend time : 3.5489 sec / total_loss : 0.8087 correct : 20778/28705 -> 72.3846%
# test dataset : 357/2000 epochs spend time : 0.3653 sec  / total_loss : 0.6882 correct : 6640/9055 -> 73.3297%
# best epoch : 328/2000 / val accuracy : 73.395914%
# ==============================
# current_lr : 0.000003
# train dataset : 358/2000 epochs spend time : 3.5476 sec / total_loss : 0.8105 correct : 20802/28705 -> 72.4682%
# test dataset : 358/2000 epochs spend time : 0.3720 sec  / total_loss : 0.6881 correct : 6641/9055 -> 73.3407%
# best epoch : 328/2000 / val accuracy : 73.395914%
# ==============================
# current_lr : 0.000003
# train dataset : 359/2000 epochs spend time : 3.5815 sec / total_loss : 0.8092 correct : 20798/28705 -> 72.4543%
# test dataset : 359/2000 epochs spend time : 0.3946 sec  / total_loss : 0.6882 correct : 6640/9055 -> 73.3297%
# Early Stopping
# best epoch : 328/2000 / accuracy : 73.395914%
# ==============================
